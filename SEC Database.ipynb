# %%
import requests
from bs4 import BeautifulSoup
import json
from collections import OrderedDict
from datetime import datetime
from dateutil.relativedelta import relativedelta
from __future__ import print_function 
import mysql.connector 
from mysql.connector import errorcode
from timeit import default_timer as timer
import time
import copy
import numpy_financial

# %%
# Update_or_Delete = input('Do you wish to Update or Delete/Restart the Datebase?')
# Confirmation = input(f'Are you sure you wish to {Update_or_Delete}')
# Computer_Shutdown = input(Do you wish to shut off the computer after running this file?)

# if Confirmation != 'Yes':
#     x=1/0

# %%
# Update or Delete
Update_or_Delete = 'Update'
# Yes or No
Computer_Shutdown = 'No'

# %%
cnx = mysql.connector.connect(user='root', password = 'password')
cursor = cnx.cursor()

# %%
if Update_or_Delete == 'Delete':
    # Drop Database
    try:
        query = ("drop database sec")
        cursor.execute(query)
        print('Successfully deleted previous SEC Database')
    except Exception as err:
        print(err)

# %% [markdown]
# # Importing Functions from another file

# %%
# %run ./Functions_Folder/Functions.ipynb
# %run ./Functions_Folder/Updating_the_Database.ipynb
# Out:
# Creating table Company_Info: already exists.
# Creating table CalcTable: already exists.
# Creating table Yahoo_Forecast: already exists.
# Creating table futureEarningsDate: already exists.

# %%
if Update_or_Delete == 'Delete':
    cnx = mysql.connector.connect(user='root', password = 'password', database='SEC')
    cursor = cnx.cursor()
    # #Creating Tables 
    Table_List = ['Revenue', 'Earnings', 'Earnings_Per_Share', 'Levered_Free_Cash_Flow', 'Cash', 'Total_Debt', 
                  'Long_term_Liabilites', 'Total_LTL_per_LFCF', 'Market_Cap', 'Div_per_Share', 'CashperTotalDebt', 
                  'Total_Debt_to_Equity']
    for Table in Table_List:
        Creating_a_table(Table)
    Master_List = [ 'PORT' , 'MULN' , 'NECA' , 'TSLA' , 'BBRW' , 'HCMC' , 'KEGS' , 'F' , 'AITX' , 'XELA' , 'AAPL' , 'PPCB' , 'AMZN' , 'HVCW' , 'HEMP' , 'MCOA' , 'GENE' , 'HLBZ' , 'META' , 'SRMX' , 'NHMD' , 'AI' , 'SYSX' , 'GMBL' , 'AMD' , 'HSCS' , 'GOOGL' , 'PLTR' , 'APE' , 'TONR' , 'CVNA' , 'CMGR' , 'AIAD' , 'INTC' , 'SOFI' , 'NIO' , 'BBAI' , 'AMC' , 'NTRR' , 'EEENF' , 'GFAI' , 'SOUN' , 'BTDG' , 'SNAP' , 'BGXX' , 'LUMN' , 'NVDA' , 'IGEX' , 'INND' , 'JWN' , 'SIDU' , 'BLFE' , 'INTK' , 'XCPL' , 'VALE' , 'GHMP' , 'BYOC' , 'SAPX' , 'FFIE' , 'BAC' , 'COIN' , 'COMS' , 'GNCP' , 'GOOG' , 'BOMO' , 'ABQQ' , 'HBI' , 'CCL' , 'NU' , 'MARA' , 'ABEV' , 'ITUB' , 'PTON' , 'MGTA' , 'TRKA' , 'T' , 'LCID' , 'MSFT' , 'AFRM' , 'CRK' , 'MAPT' , 'BBBY' , 'SANP' , 'OPEN' , 'PBTS' , 'CGAC' , 'RIVN' , 'RIG' , 'SWN' , 'SIRI' , 'UBER' , 'GOLD' , 'WLAN' , 'NOK' , 'LCLP' , 'BNOW' , 'CS' , 'GTEH' , 'BBD' , 'PFE' , 'ICBU' , 'SNMN' , 'NVOS' , 'ICNM' , 'ECEZ' , 'PBR' , 'AAL' , 'IDEX' , 'DPLS' , 'NKLA' , 'SHOP' , 'BILL' , 'AUY' , 'DNA' , 'ECOX' , 'LGBS' , 'WBD' , 'AMIH' , 'NNRX' , 'CMCSA' , 'XOM' , 'WISH' , 'MLFB' , 'C' , 'GRAB' , 'CBDD' , 'RIOT' , 'MRNJ' , 'BZFD' , 'GM' , 'ALYI' , 'VZ' , 'ADC' , 'EVIO' , 'NSAV' , 'CRKN' , 'ET' , 'CSCO' , 'KGC' , 'KYNC' , 'OXY' , 'ERIC' , 'HMBL' , 'HBRM' , 'WFC' , 'GSFI' , 'AVTR' , 'JZZI' , 'ETEK' , 'BABA' , 'DKNG' , 'ASTA' , 'CBDL' , 'XPEV' , 'KO' , 'TLRY' , 'APRN' , 'IQ' , 'FTXP' , 'BRBL' , 'LU' , 'SBUX' , 'TLSS' , 'DVLP' , 'OZSC' , 'PYPL' , 'RNVA' , 'ERBB' , 'RBLX' , 'SI' , 'FCEL' , 'KMI' , 'IDGC' , 'GOEV' , 'ZAAG' , 'U' , 'PINS' , 'HUT' , 'COP' , 'PLUG' , 'PCG' , 'SKLZ' , 'QCOM' , 'FCX' , 'SPCE' , 'BSX' , 'HBAN' , 'VOD' , 'GILD' , 'HAL' , 'COWI' , 'SQ' , 'VBHI' , 'DIS' , 'BIEI' , 'VTXB' , 'AUNXF' , 'UBQU' , 'IVCRQ' , 'TSM' , 'FTCH' , 'LYFT' , 'PXMD' , 'MU' , 'X' , 'ATNX' , 'GTCH' , 'NVTA' , 'NCLH' , 'MPW' , 'MRVL' , 'FUBO' , 'CEOS' , 'VXIT' , 'NEE' , 'RSLS' , 'KEY' , 'JPM' , 'LAZR' , 'QBTS' , 'MRK' , 'FRGT' , 'HOOD' , 'CGC' , 'DIDIY' , 'JBLU' , 'HYSR' , 'MRO' , 'SLB' , 'GFI' , 'AGNC' , 'BP' , 'QRTEA' , 'MO' , 'CHPT' , 'SEII' , 'BMY' , 'CORZQ' , 'RLX' , 'LYG' , 'PCSA' , 'CLF' , 'HL' , 'NYCB' , 'TELL' , 'UMC' , 'NEM' , 'HPE' , 'WDLF' , 'ELYS' , 'GRCL' , 'CSX' , 'GOOS' , 'SCHW' , 'HST' , 'NFLX' , 'ONCI' , 'QS' , 'M' , 'RITE' , 'NOUV' , 'UEC' , 'BKR' , 'VERB' , 'TJX' , 'GPS' , 'CPNG' , 'ROIV' , 'MCHP' , 'PACV' , 'CFRX' , 'SABR' , 'GRST' , 'SAN' , 'ACB' , 'BTG' , 'INO' , 'CNHI' , 'ARR' , 'GNS' , 'SIRC' , 'ONEM' , 'WE' , 'RSHN' , 'KRBP' , 'ON' , 'PRCX' , 'VTGN' , 'BRFS' , 'CVX' , 'BB' , 'AMCR' , 'DAL' , 'UPST' , 'ARDX' , 'DGWR' , 'YMM' , 'CLNV' , 'GEN' , 'VGID' , 'RDFN' , 'JZXN' , 'QBAN' , 'BITF' , 'ITOX' , 'D' , 'TWO' , 'TGGI' , 'PSNL' , 'TGHI' , 'GARB' , 'CPG' , 'BEGI' , 'CVE' , 'TENX' , 'CANO' , 'PBR/A' , 'JNPR' , 'WMB' , 'FOXO' , 'CTSH' , 'IGEN' , 'TYDE' , 'TEAM' , 'SNOW' , 'KGKG' , 'MMAT' , 'GGB' , 'PARA' , 'BEKE' , 'VINO' , 'CVS' , 'RGTI' , 'COTY' , 'APTY' , 'SMMT' , 'CFLT' , 'BK' , 'RGBP' , 'PSLV' , 'VTRS' , 'KDP' , 'TEVA' , 'DDOG' , 'AG' , 'AABB' , 'GEVO' , 'FE' , 'EXC' , 'ASX' , 'UAL' , 'MS' , 'BNGO' , 'SBIG' , 'CTRA' , 'UAA' , 'JNJ' , 'HLN' , 'WGS' , 'AVYA' , 'AIG' , 'EGHT' , 'KALWW' , 'KOS' , 'DNN' , 'TWOU' , 'NOHO' , 'SKX' , 'SMME' , 'USB' , 'SRNE' , 'DVN' , 'ABBV' , 'TMC' , 'MUFG' , 'IBN' , 'TFC' , 'CRM' , 'NVAX' , 'ARVL' , 'MTCH' , 'VRM' , 'ZOM' , 'PR' , 'ING' , 'TTCM' , 'BBIG' , 'DBMM' , 'SFRX' , 'RTON' , 'MDLZ' , 'TAL' , 'AR' , 'IVZ' , 'BEN' , 'KHC' , 'MARK' , 'PATH' , 'AZFL' , 'JD' , 'RF' , 'AMAT' , 'RKLB' , 'RAKR' , 'ABNB' , 'TOMDF' , 'ZIM' , 'LI' , 'KAL' , 'LESL' , 'CLOV' , 'FUNR' , 'GGII' , 'PG' , 'HPNN' , 'ROKU' , 'VLDR' , 'WBA' , 'SKYE' , 'PCLI' , 'ICTY' , 'FSR' , 'OPTI' , 'CCJ' , 'DASH' , 'XP' , 'CHWY' , 'WDC' , 'ATVI' , 'GE' , 'IGPK' , 'RMRK' , 'SHEL' , 'WKHS' , 'TXN' , 'GTII' , 'NET' , 'WMT' , 'GPRO' , 'AVVH' , 'WULF' , 'PAYA' , 'ORCL' , 'LLY' , 'W' , 'SYF' , 'PDD' , 'FAZE' , 'CDE' , 'BYRG' , 'TMUS' , 'GIS' , 'FLEX' , 'TPTW' , 'TME' , 'RUN' , 'PAAS' , 'SBES' , 'INFY' , 'STLA' , 'APA' , 'FTNT' , 'MSPC' , 'CLSK' , 'CNP' , 'UNH' , 'BBBT' , 'BILI' , 'BA' , 'RITM' , 'BRK/B' , 'PLPL' , 'RKT' , 'CX' , 'PEP' , 'AXP' , 'ILUS' , 'V' , 'RRC' , 'SPWR' , 'MGAM' , 'TXTM' , 'CLX' , 'RBGLY' , 'MJNA' , 'ELAN' , 'CNC' , 'VICI' , 'EAF' , 'NLY' , 'S' , 'HMNU' , 'AKAN' , 'STM' , 'TOST' , 'KR' , 'ALKM' , 'VST' , 'PHIL' , 'OCGN' , 'FBCD' , 'MNGG' , 'FITB' , 'BX' , 'FTI' , 'HIRU' , 'CBGL' , 'MDT' , 'GME' , 'NKE' , 'SLM' , 'CENN' , 'DT' , 'CG' , 'AZN' , 'LUV' , 'JCI' , 'STNE' , 'CYBL' , 'IONQ' , 'BAX' , 'EW' , 'NRDY' , 'AULT' , 'CTVA' , 'PPL' , 'RDHL' , 'GERN' , 'BCS' , 'FIGS' , 'CZR' , 'MET' , 'VFC' , 'KIM' , 'DB' , 'GBHL' , 'ZI' , 'RIDE' , 'ALLY' , 'INCT' , 'AHRO' , 'EEGI' , 'PACB' , 'GOTU' , 'TTD' , 'YSG' , 'ARRY' , 'WU' , 'ELRA' , 'HON' , 'IMPP' , 'IPG' , 'TDOC' , 'HYRE' , 'OWL' , 'CAG' , 'EA' , 'GEGI' , 'PJET' , 'EQT' , 'VS' , 'TGTX' , 'HPQ' , 'DUK' , 'TCOM' , 'CIG' , 'VIAV' , 'DLTR' , 'VIPS' , 'MJLB' , 'XTRM' , 'AMRS' , 'VLY' , 'EOG' , 'AU' , 'ENVX' , 'DM' , 'CAT' , 'PAA' , 'AQN' , 'ALR' , 'ASTR' , 'AEM' , 'FAST' , 'GOSS' , 'TSP' , 'CRWD' , 'FSM' , 'ADI' , 'SE' , 'DOCU' , 'HMY' , 'DOW' , 'LVS' , 'EPD' , 'IAG' , 'FTV' , 'WNW' , 'KSS' , 'REAL' , 'AZUL' , 'NVS' , 'FIS' , 'SO' , 'AGI' , 'MOS' , 'CL' , 'RTX' , 'VDRM' , 'VPER' , 'EBAY' , 'LGMK' , 'SMFG' , 'WY' , 'PSTG' , 'ROST' , 'GTLB' , 'WHEN' , 'IBM' , 'ABT' , 'MTTR' , 'MLCO' , 'VNO' , 'IMTL' , 'UNIT' , 'TCEHY' , 'EXK' , 'OTLY' , 'GT' , 'SU' , 'JOBY' , 'LYB' , 'AES' , 'PDGO' , 'NXE' , 'EBET' , 'MTG' , 'MQ' , 'PEAK' , 'NGD' , 'O' , 'XM' , 'GSK' , 'MTVC' , 'PAOG' , 'WPM' , 'PK' , 'ASAN' , 'HGEN' , 'CAH' , 'OVV' , 'BCNN' , 'GLW' , 'OHI' , 'ETRN' , 'AA' , 'HCP' , 'SNDL' , 'PM' , 'PSX' , 'BIDU' , 'LC' , 'TAK' , 'SNY' , 'NI' , 'MFC' , 'ZM' , 'GVSI' , 'FISV' , 'CARR' , 'MMEX' , 'IR' , 'BDN' , 'VLD' , 'MAT' , 'SILV' , 'GDSI' , 'CAVR' , 'HD' , 'PRPM' , 'LNC' , 'SPZI' , 'SDC' , 'CCO' , 'BHP' , 'BTU' , 'TSN' , 'AFL' , 'STT' , 'PURA' , 'BOTY' , 'COMP' , 'AUR' , 'ICOA' , 'PLD' , 'SYY' , 'AM' , 'VRUS' , 'SGFY' , 'ACHR' , 'TWST' , 'FATE' , 'CBTC' , 'NOVA' , 'VNTH' , 'EMR' , 'MGM' , 'ZH' , 'TTWO' , 'MPC' , 'CNNA' , 'GSAT' , 'NOV' , 'DHC' , 'VHAQr' , 'LHDX' , 'CIVX' , 'NWL' , 'COF' , 'MVIS' , 'PRTYQ' , 'MT' , 'SFT' , 'EQX' , 'EXPR' , 'VPLM' , 'FSLY' , 'BLDP' , 'TS' , 'FNB' , 'GPK' , 'ARMK' , 'TMSH' , 'ENB' , 'CAN' , 'PENN' , 'CHGG' , 'TWLO' , 'FHN' , 'CME' , 'GEHC' , 'AMGN' , 'MSGM' , 'ZS' , 'CNK' , 'RCL' , 'FNGU' , 'HLF' , 'CWGYF' , 'FTAAU' , 'BKKT' , 'LOW' , 'ATI' , 'DKSC' , 'AEO' , 'INVH' , 'VLO' , 'WTER' , 'INKW' , 'VRT' , 'CTLT' , 'BLUE' , 'MCD' , 'AGEN' , 'RIO' , 'IMJX' , 'WTI' , 'MBLY' , 'THER' , 'DISH' , 'GDVM' , 'CFG' , 'DXCM' , 'CDTX' , 'HYMC' , 'HIG' , 'LSCC' , 'TGT' , 'XEL' , 'VNUE' , 'DELL' , 'CLVT' , 'RSCZF' , 'TGRO' , 'APH' , 'NRG' , 'Z' , 'BYND' , 'NTR' , 'LKNCY' , 'APD' , 'CB' , 'PHYS' , 'SMCE' , 'ZBH' , 'GNW' , 'APPS' , 'CI' , 'AKBA' , 'BAYRY' , 'DD' , 'MRNA' , 'MMNFF' , 'TECK' , 'GTLL' , 'TSOI' , 'CYDY' , 'ETHE' , 'REI' , 'SUZ' , 'OKTA' , 'BYD' , 'SAND' , 'RDAR' , 'PHM' , 'NAT' , 'UPS' , 'INQD' , 'SENS' , 'EQNR' , 'GSTC' , 'PTEN' , 'SPLK' , 'SPYR' , 'MA' , 'BN' , 'GBTC' , 'CHX' , 'MGNI' , 'UA' , 'ATER' , 'ADM' , 'GTE' , 'WSRC' , 'ADBE' , 'STEM' , 'APP' , 'ETSY' , 'BIRD' , 'MMM' , 'RCM' , 'TRIP' , 'TEL' , 'PRCH' , 'HIMS' , 'IOVA' , 'SLDP' , 'LIN' , 'KKR' , 'ENZC' , 'ASTS' , 'DHI' , 'NXPI' , 'IP' , 'PGEN' , 'BANT' , 'NEX' , 'WNBD' , 'YUMC' , 'CCI' , 'EVGO' , 'COUP' , 'JMIA' , 'PAGS' , 'NNDM' , 'MNST' , 'ADT' , 'AEP' , 'EDIT' , 'SEV' , 'QRVO' , 'CENX' , 'PBLA' , 'QEDN' , 'PD' , 'CRUS' , 'BRDS' , 'JSPR' , 'SPOT' , 'ATUS' , 'EMGE' , 'OMC' , 'TPR' , 'NWSA' , 'ALIT' , 'ENPH' , 'BRX' , 'GEGP' , 'K' , 'EDBL' , 'HBM' , 'ADMA' , 'AMT' , 'ZEV' , 'MDXH' , 'SYTA' , 'MVST' , 'PXD' , 'OSH' , 'TV' , 'PANW' , 'COMM' , 'VVR' , 'AQUA' , 'ASST' , 'ORI' , 'CNX' , 'BTI' , 'BALL' , 'AAPJ' , 'CSGP' , 'ONON' , 'SHO' , 'AMRN' , 'ZRFY' , 'VTNR' , 'BDGR' , 'CYH' , 'BIEL' , 'SFIX' , 'MDB' , 'DBX' , 'CWK' , 'CPB' , 'MPLX' , 'CF' , 'WRK' , 'DFS' , 'JHG' , 'PAYO' , 'CGRA' , 'DHT' , 'MNKD' , 'CTIC' , 'LBTYK' , 'OUST' , 'WW' , 'SID' , 'AAGC' , 'PMT' , 'ME' , 'SBSW' , 'SWKS' , 'ASPU' , 'SBH' , 'ADP' , 'INPX' , 'NOG' , 'PNR' , 'EXAS' , 'ICE' , 'DCFC' , 'SPRV' , 'FERN' , 'NUTX' , 'AEE' , 'SPR' , 'DE' , 'CHD' , 'LBRT' , 'NYMT' , 'MXSG' , 'IRWD' , 'TNXP' , 'EIX' , 'NVST' , 'VLTA' , 'FREY' , 'MTB' , 'LSXMK' , 'RAD' , 'DDD' , 'HZNP' , 'HLIT' , 'OPK' , 'GSUN' , 'FDX' , 'APO' , 'DOC' , 'ASB' , 'AGL' , 'CLFD' , 'HSBC' , 'GS' , 'BKD' , 'AMNL' , 'FRO' , 'OI' , 'CNCE' , 'WMS' , 'PBF' , 'STLD' , 'WYPH' , 'AUPH' , 'CMS' , 'PVSP' , 'ATCO' , 'NUE' , 'AXTA' , 'WIT' , 'ARQQ' , 'PGR' , 'SHLS' , 'OUT' , 'HKD' , 'FND' , 'TRU' , 'DXC' , 'NATI' , 'YPF' , 'CNEY' , 'OLPX' , 'ESPR' , 'TCDAQ' , 'ACN' , 'PSRU' , 'WYNN' , 'BWA' , 'HTZ' , 'QBIO' , 'SGMD' , 'XRX' , 'BAM' , 'UNP' , 'CZOO' , 'VFF' , 'BTBT' , 'FOXA' , 'INVU' , 'BFLY' , 'BPTS' , 'PEG' , 'BLDR' , 'UNM' , 'BDX' , 'LAC' , 'KNX' , 'LTHM' , 'CIFR' , 'APPH' , 'PH' , 'APEN' , 'CP' , 'WRB' , 'HWM' , 'ANET' , 'CLM' , 'PSNY' , 'YEXT' , 'EQRX' , 'LEN' , 'LPLA' , 'PAGP' , 'EAST' , 'AVDX' , 'NCMI' , 'IRNT' , 'EC' , 'VKTX' , 'ABML' , 'DLR' , 'HPP' , 'BUD' , 'NEOG' , 'GRCU' , 'AMH' , 'TD' , 'CLNE' , 'BVN' , 'SBRA' , 'UBS' , 'KPTI' , 'ACGL' , 'DG' , 'VMEO' , 'NOKBF' , 'SEGI' , 'VOYA' , 'CHRW' , 'WDAY' , 'ZTS' , 'PLBY' , 'ENFN' , 'NWTT' , 'HUYA' , 'GOGL' , 'AMRX' , 'EGO' , 'IMGN' , 'SY' , 'DCT' , 'WWE' , 'BZ' , 'OKE' , 'SPPI' , 'SWK' , 'EXPE' , 'VHAQ/WS' , 'CRBP' , 'IOT' , 'MAS' , 'CROX' , 'EQH' , 'LEVI' , 'DOCN' , 'RMBS' , 'PDPG' , 'NWG' , 'VXRT' , 'DBD' , 'APTV' , 'LPSN' , 'EVFM' , 'IBRX' , 'ESTC' , 'EL' , 'KMX' , 'AXSM' , 'AVGO' , 'ALGM' , 'FLNC' , 'WOLF' , 'VERI' , 'DRNG' , 'STWD' , 'HDB' , 'QUBT' , 'PHG' , 'MINM' , 'UDR' , 'ACRS' , 'ADHC' , 'ORCC' , 'MIKP' , 'ERAS' , 'WM' , 'EXEL' , 'AMX' , 'AMST' , 'HOUS' , 'ITW' , 'BLND' , 'MSMY' , 'CLLS' , 'HES' , 'ANY' , 'LMND' , 'TAP' , 'GH' , 'DOYU' , 'HAYW' , 'COST' , 'INTU' , 'CUK' , 'BLDV' , 'FOMC' , 'PTRA' , 'KD' , 'FR' , 'CERS' , 'RLFTF' , 'BBVA' , 'OSTK' , 'ELF' , 'ONB' , 'CPRT' , 'RIGL' , 'FOX' , 'EQR' , 'FLGC' , 'LICY' , 'MGTI' , 'CEG' , 'ARCC' , 'RMSL' , 'MODG' , 'HPMM' , 'ESTE' , 'PAYX' , 'SSRM' , 'TERN' , 'KIND' , 'GPCR' , 'CIM' , 'NVO' , 'NINE' , 'BHC' , 'SKYW' , 'DRNK' , 'LILM' , 'AXXA' , 'TROW' , 'KMB' , 'AMBP' , 'CNGT' , 'EBR' , 'IRT' , 'ALL' , 'WEN' , 'HR' , 'CHK' , 'ETR' , 'ETN' , 'HOG' , 'FSLR' , 'VEON' , 'GOL' , 'WIMI' , 'KRG' , 'LNT' , 'ED' , 'HRTX' , 'ENLC' , 'LBTYA' , 'ES' , 'HA' , 'HLX' , 'FL' , 'VGLS' , 'SHIP' , 'RHHBY' , 'IAA' , 'GFS' , 'RCRT' , 'NOW' , 'PRU' , 'TRP' , 'BCRX' , 'IBKR' , 'DBRG' , 'BBIO' , 'FLO' , 'GNTX' , 'WT' , 'LSPD' , 'FUTU' , 'CIEN' , 'VTR' , 'DEI' , 'NEEpP' , 'SHMP' , 'INFN' , 'SONO' , 'HOLX' , 'BXP' , 'SHW' , 'CPRX' , 'ISRG' , 'CTRM' , 'VVV' , 'WEC' , 'ESI' , 'ISEE' , 'GREE' , 'EXTR' , 'DHR' , 'AZEK' , 'BOXD' , 'STX' , 'BLNK' , 'AMLH' , 'GNRC' , 'BSBR' , 'JBL' , 'UUUU' , 'ALGN' , 'FOLD' , 'CRTD' , 'DV' , 'FRSH' , 'DOCS' , 'CNQ' , 'GD' , 'WELL' , 'NDAQ' , 'VIV' , 'CYBN' , 'MMTIF' , 'HENOY' , 'TPX' , 'RYCEY' , 'BRBR' , 'EH' , 'HIVE' , 'MMC' , 'VRTX' , 'PCAR' , 'QFIN' , 'MMP' , 'TER' , 'WSC' , 'ABB' , 'FRC' , 'ENTG' , 'LKQ' , 'GNUS' , 'DINO' , 'TT' , 'DADA' , 'AON' , 'CCK' , 'ETWO' , 'SM' , 'OMF' , 'OTIS' , 'TU' , 'BRMK' , 'SSNC' , 'ENSC' , 'LXP' , 'DRH' , 'STNG' , 'VRNS' , 'SKIN' , 'BBWI' , 'HMNY' , 'KATX' , 'ACI' , 'J' , 'EAT' , 'MAC' , 'SPGI' , 'FANG' , 'HRB' , 'ATAI' , 'EZPW' , 'EVRG' , 'SQM' , 'HP' , 'SMAR' , 'INVZ' , 'AVTBF' , 'OLN' , 'SYK' , 'BORR' , 'CRON' , 'ACM' , 'CADE' , 'GPN' , 'XRAY' , 'IRM' , 'TEF' , 'VRSK' , 'HUM' , 'RNG' , 'AJOY' , 'GMPR' , 'ZTO' , 'SCCO' , 'RADI' , 'TBLA' , 'NKTR' , 'OFC' , 'PNC' , 'ANF' , 'MAR' , 'HSY' , 'ABR' , 'ABC' , 'BERY' , 'RSG' , 'RXO' , 'RJF' , 'PGY' , 'GLG' , 'NAK' , 'MDCN' , 'SNPW' , 'PFG' , 'CPRI' , 'SCS' , 'ROL' , 'AYX' , 'REXR' , 'RES' , 'DBI' , 'CHS' , 'PRQR' , 'DVAX' , 'OZK' , 'BROS' , 'CUBE' , 'YUM' , 'MUR' , 'COLD' , 'DQ' , 'NULGF' , 'PRDL' , 'KC' , 'SRE' , 'BDPT' , 'RBNW' , 'BAH' , 'VSH' , 'CRDO' , 'STAB' , 'TTE' , 'WAL' , 'HYPR' , 'DO' , 'TTI' , 'BE' , 'REGN' , 'ALLR' , 'FOCS' , 'UGI' , 'TTCF' , 'MNSO' , 'SITC' , 'SBS' , 'INVA' , 'PACW' , 'INCY' , 'FTEG' , 'BBY' , 'BCE' , 'DTE' , 'DMYS' , 'ALK' , 'BNS' , 'LSXMA' , 'RDN' , 'NVTS' , 'VSCO' , 'NEXT' , 'AMWL' , 'WAB' , 'SMCI' , 'UL' , 'CELH' , 'QD' , 'SPG' , 'EURN' , 'NOC' , 'BMBL' , 'HMC' , 'WOOF' , 'MP' , 'GEGR' , 'PEB' , 'SIX' , 'CBD' , 'LNG' , 'WWW' , 'HRL' , 'OTTV' , 'VEEV' , 'OTEX' , 'RPRX' , 'UMPQ' , 'VET' , 'IFUS' , 'CMCLF' , 'ST' , 'CBOE' , 'XYL' , 'EHVVF' , 'COSM' , 'SDIG' , 'EDU' , 'BRLL' , 'NTAP' , 'NFE' , 'ADXN' , 'TRV' , 'TGNA' , 'PCTL' , 'RWT' , 'IFF' , 'SLG' , 'BTWN' , 'ZWS' , 'SOND' , 'CPT' , 'SBNY' , 'NE' , 'XPO' , 'DNMR' , 'MCK' , 'PDI' , 'RGA' , 'AWK' , 'DGX' , 'AFMD' , 'LYV' , 'HYLN' , 'RXRX' , 'APLS' , 'TETC' , 'FERG' , 'DUOL' , 'GETR' , 'CMPX' , 'FLWS' , 'LMT' , 'MRSN' , 'OCLG' , 'AME' , 'EDR' , 'NUWE' , 'ILST' , 'SBLK' , 'BJ' , 'IMUX' , 'LW' , 'WHSI' , 'MBC' , 'MWWC' , 'PGRE' , 'TMO' , 'MWA' , 'RKLYQ' , 'INDI' , 'PLTK' , 'GMBXF' , 'TGB' , 'LRCX' , 'OII' , 'CMC' , 'URBN' , 'GZIC' , 'PARR' , 'USEI' , 'BRO' , 'NFG' , 'ABCL' , 'GDRX' , 'TECH' , 'RXT' , 'IMVT' , 'HLT' , 'SBET' , 'SHC' , 'PFSI' , 'YOU' , 'EXMT' , 'UGP' , 'TXT' , 'HUBS' , 'VERU' , 'CSTM' , 'FIVN' , 'CD' , 'PDCE' , 'ASO' , 'VIRT' , 'EFC' , 'ACAD' , 'GSM' , 'EOSE' , 'CARG' , 'SAVE' , 'APLE' , 'UP' , 'ARI' , 'EMN' , 'ORMP' , 'KT' , 'ANZU' , 'GCAN' , 'FBP' , 'CNMD' , 'AEVA' , 'TDS' , 'HAIN' , 'LPG' , 'ALNY' , 'FROG' , 'CMA' , 'CNI' , 'DUTV' , 'RLJ' , 'SVM' , 'RELX' , 'BLK' , 'SNDR' , 'ALT' , 'ADSK' , 'LGF/A' , 'TREX' , 'MKC' , 'TRSI' , 'HIMX' , 'COLB' , 'BF/B' , 'CALX' , 'LULU' , 'TGI' , 'EGIO' , 'MAA' , 'SYNA' , 'DBGI' , 'SG' , 'AFOM' , 'CRF' , 'BXMT' , 'GXO' , 'HAS' , 'CPE' , 'PBI' , 'INMD' , 'SHMN' , 'SPKB' , 'CUZ' , 'OC' , 'VORB' , 'LPRO' , 'PL' , 'MGI' , 'ELV' , 'SXYAY' , 'MOMO' , 'SMG' , 'WTTR' , 'IXAQ' , 'IRBT' , 'ALB' , 'CRSP' , 'MIR' , 'AEHR' , 'GCI' , 'BG' , 'CDNS' , 'HTHT' , 'CEI' , 'FORG' , 'NBIX' , 'KBH' , 'DNB' , 'CBIO' , 'HFBG' , 'MTDR' , 'PALI' , 'LGF/B' , 'SEE' , 'NHHHF' , 'MGA' , 'OCLN' , 'ILMN' , 'SLGC' , 'TOL' , 'CXW' , 'ADAL' , 'VCSA' , 'CBRE' , 'AXL' , 'NYT' , 'HIPH' , 'RVSN' , 'ATO' , 'ECL' , 'GVA' , 'AJRD' , 'BFH' , 'BGCP' , 'ARES' , 'CHNC' , 'MGY' , 'IAUX' , 'EXPD' , 'PRVB' , 'RPD' , 'ALPP' , 'GFF' , 'MAXR' , 'GTOR' , 'HUN' , 'AIMC' , 'SGMO' , 'RHI' , 'PRDO' , 'BOX' , 'VGFCQ' , 'SAP' , 'LKCO' , 'SFM' , 'YETI' , 'TRGP' , 'GLDG' , 'DK' , 'PFGC' , 'HALB' , 'DLO' , 'COHR' , 'CXM' , 'CRBG' , 'BLMN' , 'SAVA' , 'AIHS' , 'KLAC' , 'HOPE' , 'FNF' , 'OTIC' , 'DOMA' , 'FBIN' , 'POWW' , 'ALLO' , 'LEA' , 'AVXL' , 'CLXT' , 'INN' , 'FONU' , 'CAKE' , 'NN' , 'ACVA' , 'FRTG' , 'BIGZ' , 'RVLV' , 'HLMN' , 'JQC' , 'POR' , 'VVPR' , 'FORZ' , 'FMC' , 'BMRN' , 'PNW' , 'AEG' , 'PSEC' , 'STZ' , 'AREB' , 'UPWK' , 'MPLN' , 'GRLT' , 'OPGN' , 'SONY' , 'MCO' , 'GMEV' , 'AKTS' , 'NVT' , 'NSC' , 'NG' , 'GGAL' , 'PRGO' , 'NTES' , 'FLR' , 'WBS' , 'LODE' , 'UCPA' , 'OGE' , 'APG' , 'HGV' , 'GROM' , 'FINV' , 'UNVR' , 'LTRY' , 'NTRS' , 'FVRR' , 'L' , 'FNMA' , 'WTRG' , 'OGN' , 'AGMRF' , 'EFX' , 'BEPC' , 'THC' , 'PUMP' , 'BAND' , 'ERJ' , 'TEX' , 'ECVT' , 'ALV' , 'MEOH' , 'ODFL' , 'PSN' , 'CTKB' , 'ETNB' , 'ERF' , 'ASML' , 'COLM' , 'EXPI' , 'BEAM' , 'CGEN' , 'AOIFF' , 'VMW' , 'LAZ' , 'BRGO' , 'ZIP' , 'GEO' , 'ZETA' , 'PPG' , 'QSR' , 'EFCRP' , 'MRTX' , 'SYNH' , 'DOMO' , 'HYZN' , 'OXLC' , 'ATNPQ' , 'VAL' , 'GLCC' , 'IVDA' , 'VUZI' , 'CYTK' , 'BGS' , 'EWBC' , 'WNC' , 'FAX' , 'SNV' , 'TNDM' , 'SHAK' , 'BKSY' , 'A' , 'SINT' , 'ADPT' , 'VINE' , 'JXN' , 'BC' , 'ICL' , 'KN' , 'XPRO' , 'JAGX' , 'PHUN' , 'JBGS' , 'IJJP' , 'NAVI' , 'OSCR' , 'NTNX' , 'IGT' , 'OLO' , 'DOV' , 'UWMC' , 'UVSE' , 'ADNT' , 'CDAY' , 'MDRX' , 'AAC' , 'FHB' , 'FTCI' , 'TW' , 'LEG' , 'WES' , 'SFLM' , 'GLBE' , 'YELL' , 'INSM' , 'NCNO' , 'SNCY' , 'BSM' , 'TSCO' , 'VERA' , 'PTC' , 'CPHI' , 'MOTNF' , 'LADR' , 'LCAA' , 'MKFG' , 'LIDR' , 'FWONK' , 'GOGO' , 'AOS' , 'GPRE' , 'ANGI' , 'USFD' , 'EB' , 'ZUO' , 'FYBR' , 'CDNA' , 'GNL' , 'SNPS' , 'CYN' , 'PALAF' , 'THRX' , 'EXR' , 'PI' , 'UTRS' , 'HCTI' , 'CIVI' , 'HCA' , 'AVB' , 'AWH' , 'BXRX' , 'HIW' , 'ENER' , 'DPRO' , 'EGY' , 'GWH' , 'HTGC' , 'SUMO' , 'BKI' , 'CFFN' , 'BIGC' , 'SJM' , 'TALO' , 'CMI' , 'SXC' , 'FCF' , 'KMPR' , 'LHX' , 'SATX' , 'AMKR' , 'VRRM' , 'FULT' , 'WB' , 'GTHX' , 'SBCF' , 'SOBR' , 'CCCC' , 'NEGG' , 'WINT' , 'ZION' , 'GNK' , 'HOMB' , 'TWNK' , 'GRNH' , 'DLOC' , 'BNL' , 'GMSQF' , 'CPA' , 'ALKS' , 'PDCO' , 'GLPI' , 'CVBF' , 'UATG' , 'IVR' , 'UNQL' , 'EVRI' , 'ELS' , 'SIVB' , 'PTY' , 'MMMM' , 'NEO' , 'BSY' , 'UE' , 'COOK' , 'MREO' , 'BLU' , 'BFCH' , 'NVSGF' , 'GENI' , 'DX' , 'SRUTF' , 'KRC' , 'CEQP' , 'TCRT' , 'TMHC' , 'RCKT' , 'RETA' , 'ARHS' , 'POST' , 'ESRT' , 'MNTV' , 'LEGN' , 'CEF' , 'IFXY' , 'DKS' , 'CVSI' , 'GGG' , 'FSK' , 'NMRK' , 'ORGN' , 'MLAI' , 'TIL' , 'AVIR' , 'BIG' , 'CALA' , 'MNDY' , 'AROC' , 'RL' , 'MONI' , 'INTR' , 'TDUP' , 'EPAM' , 'AJG' , 'BIOS' , 'NJR' , 'TXG' , 'KODK' , 'RBA' , 'AMN' , 'TROX' , 'VNET' , 'HQY' , 'MRC' , 'OWLT' , 'XXII' , 'NNN' , 'ENR' , 'CTMX' , 'HALO' , 'LEV' , 'WSM' , 'SPT' , 'NVRO' , 'VIR' , 'SELB' , 'VSTO' , 'PKG' , 'SVC' , 'ARNGF' , 'ASRT' , 'LRN' , 'CALM' , 'WRBY' , 'ZICX' , 'PWR' , 'CM' , 'RRX' , 'GPC' , 'TENB' , 'JEF' , 'SESN' , 'VBIV' , 'AGRX' , 'MXL' , 'DAN' , 'SLAB' , 'PLNT' , 'SMTC' , 'OBE' , 'OIG' , 'GRWG' , 'JELD' , 'RCUS' , 'OPAD' , 'NWS' , 'TXRH' , 'CNM' , 'RVNC' , 'ARQT' , 'GGN' , 'KLIC' , 'GRFS' , 'CHTR' , 'INBS' , 'OBSV' , 'LNTH' , 'CC' , 'BXSL' , 'OMI' , 'RTL' , 'TKR' , 'BHG' , 'AFMJF' , 'ARLP' , 'BHAT' , 'ULCC' , 'GL' , 'PRVA' , 'BKU' , 'AZTA' , 'WDH' , 'DEA' , 'FPAC' , 'HDSN' , 'SONG' , 'EQC' , 'IDXX' , 'TWOH' , 'MDCE' , 'SCPH' , 'AGCO' , 'PII' , 'ARAY' , 'SMR' , 'NWBI' , 'FTS' , 'TCBP' , 'ARCO' , 'SIGA' , 'SWTX' , 'BPMC' , 'PCT' , 'URG' , 'GSL' , 'LAUR' , 'HTGM' , 'XERS' , 'QNCX' , 'HNST' , 'NCR' , 'PTLO' , 'PEGR' , 'MFA' , 'IAC' , 'BLI' , 'SDGR' , 'DCPH' , 'COUR' , 'HSIC' , 'GETY' , 'LILAK' , 'ML' , 'PRMO' , 'EVH' , 'TPH' , 'WINR' , 'AVA' , 'EPR' , 'BIIB' , 'BARK' , 'QGEN' , 'MOD' , 'STAR' , 'NTLA' , 'WCN' , 'ATRA' , 'VIZC' , 'PGNY' , 'POOL' , 'NEP' , 'FMS' , 'CYXT' , 'ROP' , 'TLLTF' , 'EHC' , 'ALC' , 'FNVT' , 'SRPT' , 'ACRL' , 'G' , 'RACE' , 'RSKD' , 'BRY' , 'AKAM' , 'CUBI' , 'BOWL' , 'XALL' , 'MDU' , 'TRTX' , 'RELY' , 'TRVG' , 'UOVEY' , 'USA' , 'PLMI' , 'NXMR' , 'GLNCY' , 'FOUR' , 'QUOT' , 'MCRB' , 'ACHC' , 'WIX' , 'EIGR' , 'DLB' , 'ASTL' , 'TSHA' , 'WPC' , 'PKI' , 'FAMI' , 'RUM' , 'CWH' , 'RNW' , 'GOVX' , 'SWVLW' , 'GDDY' , 'ADTX' , 'MDXG' , 'MDC' , 'SHCR' , 'EVTL' , 'CHRS' , 'CTRE' , 'XHR' , 'STAG' , 'SAIA' , 'JBHT' , 'NVCR' , 'NEA' , 'ARW' , 'CDW' , 'HLGN' , 'GFL' , 'RENT' , 'SES' , 'SRC' , 'ASXC' , 'TIGR' , 'ZYXI' , 'DRI' , 'ASPS' , 'FFWM' , 'DAR' , 'CNO' , 'TIMB' , 'AVT' , 'SGML' , 'LCGMF' , 'TVTX' , 'QSI' , 'ESS' , 'BBBXF' , 'PPC' , 'RVMD' , 'GSAC' , 'SRG' , 'BZH' , 'BR' , 'NTCO' , 'SGLY' , 'ATVK' , 'PUK' , 'SNRY' , 'TOUR' , 'TSVT' , 'LCI' , 'FIBK' , 'NCTY' , 'RLAY' , 'ARE' , 'ILPT' , 'CCRN' , 'DECK' , 'LZ' , 'GRND' , 'NTDOY' , 'LIGA' , 'LASE' , 'GRSO' , 'WFRD' , 'SMRT' , 'ETD' , 'MKTX' , 'PSA' , 'LOVE' , 'AMPY' , 'LOGI' , 'HYFM' , 'KEYS' , 'OR' , 'FUUFF' , 'AAWW' , 'CE' , 'SKY' , 'VAPR' , 'ABUS' , 'GMNI' , 'HASI' , 'LITE' , 'ATIG' , 'KOPN' , 'NWPN' , 'LXU' , 'BHVN' , 'PINC' , 'BHIL' , 'CCV' , 'IDAI' , 'NUVA' , 'SKT' , 'GWRE' , 'XMTR' , 'KBR' , 'GRMN' , 'CMRX' , 'GDS' , 'TUP' , 'WBX' , 'IMBBY' , 'WMG' , 'ARIS' , 'RC' , 'MPWR' , 'FHI' , 'CDAK' , 'OLLI' , 'SUPV' , 'PCTY' , 'BVS' , 'ASC' , 'CNDT' , 'SHOO' , 'EBC' , 'VSTM' , 'BSFC' , 'MCW' , 'KTOS' , 'GBDC' , 'LWLG' , 'FNA' , 'TRMB' , 'CINF' , 'EHTH' , 'NWBO' , 'METX' , 'IQV' , 'FUL' , 'AXNX' , 'LTH' , 'CTXR' , 'ZYME' , 'SLS' , 'VGR' , 'CIDM' , 'API' , 'DXF' , 'ARNC' , 'ALLE' , 'PCRX' , 'AN' , 'PIRS' , 'HILS' , 'RYN' , 'SKYI' , 'UNRV' , 'HWNI' , 'SMPL' , 'OCUL' , 'CRSR' , 'SPIR' , 'ENLAY' , 'ATEN' , 'ACLS' , 'CGNX' , 'NARI' , 'PDM' , 'DCP' , 'WPRT' , 'OPCH' , 'MEIP' , 'NTRA' , 'CRC' , 'EVR' , 'NGL' , 'SNCE' , 'PTCT' , 'PLAY' , 'XFOR' , 'WISA' , 'MRES' , 'TUYA' , 'SLI' , 'SEDG' , 'MRVI' , 'SIGI' , 'DOX' , 'BSAC' , 'ORC' , 'EMBC' , 'MFG' , 'INCC' , 'CCEP' , 'AUD' , 'KAR' , 'LMDX' , 'MD' , 'MANH' , 'MLKN' , 'SPRU' , 'VNT' , 'HZO' , 'PTGX' , 'AMLX' , 'FLYW' , 'OSW' , 'OWUV' , 'CDLX' , 'REG' , 'IMO' , 'INSW' , 'ATHM' , 'ASPN' , 'SSTK' , 'SANA' , 'BZUN' , 'ICLR' , 'NCZ' , 'SGEN' , 'SBAC' , 'URI' , 'DNOW' , 'REZI' , 'DRS' , 'ACRE' , 'KYMR' , 'FSTX' , 'NRGV' , 'PRAX' , 'AEMD' , 'NMR' , 'EBS' , 'DOLLF' , 'MDMN' , 'RCRUY' , 'MSTR' , 'FRT' , 'SCI' , 'PLYA' , 'DXLG' , 'GNLN' , 'ALEC' , 'RH' , 'UNCY' , 'VRE' , 'SFNC' , 'LECO' , 'LPX' , 'HWC' , 'UIS' , 'LQDA' , 'BURL' , 'VRAY' , 'PBA' , 'ENVA' , 'OGS' , 'NIU' , 'ORGO' , 'VIEW' , 'WHR' , 'MNTS' , 'ASH' , 'KNSA' , 'LIVN' , 'GIII' , 'MIGI' , 'MAG' , 'MTZ' , 'ARWR' , 'TDW' , 'GTN' , 'WCC' , 'ICNC' , 'GLOP' , 'FNMAS' , 'PPJE' , 'CWEN' , 'ADEA' , 'CRI' , 'WETG' , 'CORT' , 'SGRY' , 'RMTI' , 'ITGR' , 'AELpB' , 'LDI' , 'CFR' , 'TDC' , 'TGIDW' , 'FRPT' , 'XNCR' , 'WDS' , 'HXL' , 'MMYT' , 'ORAN' , 'CSIQ' , 'FAF' , 'ACIW' , 'PRG' , 'KMT' , 'CNET' , 'ATCX' , 'MYGN' , 'SOLO' , 'AIV' , 'APLD' , 'IEX' , 'GO' , 'CBSH' , 'GLDD' , 'UROY' , 'UBSI' , 'STR' , 'WH' , 'CCTL' , 'ZNOG' , 'NSTG' , 'QBTS/WS' , 'NLST' , 'EPRT' , 'PRMW' , 'ZLAB' , 'EVTC' , 'AVY' , 'VNDA' , 'LBRDK' , 'ITI' , 'IONS' , 'IRDM' , 'SLQT' , 'JBI' , 'ROIC' , 'NVG' , 'LUNG' , 'SLCA' , 'TCN' , 'RY' , 'SEAS' , 'MSI' , 'AMTX' , 'CAL' , 'PRO' , 'AVTA' , 'MTSI' , 'SUM' , 'HLLY' , 'GLNG' , 'GSBD' , 'MIDD' , 'NWGC' , 'OGI' , 'VTMXF' , 'SWIM' , 'ASM' , 'ACCD' , 'SIG' , 'AAP' , 'TRX' , 'EFTR' , 'UCBI' , 'ZG' , 'ATEC' , 'BRCC' , 'ALTO' , 'SDRC' , 'WTW' , 'PRM' , 'HUBG' , 'QMCO' , 'RNAZ' , 'BIOL' , 'AMPL' , 'RYAM' , 'NEWR' , 'GAME' , 'ITCI' , 'IHICY' , 'GIL' , 'MGNX' , 'ARLO' , 'NEEpQ' , 'RLLCF' , 'CNXA' , 'DNP' , 'SLF' , 'LYEL' , 'GOF' , 'BCLI' , 'CHKP' , 'SHFS' , 'AIRC' , 'VTLE' , 'RUBY' , 'VERV' , 'AMP' , 'PERI' , 'NBSE' , 'IVVD' , 'VYGR' , 'NSA' , 'TTC' , 'CYIO' , 'NGM' , 'NVVE' , 'HYT' , 'HEPA' , 'APLT' , 'HARP' , 'MELI' , 'DSL' , 'OSK' , 'BRKL' , 'QLYS' , 'YELP' , 'AXS' , 'LX' , 'SKM' , 'HCAT' , 'STGW' , 'VCYT' , 'OTRK' , 'ARDS' , 'PVH' , 'FNV' , 'TRUP' , 'MKSI' , 'PLXP' , 'ATKR' , 'TNL' , 'NR' , 'KURA' , 'FTDR' , 'TLOFF' , 'VYNT' , 'SUPN' , 'FFIV' , 'HEPS' , 'ZVZZT' , 'NUS' , 'GSVRF' , 'EXFY' , 'OCSL' , 'EXG' , 'INSG' , 'AHCO' , 'ABSI' , 'SEER' , 'TK' , 'CLS' , 'SF' , 'LL' , 'WDOFF' , 'ACLX' , 'PBYI' , 'ANLDF' , 'ALSN' , 'AEL' , 'PYCR' , 'LTCH' , 'CVAC' , 'PFS' , 'RMD' , 'NAD' , 'POL' , 'IMMX' , 'APHLF' , 'ATOS' , 'ROK' , 'AX' , 'BGRY' , 'RAMP' , 'RRGB' , 'DTM' , 'HROW' , 'PLAB' , 'JKS' , 'ACMR' , 'IZEA' , 'FNICF' , 'CRDF' , 'PNFP' , 'LLAP' , 'NUGN' , 'SNDX' , 'DDL' , 'TLS' , 'AUVI' , 'FGEN' , 'TBLT' , 'ELME' , 'COGT' , 'CBAY' , 'PRTS' , 'FLS' , 'PB' , 'SUN' , 'PDO' , 'VMC' , 'GTVH' , 'GXXM' , 'ATHX' , 'DHF' , 'FLNG' , 'LNW' , 'NEWH' , 'KDNY' , 'MGOL' , 'SNN' , 'ABCB' , 'PPBI' , 'CVI' , 'ECAT' , 'SJR' , 'DH' , 'ABBRF' , 'PCOR' , 'UNFI' , 'LRSV' , 'DNLI' , 'CDXS' , 'OABI' , 'AGR' , 'SQSP' , 'UHS' , 'SYAXF' , 'LDOS' , 'DEN' , 'APYP' , 'RCII' , 'MAPS' , 'VAQC' , 'DNCVF' , 'BHR' , 'AFFU' , 'GMRE' , 'ALBO' , 'SFL' , 'BTAI' , 'CEIX' , 'CRH' , 'QURE' , 'ADCT' , 'FDFT' , 'LHCG' , 'MTH' , 'HSC' , 'GRPN' , 'MTX' , 'NBIO' , 'UAVS' , 'GBCI' , 'BLIS' , 'GAHC' , 'RNA' , 'NSIT' , 'AVNT' , 'BLLB' , 'CERT' , 'INT' , 'MXCT' , 'ADYEY' , 'ALHC' , 'CEMI' , 'NEPT' , 'RS' , 'FTAI' , 'BL' , 'SLNH' , 'CFRUY' , 'PRTA' , 'NVSEF' , 'UTHR' , 'WPCB' , 'LGBI' , 'MANU' , 'HEXO' , 'BANC' , 'ZBRA' , 'RPM' , 'FSRDQ' , 'NRBO' , 'WTFC' , 'VRSN' , 'H' , 'AMTI' , 'ASAP' , 'APAM' , 'USAS' , 'FIVE' , 'BOOT' , 'FREQ' , 'CYBR' , 'WLK' , 'MSCI' , 'BLCO' , 'SPB' , 'CGNT' , 'ADMP' , 'TRI' , 'VVNT' , 'FUV' , 'CABA' , 'KEX' , 'CNTX' , 'STKL' , 'DSX' , 'RRR' , 'YY' , 'FLT' , 'OIS' , 'OCEL' , 'AGIO' , 'SWISF' , 'GLOB' , 'PWSC' , 'ARCB' , 'NNOX' , 'GTY' , 'CRNC' , 'DWAC' , 'KSCP' , 'ALKT' , 'TAC' , 'LH' , 'CAR' , 'CYCA' , 'ARVN' , 'CRIS' , 'HUBB' , 'FSP' , 'SANM' , 'MC' , 'HTLD' , 'PRGS' , 'PCVX' , 'INM' , 'OCGSF' , 'MRTN' , 'TFX' , 'AMLI' , 'TRNO' , 'TRN' , 'AREC' , 'DNUT' , 'FXLV' , 'DENN' , 'MRIN' , 'PEGA' , 'TCBI' , 'OTMOW' , 'VITX' , 'ATIP' , 'TOVX' , 'HDUP' , 'PHK' , 'FULC' , 'TTMI' , 'MRNS' , 'JSAIY' , 'EYE' , 'AMPS' , 'MUSA' , 'FORM' , 'RGLD' , 'MGMLF' , 'FFMGF' , 'VSAT' , 'BAP' , 'TX' , 'STE' , 'WST' , 'SUNW' , 'LSI' , 'GWW' , 'QNRX' , 'COLL' , 'SB' , 'IHRT' , 'SJT' , 'ABG' , 'HCSG' , 'DSHK' , 'SRUUF' , 'CEPU' , 'RPT' , 'ABCM' , 'BRSP' , 'INUV' , 'AXON' , 'LGHL' , 'ECC' , 'CAAS' , 'IGD' , 'PWP' , 'OM' , 'THO' , 'AIT' , 'NOMD' , 'DTIL' , 'PLG' , 'AMV' , 'BRKR' , 'REE' , 'NXST' , 'DSGT' , 'CNHC' , 'WGO' , 'DOUG' , 'OP' , 'CRTG' , 'STEK' , 'MOH' , 'HOKCF' , 'VTYX' , 'WPUR' , 'WERN' , 'RECAF' , 'FFIN' , 'IEP' , 'STAA' , 'PAG' , 'BHF' , 'ADTN' , 'KROS' , 'PSWW' , 'CDMO' , 'QGSI' , 'DOLE' , 'ESNT' , 'GTLS' , 'SON' , 'GROY' , 'PRPL' , 'ICPT' , 'THCH' , 'STRE' , 'VBLT' , 'PNT' , 'SLGN' , 'SEDA' , 'SNX' , 'DVA' , 'NKTX' , 'NMIH' , 'CVLT' , 'BLFS' , 'CMRE' , 'ENDPQ' , 'SEM' , 'BTB' , 'BZWR' , 'JKHY' , 'MCY' , 'CPTK' , 'COOP' , 'RPAY' , 'GMED' , 'AGRO' , 'UNVC' , 'BGFV' , 'STRC' , 'HSPO' , 'ITT' , 'MHK' , 'TXHG' , 'AY' , 'AKR' , 'HCC' , 'CAJ' , 'COWN' , 'KIOr' , 'CRS' , 'BBAR' , 'XAIR' , 'CECO' , 'PRME' , 'FMX' , 'AXLA' , 'FPI' , 'OMCL' , 'BIOR' , 'EXAI' , 'BAK' , 'CHEF' , 'OEC' , 'PSO' , 'ZIMV' , 'ATGE' , 'WRIT' , 'HESM' , 'ZVSA' , 'VREX' , 'YOTA' , 'SBGI' , 'DAWN' , 'NAC' , 'KZR' , 'WARM' , 'ADN' , 'SLAM' , 'TRCK' , 'BSTZ' , 'NTCT' , 'FNKO' , 'PSTX' , 'SMFL' , 'MNMD' , 'GTES' , 'FARO' , 'BODY' , 'TSEM' , 'BCAT' , 'WAFD' , 'AFG' , 'EQIX' , 'ONCR' , 'VRNA' , 'NWE' , 'NAPA' , 'PFN' , 'HRMY' , 'RELI' , 'EVLV' , 'PLRX' , 'FBIO' , 'TNYA' , 'BTZI' , 'WHD' , 'AUMN' , 'MAIFF' , 'GKOS' , 'VQS' , 'ALLK' , 'PUBM' , 'CINC' , 'PVCT' , 'CIB' , 'VAC' , 'MSM' , 'FCPT' , 'ROG' , 'CHRD' , 'MRCY' , 'PONO' , 'NS' , 'PZZA' , 'CBT' , 'VXTRF' , 'LFST' , 'NUV' , 'AUTL' , 'DCGO' , 'RYAAY' , 'SPGYF' , 'CARS' , 'SSB' , 'CLSD' , 'CRL' , 'BIP' , 'GMDA' , 'PHNMF' , 'WING' , 'GPMT' , 'BUSE' , 'SPNT' , 'CBYI' , 'GMAB' , 'ODP' , 'BKE' , 'ONL' , 'KERN' , 'FLME' , 'EVA' , 'HLI' , 'ACCO' , 'GAB' , 'AMBC' , 'POWI' , 'VZIO' , 'DRVN' , 'IMAX' , 'PBH' , 'TRLEF' , 'FSCO' , 'NXGN' , 'JAZZ' , 'DRD' , 'CRYBF' , 'IT' , 'MASI' , 'GDYN' , 'SWBI' , 'HAE' , 'MHO' , 'ACET' , 'PNM' , 'OSUR' , 'KW' , 'SAGE' , 'TWI' , 'BLEG' , 'CTAS' , 'SPRO' , 'RSI' , 'FRGE' , 'SA' , 'ENSG' , 'RKDA' , 'IPOOF' , 'CELU' , 'SEIC' , 'VMSI' , 'SCVL' , 'GRTS' , 'IMAB' , 'TRUE' , 'TTEK' , 'RVT' , 'LAMR' , 'QDEL' , 'CYRX' , 'EMBK' , 'GXRFF' , 'CARA' , 'DPZ' , 'MTCR' , 'FFBC' , 'BPOP' , 'RYAN' , 'CULTF' , 'TSPG' , 'TOPS' , 'BRP' , 'MERC' , 'TPIC' , 'JNCE' , 'IDYA' , 'VCEL' , 'ORLY' , 'CUEN' , 'MIRM' , 'EVER' , 'PAYC' , 'GEMSF' , 'CRGE' , 'MICT' , 'PAR' , 'DSEY' , 'CSL' , 'ZGN' , 'CAPV' , 'EVC' , 'EHAB' , 'CCS' , 'BMO' , 'KRON' , 'WSFS' , 'CCCS' , 'MBI' , 'GATO' , 'RAREF' , 'SHPW' , 'SLVM' , 'INFI' , 'ZGN/WS' , 'IRTC' , 'GLYC' , 'VWE' , 'LZB' , 'CNNWQ' , 'SWAV' , 'SING' , 'BNTX' , 'NCV' , 'AVPT' , 'SNBR' , 'RARE' , 'SOL' , 'CWAN' , 'NIOBF' , 'KRP' , 'OPTN' , 'BALY' , 'INBX' , 'PLCE' , 'VBTX' , 'SGH' , 'ANSS' , 'ESMT' , 'BFAM' , 'BV' , 'STAL' , 'JPEX' , 'SBEV' , 'ZYNE' , 'DTC' , 'WTII' , 'NTST' , 'EJH' , 'ZD' , 'IART' , 'AER' , 'LQMT' , 'EBML' , 'OPI' , 'CYRN' , 'TSE' , 'MBGYY' , 'POAI' , 'RYTM' , 'KUASF' , 'HELE' , 'SVRA' , 'STRO' , 'NERV' , 'TRTN' , 'CNCT' , 'HTLF' , 'AIGpA' , 'RILY' , 'BWEN' , 'LSTR' , 'IGR' , 'DMTK' , 'HTH' , 'CRTO' , 'ARCT' , 'OMID' , 'BHE' , 'FLGT' , 'DLX' , 'RBOT' , 'BCYC' , 'GES' , 'SUI' , 'CRLBF' , 'AVRO' , 'CLAR' , 'HII' , 'NRIX' , 'FLXT' , 'SURF' , 'BPT' , 'AWP' , 'VRNT' , 'BMXI' , 'ELP' , 'ORKLF' , 'MATV' , 'ORKLY' , 'SEEL' , 'EXROF' , 'STIXW' , 'KNOP' , 'DCRD' , 'CLH' , 'LRLCY' , 'HEI' , 'NRDS' , 'FSS' , 'DSKE' , 'LTC' , 'TGOPY' , 'TMST' , 'AMED' , 'MESA' , 'CRBU' , 'HSDT' , 'HE' , 'KRNY' , 'SD' , 'AMCX' , 'PECO' , 'VRDN' , 'ADV' , 'BKH' , 'BIPC' , 'VNOM' , 'ZNTL' , 'EQMEF' , 'OODH' , 'MEGL' , 'ONCY' , 'PCH' , 'AIRS' , 'SRZN' , 'OTMO' , 'SIpA' , 'SR' , 'DRRSF' , 'MAIN' , 'RSNVF' , 'BLDE' , 'MUX' , 'CGEM' , 'AMG' , 'PDSB' , 'NREG' , 'MYO' , 'METC' , 'RGEN' , 'PACK' , 'PALT' , 'MAN' , 'DCI' , 'LPTX' , 'AQMS' , 'GOMRF' , 'KOOYF' , 'VECO' , 'ALGT' , 'PMVP' , 'THG' , 'CHKKF' , 'ALEAF' , 'RNR' , 'TBBK' , 'TH' , 'MLYF' , 'BGNE' , 'ATNF' , 'ISNPY' , 'DROOF' , 'CLDX' , 'AOSL' , 'BFRI' , 'IDVV' , 'GRBK' , 'YJ' , 'DY' , 'BSXGF' , 'SRCL' , 'SNCR' , 'AGO' , 'JPS' , 'AHT' , 'EMKR' , 'BBN' , 'AGAC' , 'EPC' , 'BOXL' , 'FMCC' , 'HTBK' , 'TRMK' , 'HI' , 'INZY' , 'NZF' , 'BJRI' , 'WEX' , 'BMEZ' , 'GLPG' , 'DICE' , 'RUTH' , 'CDZI' , 'PODD' , 'WVE' , 'PTOI' , 'AKRO' , 'ULTA' , 'PFLT' , 'RA' , 'TSLX' , 'WABC' , 'LCII' , 'YCRM' , 'ORA' , 'ALEX' , 'FDMT' , 'OBNNF' , 'PETS' , 'DRQ' , 'AURI' , 'DEO' , 'KTB' , 'STRY' , 'AXDX' , 'MNRO' , 'DRCT' , 'MMSI' , 'EBIX' , 'MLI' , 'KREF' , 'CDXC' , 'EMAN' , 'TKC' , 'TNP' , 'PFTAU' , 'VAXX' , 'OXUSW' , 'BRZE' , 'EVBG' , 'LII' , 'UMBF' , 'TFII' , 'AMAM' , 'IGIC' , 'HFRO' , 'LCTX' , 'CLB' , 'DRMA' , 'CMP' , 'THRM' , 'XERI' , 'MODN' , 'BBDC' , 'KNOS' , 'NOTV' , 'RDGL' , 'ISR' , 'LQDT' , 'BLRX' , 'RGNX' , 'SYM' , 'VIST' , 'SITM' , 'CPTN' , 'VASO' , 'APPN' , 'INGR' , 'GLCNF' , 'PLL' , 'BUR' , 'LGIH' , 'IVCB' , 'SLVTF' , 'FORW' , 'NHYKF' , 'ENZ' , 'PGTI' , 'LOMLF' , 'WLBMF' , 'OLYMY' , 'CATY' , 'FOSL' , 'EVOP' , 'CNDB/WS' , 'KYN' , 'VISL' , 'OFIX' , 'USBpH' , 'GLT' , 'LLKKF' , 'PHR' , 'AWF' , 'GEL' , 'PRTDF' , 'ARAV' , 'OSG' , 'RXDX' , 'UFPI' , 'BMA' , 'AGFY' , 'BAER' , 'CSII' , 'SKIL' , 'PRLB' , 'GCXXF' , 'PHOT' , 'TMDI' , 'PEAR' , 'POAHY' , 'APCX' , 'NOTE' , 'AAGFF' , 'ENOV' , 'THR' , 'FMNJ' , 'EGP' , 'SRTS' , 'TNK' , 'DNAB' , 'AAT' , 'ACDC' , 'MYMD' , 'LAD' , 'KPLT' , 'VSST' , 'NBXG' , 'CCOI' , 'ECPG' , 'OPTT' , 'REKR' , 'BGTTF' , 'ASMB' , 'GORO' , 'AUB' , 'ASCK' , 'RBBN' , 'DESP' , 'NJDCY' , 'ONEW' , 'CUTR' , 'TBPH' , 'DANOY' , 'TYL' , 'ABM' , 'VRAR' , 'BHLB' , 'PIII' , 'PRKR' , 'ADAP' , 'BASFY' , 'IDCBF' , 'FBNC' , 'THS' , 'NML' , 'VLRS' , 'WNFT' , 'AHH' , 'NETI' , 'EMED' , 'BDSX' , 'BECN' , 'EVV' , 'MATX' , 'NMZ' , 'CMG' , 'BABL' , 'EXPO' , 'CTSO' , 'LCAAU' , 'RECHF' , 'PQEFF' , 'ALTR' , 'JUSHF' , 'TREE' , 'IBIO' , 'WK' , 'PSTV' , 'FCFS' , 'QNGYQ' , 'BRAV' , 'AWI' , 'DSGN' , 'AVCTQ' , 'LFLY' , 'EPAC' , 'MYMX' , 'AMBA' , 'CERE' , 'MLGO' , 'CTOS' , 'QNST' , 'ODYY' , 'ALE' , 'MYHI' , 'SNWV' , 'CATV' , 'NSSC' , 'CNSL' , 'FREE' , 'DGII' , 'PSFE' , 'CBU' , 'VTS' , 'LAW' , 'E' , 'AIZ' , 'PAXS' , 'ZUMZ' , 'MCS' , 'FUN' , 'SBFM' , 'TMDX' , 'ROVR' , 'TNET' , 'GRPS' , 'DHY' , 'KORE' , 'VNTA' , 'FUNN' , 'CBTTF' , 'RHP' , 'AL' , 'IAALF' , 'SITE' , 'SXTC' , 'GPRK' , 'DCRDW' , 'AVAH' , 'NNRI' , 'ENV' , 'GDV' , 'EYEN' , 'ZENV' , 'ONDS' , 'EXP' , 'SSYS' , 'BNED' , 'HT' , 'AMTD' , 'RKTA' , 'ATHA' , 'CTHR' , 'TRMD' , 'BSIG' , 'DSVSF' , 'KRNT' , 'NTOIY' , 'FN' , 'MDGL' , 'IMXI' , 'PTAM' , 'FA' , 'ZTR' , 'GMER' , 'BKNG' , 'CSWC' , 'SJW' , 'VTEX' , 'BCAB' , 'RPTX' , 'PATK' , 'FOLGF' , 'RAPT' , 'EOLS' , 'NBHC' , 'SNMP' , 'THRY' , 'EPM' , 'INFA' , 'AVNS' , 'GRFX' , 'AB' , 'FRXB' , 'PUGE' , 'UCTT' , 'ATR' , 'SILK' , 'STEP' , 'TALS' , 'ORIC' , 'MYPS' , 'VC' , 'MMNGF' , 'FSRX' , 'CVRX' , 'IGC' , 'SNA' , 'CRGY' , 'IIPR' , 'ADNWW' , 'MCG' , 'TILE' , 'LABP' , 'GTBIF' , 'OSI/WS' , 'ROCC' , 'ETW' , 'GDOT' , 'MYOV' , 'VERX' , 'PFMT' , 'GZDIF' , 'KIII' , 'ACGBF' , 'HIBB' , 'APDN' , 'FAZEW' , 'UTG' , 'ARRWU' , 'CRMD' , 'NHAWF' , 'NGVT' , 'JPC' , 'PRA' , 'PAVM' , 'CASY' , 'SILO' , 'NKGFF' , 'ALZN' , 'BDJ' , 'VERO' , 'CLVSQ' , 'HRI' , 'VSOLF' , 'LXRX' , 'SCHN' , 'AQB' , 'NUVB' , 'NRDY/WS' , 'MBCN' , 'NUGS' , 'ETJ' , 'JRVMF' , 'IDA' , 'TPII' , 'REYN' , 'TBI' , 'PAM' , 'UDMY' , 'MITQ' , 'MLM' , 'FWBI' , 'SEAC' , 'YAMCY' , 'VICR' , 'ORLA' , 'ETY' , 'OLED' , 'ETV' , 'IONM' , 'ADVM' , 'COOLW' , 'EVCM' , 'QTRX' , 'IVT' , 'HTDS' , 'LTRPA' , 'NLS' , 'TWKS' , 'GBIO' , 'MYD' , 'MATH' , 'JOB' , 'APTO' , 'NGMC' , 'TPB' , 'RNST' , 'HERA' , 'EWCZ' , 'LIAN' , 'WOW' , 'FDCFF' , 'LGAC' , 'NABL' , 'KNTK' , 'SSP' , 'CTS' , 'VLN' , 'ITOS' , 'ALDX' , 'BIOAF' , 'WWD' , 'ASGN' , 'VIVE' , 'SLRC' , 'IE' , 'CRNX' , 'B' , 'VRA' , 'ADX' , 'STXS' , 'TGH' , 'SHPW/WS' , 'SPWH' , 'EME' , 'NGG' , 'MTNB' , 'CISO' , 'NDMO' , 'AOD' , 'CIO' , 'KNW' , 'OTLK' , 'NVGLF' , 'COO' , 'CVT' , 'WIRE' , 'TDG' , 'ATMC' , 'GBX' , 'LAB' , 'GPI' , 'BWXT' , 'ARBK' , 'BEP' , 'CNNE' , 'ASG' , 'CW' , 'DROP' , 'IQST' , 'FWONA' , 'CWT' , 'BBKCF' , 'PHGE' , 'CPMD' , 'GAN' , 'XOS' , 'KFY' , 'VZLA' , 'AAN' , 'USM' , 'MEDS' , 'UAMY' , 'DAKT' , 'MNTK' , 'OLK' , 'IDCC' , 'CUE' , 'UTZ' , 'SBOW' , 'HHC' , 'ANDD' , 'NHI' , 'AMRC' , 'UHAL' , 'SPOM' , 'GSMG' , 'TRTL' , 'IBTX' , 'CR' , 'BYDDY' , 'CBRL' , 'KULR' , 'STBA' , 'MMV' , 'SAFE' , 'EAWD' , 'TWNI' , 'OCX' , 'QTWO' , 'EPAZ' , 'GNPX' , 'VLON' , 'HMN' , 'NSPT' , 'INDB' , 'SAH' , 'NEWP' , 'TGS' , 'DGNU' , 'RQI' , 'OFG' , 'RTO' , 'PHRRF' , 'DAVA' , 'TCNNF' , 'ZONX' , 'MGCLF' , 'RCI' , 'WSO' , 'WEBR' , 'ATXI' , 'DIN' , 'OSBC' , 'EOCW/WS' , 'EU' , 'MMS' , 'SOPA' , 'COHU' , 'DGLY' , 'TM' , 'CSAN' , 'STIM' , 'XPER' , 'MHTX' , 'CWST' , 'MRAAY' , 'CGAU' , 'FIP' , 'RLMD' , 'STC' , 'JUPW' , 'UPLD' , 'TLGY' , 'TOP' , 'INGN' , 'FF' , 'BTCM' , 'FRME' , 'WWR' , 'HUDI' , 'BHK' , 'TCS' , 'MTN' , 'AAU' , 'BW' , 'ALRM' , 'AAGIY' , 'MVVYF' , 'ENIC' , 'BSXpA' , 'WMLLF' , 'HCANF' , 'LOPE' , 'GOLF' , 'THMO' , 'ANGO' , 'VYNE' , 'NBRI' , 'MTRX' , 'RE' , 'TRVN' , 'PTHRF' , 'TSI' , 'MLXEF' , 'AGTI' , 'LYLT' , 'FRG' , 'FBRT' , 'GTX' , 'BLBX' , 'SPTN' , 'CGTX' , 'HOLO' , 'WOR' , 'JACK' , 'MKTAY' , 'TOWN' , 'FRSX' , 'SCOR' , 'CVV' , 'ARCH' , 'BHLL' , 'ONTF' , 'IPSC' , 'VIRI' , 'OMER' , 'AVDL' , 'DFIN' , 'VYGVQ' , 'AIR' , 'NDSN' , 'AVAV' , 'LVRAW' , 'KXIN' , 'AZURF' , 'NNBR' , 'GTBP' , 'PML' , 'CRYM' , 'SFIO' , 'SJIJ' , 'BLKB' , 'ITRI' , 'XFLS' , 'BOOM' , 'CASA' , 'CATPF' , 'SNOA' , 'AXGN' , 'HEI/A' , 'TLTFF' , 'HRZN' , 'KVSC' , 'SEAT' , 'REPL' , 'IBP' , 'ENG' , 'BANR' , 'LOB' , 'HLTH' , 'AGLE' , 'EGBN' , 'LOMA' , 'PRRY' , 'UXIN' , 'ACRO' , 'PETQ' , 'ZAIRF' , 'SWVL' , 'ONTO' , 'CENTA' , 'FICVW' , 'STMH' , 'NMFC' , 'AEIS' , 'ERII' , 'MGUY' , 'IPIX' , 'GMS' , 'BDORY' , 'HGBL' , 'SLNO' , 'IFBD' , 'ADIL' , 'SWI' , 'INSP' , 'SQZ' , 'TR' , 'HGTY' , 'CURLF' , 'ATDS' , 'DLY' , 'XTNT' , 'UEEC' , 'PXLW' , 'KNSL' , 'BACHF' , 'AMR' , 'USX' , 'NWN' , 'KALV' , 'OCFC' , 'ASAI' , 'MTW' , 'MEDP' , 'LASR' , 'CMTG' , 'PHAT' , 'ASTC' , 'MMMB' , 'AQST' , 'AVID' , 'BCC' , 'CQP' , 'SDRL' , 'FTK' , 'SASR' , 'ZCTSF' , 'INTV' , 'SONN' , 'MTRN' , 'RGP' , 'XTRRF' , 'ALDS' , 'BKRRF' , 'TSCDY' , 'OB' , 'UBX' , 'UMH' , 'FELE' , 'AKLI' , 'NRT' , 'BNTC' , 'TPG' , 'HRTFF' , 'BRC' , 'KBLB' , 'ORTX' , 'TTOO' , 'KAII' , 'UHAL/B' , 'BEST' , 'GLUE' , 'BZFDW' , 'SSD' , 'ATNM' , 'MQY' , 'TFIN' , 'CBWTF' , 'ROOT' , 'SIBN' , 'GVXXF' , 'VRTV' , 'JRVR' , 'HBNC' , 'IMTX' , 'GLATF' , 'TUSK' , 'TBPMF' , 'VCTR' , 'GRNA' , 'NFBK' , 'WATT' , 'SIEN' , 'IRS' , 'JOE' , 'CHEK' , 'RCIT' , 'UCLE' , 'GIM' , 'HITI' , 'CMPS' , 'IFNNY' , 'AXTI' , 'AXREF' , 'HLYK' , 'FDS' , 'FDP' , 'VMO' , 'GRLF' , 'PESI' , 'KRTX' , 'CONN' , 'SWX' , 'BKCC' , 'GALT' , 'RDNT' , 'AMPH' , 'BLD' , 'ICAGY' , 'GP' , 'GULTU' , 'RVYL' , 'XPEL' , 'SSL' , 'YALA' , 'MLRKF' , 'CIK' , 'FOXF' , 'PEN' , 'ISPO' , 'TRUFF' , 'IMII' , 'BDC' , 'VOC' , 'APRU' , 'FICO' , 'GIB' , 'TCPC' , 'GOOD' , 'TMQ' , 'BTZ' , 'SACH' , 'LBAS' , 'EADSY' , 'CFB' , 'LAND' , 'XENE' , 'ACER' , 'NSP' , 'MORF' , 'FCN' , 'APTX' , 'TFSL' , 'CACC' , 'PNNT' , 'CGBD' , 'MJWL' , 'DUO' , 'ARGX' , 'ARRW' , 'FTF' , 'KUKE' , 'TREP' , 'VMGA' , 'IMH' , 'NRO' , 'WAT' , 'STKH' , 'CBZ' , 'SWRM' , 'IREN' , 'AGS' , 'LGDTF' , 'PLYM' , 'BHPLF' , 'ICU' , 'MOG/A' , 'DIOD' , 'CUBT' , 'KRKNF' , 'PRTK' , 'SGTB' , 'LIND' , 'CHJTF' , 'BTCWF' , 'INST' , 'PNGAY' , 'EVLO' , 'AORT' , 'MEGI' , 'SLGG' , 'NEEpR' , 'STRL' , 'NTGR' , 'BTGOF' , 'LOCO' , 'PLX' , 'TALK' , 'YMAB' , 'NFJ' , 'TEO' , 'SPRY' , 'CPF' , 'HFWA' , 'RMRDF' , 'GLP' , 'LVTTF' , 'PLYZ' , 'CNA' , 'EE' , 'PEV' , 'IDEXY' , 'APEI' , 'APYX' , 'IAS' , 'ANDE' , 'TG' , 'EEFT' , 'SVNLY' , 'GRIL' , 'BSGM' , 'ATSG' , 'BTCY' , 'R' , 'VLCN' , 'AZZTF' , 'FTFT' , 'NSL' , 'PSYC' , 'CLDT' , 'CLEU' , 'ICHR' , 'SIRE' , 'GSHD' , 'GAU' , 'ICVX' , 'SPH' , 'BTEGF' , 'NXP' , 'NAAS' , 'MITK' , 'LVO' , 'SHEN' , 'MRKR' , 'CREX' , 'ACA' , 'GPP' , 'ONTX' , 'TMCI' , 'MJNE' , 'PRAA' , 'INSE' , 'FWRG' , 'HEAR' , 'AAOI' , 'USAC' , 'PX' , 'DGHI' , 'RLI' , 'VGZ' , 'WEJO' , 'METpA' , 'SNWGF' , 'PAYS' , 'NSRGY' , 'EFSC' , 'ENTA' , 'BOE' , 'SCPL' , 'FNCH' , 'PLNHF' , 'HGTXU' , 'STIX' , 'MVF' , 'NEXCF' , 'CWBHF' , 'LUXFF' , 'FUNFF' , 'BST' , 'HNI' , 'ALXO' , 'LTUM' , 'HUMA' , 'IVCTF' , 'LRMR' , 'FSTTF' , 'SIOX' , 'ASLE' , 'BCO' , 'LVMUY' , 'SAIC' , 'PFL' , 'ELEK' , 'FANUY' , 'RCS' , 'NBTB' , 'EXLS' , 'RERE' , 'OTTR' , 'MCLD' , 'ACEL' , 'ATRC' , 'CBAT' , 'KKPNY' , 'AUID' , 'AYI' , 'TITN' , 'STEL' , 'SCLX' , 'WRN' , 'MEI' , 'PVL' , 'BCPC' , 'VNRX' , 'SUTI' , 'CCHWF' , 'SFBS' , 'UIHC' , 'REVB' , 'ALGS' , 'PJT' , 'WD' , 'CELZ' , 'BGY' , 'WEAV' , 'CASH' , 'LNSTY' , 'REPO' , 'HPCO' , 'TDY' , 'AMEH' , 'IPGP' , 'SPONF' , 'AREN' , 'PRFT' , 'ESAB' , 'KOD' , 'SNEX' , 'NEWDF' , 'SNWR' , 'GATX' , 'AWR' , 'AIN' , 'SRRK' , 'MMI' , 'IVAC' , 'BTCS' , 'LMLLF' , 'MUC' , 'CHH' , 'AMRK' , 'SSLZY' , 'IBOC' , 'APCA' , 'RFP' , 'VWAGY' , 'AFIB' , 'GHY' , 'JTBK' , 'DMTTF' , 'DOGZ' , 'CHMI' , 'HOV' , 'MAXN' , 'POL/WS' , 'BCX' , 'DTEGY' , 'VCXB/WS' , 'AVLNF' , 'CNTY' , 'LBAI' , 'JBSAY' , 'PBHG' , 'BOC' , 'HNRC' , 'SZSMF' , 'AKYA' , 'NEXI' , 'TIRX' , 'TPC' , 'CCU' , 'BMWYY' , 'GDEN' , 'PPT' , 'DHCA' , 'YGMZ' , 'BRSH' , 'IFBC' , 'VMD' , 'COCO' , 'TTSH' , 'GLS' , 'LUNA' , 'IMMR' , 'BGB' , 'ACT' , 'TSCDF' , 'CSGS' , 'PIPR' , 'FIX' , 'BLOZF' , 'PHYT' , 'BMI' , 'SCHL' , 'BBW' , 'BRLT' , 'LPL' , 'LKFN' , 'MTLS' , 'HEES' , 'CRSM' , 'CHW' , 'XWEL' , 'SPE' , 'SYRS' , 'AGXPF' , 'WSR' , 'SSKN' , 'HMST' , 'APXI' , 'PKX' , 'NGLOY' , 'DCOM' , 'DATS' , 'RGS' , 'SNGX' , 'HCM' , 'FCT' , 'STVN' , 'ONCT' , 'BASE' , 'AYRWF' , 'AGRI' , 'ATRO' , 'SURG' , 'CTV' , 'TNGX' , 'TNYBF' , 'TTGT' , 'ACP' , 'NMRD' , 'IPSI' , 'FAM' , 'RAAS' , 'BOKF' , 'USGDF' , 'LBRDA' , 'HIO' , 'JADA' , 'CHY' , 'STRA' , 'CWEN/A' , 'TPVG' , 'KAMN' , 'EMSKF' , 'UTF' , 'DOOR' , 'MED' , 'GTH' , 'PLXS' , 'CLVR' , 'PANL' , 'CODI' , 'ATAO' , 'BRNE' , 'SMSI' , 'ALSMY' , 'BLGO' , 'PSTL' , 'JKHCF' , 'DYN' , 'ICCM' , 'GBLX' , 'CETX' , 'PCN' , 'FDCT' , 'DUFRY' , 'MYE' , 'RVVTF' , 'NICE' , 'RPMT' , 'HOOK' , 'DBLVF' , 'HRT' , 'IHS' , 'TMMI' , 'SATS' , 'SCU' , 'PNTG' , 'SPSC' , 'PRIM' , 'SENR' , 'MKGP' , 'PBYA' , 'NOVT' , 'JLL' , 'CDSG' , 'UI' , 'RLAB' , 'ARYMF' , 'NRRMF' , 'PWRMF' , 'MX' , 'JBT' , 'DARE' , 'BKTPF' , 'LGACU' , 'JAMF' , 'INNI' , 'HNRG' , 'AMPG' , 'RMT' , 'UVSP' , 'AAON' , 'WLDS' , 'BASA' , 'DOCRF' , 'KIRK' , 'CACI' , 'FDUS' , 'SSFT' , 'GXII' , 'VXLLF' , 'CMCZ' , 'AZO' , 'RMCF' , 'IPAR' , 'CVGI' , 'PCYO' , 'LTMAY' , 'SPXC' , 'CBDY' , 'ALTG' , 'ENS' , 'RGLS' , 'BMAC' , 'CMPR' , 'UFI' , 'RMNI' , 'ATTO' , 'AMBO' , 'GLMD' , 'CLBK' , 'KELYA' , 'COFpI' , 'IMRA' , 'HTCR' , 'AHFD' , 'LDDFF' , 'ADES' , 'MGON' , 'GLGDF' , 'BCSF' , 'PRI' , 'SNPO' , 'AWLIF' , 'GELYF' , 'ASIX' , 'SMCAY' , 'VWAPY' , 'PSNYW' , 'NLTX' , 'FRZA' , 'SPI' , 'PT' , 'GWTI' , 'SGSVF' , 'VHNA' , 'FCGD' , 'ACLHF' , 'BMAC/WS' , 'AMTY' , 'NAOV' , 'JOAN' , 'WLY' , 'CII' , 'CTLP' , 'ANAB' , 'SMP' , 'ABEO' , 'SEMR' , 'BYSI' , 'WDI' , 'OPP' , 'EYPT' , 'GCEI' , 'GAXY' , 'RELL' , 'PWFL' , 'LANC' , 'IMV' , 'PFSW' , 'HLNE' , 'IFN' , 'BYDDF' , 'BOH' , 'MGDPF' , 'DSM' , 'XPOF' , 'OXM' , 'AXIM' , 'EFOI' , 'JZ' , 'SIMO' , 'ILAG' , 'VITL' , 'AVAL' , 'MATW' , 'LFUS' , 'KRYS' , 'EMD' , 'HHLA' , 'KIO' , 'MRMD' , 'MRUS' , 'SMWB' , 'GGR' , 'DTOCU' , 'FLL' , 'ADTH' , 'BCEL' , 'KNDI' , 'GRIN' , 'SCWO' , 'FACT' , 'ECOR' , 'CCAJ' , 'CTRN' , 'FWRD' , 'BDXB' , 'SCOB' , 'CNXC' , 'CAE' , 'RAIN' , 'DRCR' , 'BOXS' , 'HIX' , 'LGND' , 'CVCO' , 'JJM' , 'KTCC' , 'COEP' , 'CBRG' , 'CCSI' , 'SPOK' , 'CMLS' , 'AURC' , 'CNS' , 'TRIN' , 'VKI' , 'TASK' , 'AMYT' , 'ALVR' , 'DRUG' , 'UNCRY' , 'GOLXF' , 'ATOM' , 'PTOC' , 'KEP' , 'PDLB' , 'CURV' , 'KRUS' , 'PGEZF' , 'LYTS' , 'LGTO' , 'GLO' , 'MBIO' , 'SHPH' , 'PMX' , 'AERG' , 'PLMR' , 'KRO' , 'KDDIY' , 'LOCL' , 'NESR' , 'ICUI' , 'SLVRF' , 'MPNGY' , 'REVG' , 'TLK' , 'UVV' , 'TRDA' , 'BLBD' , 'CRRFY' , 'BTOG' , 'RNP' , 'HEP' , 'BRAXF' , 'ZFOX' , 'PDT' , 'MASS' , 'ATXG' , 'MUI' , 'SRI' , 'HGCPF' , 'GCT' , 'CYCN' , 'AGYS' , 'CURO' , 'FTCO' , 'OIIM' , 'CION' , 'SAM' , 'TIGO' , 'HAFC' , 'RUSHA' , 'RYI' , 'EVF' , 'CBMJ' , 'VSMR' , 'DSS' , 'STOK' , 'RDY' , 'NID' , 'CBNK' , 'JPMpK' , 'CBGZF' , 'CLNN' , 'STHFF' , 'ETG' , 'LTSRF' , 'FBK' , 'CAMP' , 'ACHL' , 'EHI' , 'WDFCF' , 'ALST' , 'AFYA' , 'DFH' , 'BXMX' , 'LOWLF' , 'JFR' , 'CNBX' , 'NVLHF' , 'MDVL' , 'WDRP' , 'QH' , 'REAX' , 'GLTA' , 'IMCR' , 'TRCTF' , 'MSEX' , 'MASN' , 'CIGI' , 'CVKD' , 'BKN' , 'NABZY' , 'FLFV' , 'KKRpC' , 'HSTM' , 'GPHOF' , 'SAPMY' , 'ASTI' , 'MBUU' , 'BNPQY' , 'TFPM' , 'SRAD' , 'NVDEF' , 'MDNWF' , 'UVE' , 'STSS' , 'EVGN' , 'BANF' , 'VRTS' , 'URGN' , 'SPRB' , 'SNPX' , 'EPIX' , 'CSQ' , 'MTA' , 'RCON' , 'DUOT' , 'DMO' , 'PEGY' , 'KMPH' , 'DDS' , 'DKILY' , 'CMAX' , 'DSU' , 'TTNDY' , 'CRCT' , 'KBAL' , 'JSDA' , 'CYTH' , 'EMX' , 'YVR' , 'ROCK' , 'NPCT' , 'UGDIF' , 'TLDE' , 'BNR' , 'WONDF' , 'NRK' , 'SBSI' , 'FLJ' , 'ATLKY' , 'CHDN' , 'GAIN' , 'DRIO' , 'LEO' , 'EVN' , 'RDW' , 'JJSF' , 'DPWW' , 'ARKO' , 'MVMDF' , 'ISCNF' , 'PRE' , 'VAYK' , 'CVVUF' , 'PPTA' , 'EVT' , 'FENC' , 'WFCpQ' , 'NVEI' , 'EOI' , 'MRRTY' , 'CNPOF' , 'SHOM' , 'MQBKY' , 'XFLT' , 'SKWD' , 'BGI' , 'BDRSF' , 'INTA' , 'XRTX' , 'IOSP' , 'GLAD' , 'OXSQ' , 'DAC' , 'WFCpZ' , 'FEAM' , 'PEBO' , 'HRTG' , 'BNY' , 'BCTX' , 'RBC' , 'RBT' , 'GMPW' , 'LYT' , 'OSPN' , 'HXGBY' , 'AEGY' , 'DHX' , 'MEG' , 'NRXP' , 'SKYT' , 'PUBGY' , 'BRZV' , 'FMCKJ' , 'NAUT' , 'AZPN' , 'OREAF' , 'STBX' , 'EQ' , 'CHKR' , 'FPOCF' , 'LITM' , 'REX' , 'OPRT' , 'VVI' , 'STRH' , 'LPCN' , 'HAYN' , 'JPMpL' , 'SNTI' , 'LVVV' , 'JPMpC' , 'CORS' , 'NBH' , 'EMO' , 'XTRAF' , 'IBGR' , 'HMENF' , 'GLTO' , 'ALBKY' , 'BCH' , 'SBGSY' , 'SXI' , 'CXBMF' , 'ALVLF' , 'CHI' , 'TOI' , 'PTXKY' , 'LTCN' , 'THRD' , 'AMSC' , 'CBL' , 'KTF' , 'ELECF' , 'BBLG' , 'PAHC' , 'PHT' , 'AOTVF' , 'TRVI' , 'AZZ' , 'ASPI' , 'AIO' , 'LILA' , 'MHD' , 'EGRX' , 'FURY' , 'TRST' , 'FPH' , 'RMAX' , 'URLOF' , 'RSPI' , 'GBRCF' , 'NOAH' , 'ROSS' , 'STSA' , 'DUSYF' , 'ADSV' , 'BIOF' , 'WFG' , 'CHCT' , 'IPI' , 'BCEKF' , 'SLTFF' , 'MGPI' , 'WASH' , 'EGLE' , 'NM' , 'BLE' , 'SHG' , 'HONE' , 'BHSIF' , 'CEQPp' , 'SYAAF' , 'ACOR' , 'FIZZ' , 'GPHBF' , 'DTMXF' , 'NYMX' , 'KOF' , 'CSWI' , 'TLYS' , 'IVH' , 'SCSC' , 'CURR' , 'AYRO' , 'LIZI' , 'GFGSF' , 'VRAX' , 'BRPHF' , 'TETOF' , 'MEDVF' , 'KFRC' , 'CNOB' , 'ASTE' , 'PFC' , 'ASND' , 'NCAUF' , 'BLFY' , 'TMRC' , 'MIN' , 'GENGF' , 'CSTL' , 'FGPHF' , 'JXJT' , 'ARDC' , 'MTD' , 'ITNS' , 'ALLpH' , 'NISN' , 'AMAL' , 'CPLP' , 'TIVC' , 'LTNC' , 'ACST' , 'IPAXW' , 'BAYZF' , 'FFIC' , 'ZVIA' , 'WSBC' , 'ANNX' , 'IMKTA' , 'CHUY' , 'CRNT' , 'IIM' , 'ALCUF' , 'DMGGF' , 'OGNRF' , 'SUNL' , 'MCFT' , 'PMEDF' , 'BBCP' , 'PSMT' , 'CMTL' , 'SUPGF' , 'BIVI' , 'TGLS' , 'ATWT' , 'XPL' , 'MKVNF' , 'AVD' , 'ATOXF' , 'PTALF' , 'STMEF' , 'VGM' , 'ACTG' , 'MFIC' , 'NVGS' , 'HNCKF' , 'CYCC' , 'CRZN' , 'GCO' , 'EWTX' , 'DRTT' , 'SOI' , 'IMBI' , 'MOV' , 'PTRVF' , 'AENZ' , 'NX' , 'NEVDF' , 'MFM' , 'BATRK' , 'KOP' , 'ATXS' , 'KB' , 'SXT' , 'LQAVF' , 'MCAA' , 'MIST' , 'PEXZF' , 'MHLD' , 'BOLT' , 'MYI' , 'AURA' , 'WNS' , 'NTTYY' , 'FG' , 'ALNAQ' , 'CMPO' , 'LPTH' , 'FMNB' , 'FLIC' , 'CNRIF' , 'NDLS' , 'HCMLY' , 'PDFS' , 'PRCT' , 'MSGS' , 'HOLI' , 'TWIN' , 'CESDF' , 'SYHBF' , 'FpD' , 'GRX' , 'RIV' , 'APRE' , 'BGH' , 'SHYF' , 'LFCR' , 'VRPX' , 'UCL' , 'USOI' , 'CAMT' , 'PROSY' , 'WEST' , 'GPOR' , 'APTVpA' , 'NMAI' , 'VMI' , 'NMCO' , 'NBR' , 'CPS' , 'GER' , 'USEA' , 'RGGI' , 'IIIV' , 'CHNR' , 'PCSV' , 'WRLD' , 'GMVD' , 'SSET' , 'JPMpJ' , 'OPRX' , 'NXDT' , 'REZZF' , 'HUGE' , 'GGSM' , 'FBMS' , 'HPK' , 'EGLX' , 'CYDVF' , 'EPSN' , 'IPNFF' , 'AMSWA' , 'VRNOF' , 'HURN' , 'KRTL' , 'NPO' , 'FRHC' , 'BRWXF' , 'TAMG' , 'CHT' , 'TEI' , 'PLTXF' , 'BJDX' , 'NWTN' , 'CPPMF' , 'AVNW' , 'PMETF' , 'GLQ' , 'PTUUF' , 'TXO' , 'KIDS' , 'KWIK' , 'IQI' , 'KLR' , 'JEWL' , 'DIBS' , 'MGAFF' , 'DC' , 'NUMIF' , 'APHP' , 'NXRT' , 'LTRX' , 'FCUUF' , 'LIPO' , 'SYFpA' , 'AFCG' , 'VIRX' , 'TKNO' , 'QQQX' , 'AUGX' , 'ZEUS' , 'GILT' , 'HWAUF' , 'LXFR' , 'JWEL' , 'VANI' , 'TIG' , 'DMLP' , 'DXPE' , 'WHF' , 'VKQ' , 'UBA' , 'WMMVY' , 'CRECF' , 'ATLX' , 'CODX' , 'ONCS' , 'USMT' , 'CRCW' , 'ITP' , 'KALU' , 'LBUY' , 'HSII' , 'NAVB' , 'IIIN' , 'PBT' , 'MRDB' , 'LMNR' , 'LIFE' , 'PXSAW' , 'WKME' , 'MDWD' , 'LCAAW' , 'DORM' , 'OPY' , 'STKS' , 'RCEL' , 'CHUC' , 'SRAX' , 'SAKL' , 'PFFOF' , 'KRRGF' , 'SSSS' , 'TLIS' , 'BOAC' , 'AMMPF' , 'MUA' , 'EIM' , 'NUSMF' , 'METpF' , 'PFIE' , 'TpC' , 'ACRX' , 'AAPT' , 'RMBL' , 'LEU' , 'ASLN' , 'NETC' , 'CURI' , 'DBTX' , 'GEF' , 'LANV/WS' , 'RWAY' , 'TFCpR' , 'MTC' , 'BSENF' , 'KBNT' , 'MGTX' , 'PIXY' , 'USDP' , 'BLAGF' , 'NRGX' , 'SPPP' , 'LIQT' , 'EWRC' , 'SST' , 'FVCB' , 'SLP' , 'CVSC' , 'BELFB' , 'SCL' , 'PRNDY' , 'TWOA' , 'JRNGF' , 'CMCO' , 'OBLG' , 'JRO' , 'CSV' , 'GUG' , 'IGMS' , 'KALA' , 'VENG' , 'BLSP' , 'VRCA' , 'GSpJ' , 'NVFY' , 'GASS' , 'CIBEY' , 'BACpP' , 'MGRC' , 'NVSA' , 'NRUC' , 'ISD' , 'USRM' , 'GNE' , 'QUMU' , 'PMM' , 'PWUP' , 'ARGO' , 'MODV' , 'KLXE' , 'MEIL' , 'URHG' , 'LXXGF' , 'IHG' , 'PASG' , 'ENSV' , 'BY' , 'GUT' , 'SENEA' , 'HLBZW' , 'BTT' , 'DUKpA' , 'ITRM' , 'MPVDF' , 'MARVF' , 'BRW' , 'III' , 'LOOP' , 'HSKA' , 'CpK' , 'SOVO' , 'OWCP' , 'GSQD' , 'AMPX' , 'NAN' , 'SGII' , 'ERDCF' , 'CJJD' , 'ANVS' , 'STRM' , 'ZURVY' , 'CURUF' , 'TOAC' , 'FPF' , 'SYPR' , 'CVII' , 'NXTTF' , 'BRDG' , 'ERO' , 'SPNS' , 'NDVAF' , 'MLYCF' , 'VVCIF' , 'BRZL' , 'IITSF' , 'MDNA' , 'RYES' , 'AMMJ' , 'SGHC' , 'JPMpM' , 'NEWT' , 'POWL' , 'BEHL' , 'NVCT' , 'NEON' , 'AFTTF' , 'PTVE' , 'BADEF' , 'CGOLF' , 'AMRZF' , 'PMO' , 'PHX' , 'DTEA' , 'NRPI' , 'AZRE' , 'YQ' , 'HYB' , 'CPK' , 'RDBBF' , 'BWC' , 'ADBN' , 'GPFT' , 'PBPB' , 'YI' , 'PED' , 'CLGCF' , 'SBR' , 'SPEYF' , 'GCMG' , 'DFMTF' , 'ITHUF' , 'BACpM' , 'SEUSF' , 'PGC' , 'FLUX' , 'HQL' , 'CATC' , 'KONEF' , 'BCOV' , 'BEWFF' , 'RGR' , 'HHS' , 'ABMC' , 'UUSAF' , 'TKRFF' , 'GLST' , 'HVT' , 'BEEM' , 'HAMRF' , 'SOJE' , 'TTEC' , 'MOBV' , 'AVPMF' , 'ILIM' , 'RNWF' , 'ATADF' , 'ATTBF' , 'CWIR' , 'GSHRF' , 'WDFC' , 'KTTA' , 'CLBT' , 'CAFS' , 'VATE' , 'DFCO' , 'OPHLY' , 'ITRG' , 'SSVFF' , 'FUSEF' , 'JBSS' , 'BACK' , 'AIM' , 'BZYR' , 'SND' , 'IAF' , 'AIQUY' , 'LMFA' , 'EDF' , 'CLW' , 'KLSVF' , 'PVBC' , 'QRTEP' , 'PRTG' , 'NLSPW' , 'QUAD' , 'IVPAF' , 'MGDDY' , 'TFFP' , 'RPHM' , 'JYNT' , 'MZZMF' , 'KHRNF' , 'MEC' , 'DSP' , 'JAMN' , 'FTMDF' , 'MSGE' , 'TKOMY' , 'ALLpG' , 'MVO' , 'SYBX' , 'SOS' , 'AMWD' , 'CEVA' , 'VAPO' , 'ATEX' , 'HUIZ' , 'WRAP' , 'CGRN' , 'MACK' , 'KNTE' , 'TARA' , 'GRTX' , 'RMED' , 'EFT' , 'KNTNF' , 'ASAZY' , 'GLCO' , 'VTOL' , 'PZC' , 'BIAF' , 'NVEE' , 'CVGW' , 'LE' , 'LMGDF' , 'CGXEF' , 'CIG/C' , 'VPCB' , 'PCRFY' , 'ORRCF' , 'NWTNW' , 'PYCT' , 'ISVLF' , 'IH' , 'LEMIF' , 'ACDI/U' , 'TIXT' , 'FFC' , 'ICCT' , 'MMLP' , 'MESO' , 'PTA' , 'ENGIY' , 'EBF' , 'MAX' , 'OSIS' , 'NILIF' , 'MPEG' , 'HPS' , 'HCKT' , 'GRUSF' , 'MUJ' , 'MSpO' , 'TRMR' , 'OMIC' , 'HQH' , 'GRC' , 'NOGNW' , 'BIO' , 'LATG' , 'OBNK' , 'NUVL' , 'ICAD' , 'PYPD' , 'CIR' , 'ATAT' , 'STER' , 'BACpN' , 'TMNA' , 'WFCpC' , 'COCP' , 'PKPH' , 'CYT' , 'HWKN' , 'NXTC' , 'DCBO' , 'NGMS' , 'KAVL' , 'PLYN' , 'AMNI' , 'RLGT' , 'SCTL' , 'TMGEF' , 'UAN' , 'HUSA' , 'WIW' , 'NGPHF' , 'COFpJ' , 'KWR' , 'PSUD' , 'NMTR' , 'ARAFF' , 'LDP' , 'KASHF' , 'USPH' , 'FFNTF' , 'HMTXF' , 'SSVRF' , 'PRPO' , 'SCGLY' , 'RDWR' , 'ASUR' , 'NCMGY' , 'ESTA' , 'SGGKF' , 'EOS' , 'CANG' , 'XNET' , 'RCAT' , 'CNSP' , 'KPCPY' , 'MOB' , 'ALTI' , 'AUDC' , 'MSpA' , 'SCM' , 'ISO' , 'LITOF' , 'AMOT' , 'PETZ' , 'EJPRY' , 'FORR' , 'TC' , 'VINC' , 'GRAMF' , 'BVXV' , 'SRAFF' , 'QIND' , 'MMT' , 'FRBK' , 'RCAR' , 'GGT' , 'CRDL' , 'RMR' , 'BMXC' , 'QIPT' , 'PHBI' , 'CMPGY' , 'USNZY' , 'MLAB' , 'AMK' , 'NOVN' , 'PIFYF' , 'EIG' , 'CTO' , 'BIREF' , 'TMPO' , 'TRS' , 'HIPO' , 'RVPH' , 'USIO' , 'MCRI' , 'SLGWF' , 'BABYF' , 'TMBR' , 'DEFTF' , 'CKPT' , 'VAUCF' , 'EAD' , 'DMB' , 'RJDG' , 'PAY' , 'FUJHY' , 'ISHYF' , 'ILIKF' , 'FTHY' , 'DRGV' , 'INDO' , 'MSA' , 'HTOO' , 'ACIU' , 'MSpF' , 'SCPS' , 'CSSI' , 'PLUS' , 'KAOOY' , 'NLYpF' , 'QTT' , 'ESE' , 'NKORF' , 'SHECY' , 'JWSM' , 'KE' , 'BIT' , 'USNA' , 'TCRR' , 'VWDRY' , 'UTI' , 'JFBR' , 'LUCD' , 'SDVKY' , 'SIEGY' , 'STGZ' , 'DSGX' , 'RLTY' , 'LINC' , 'MLTX' , 'CRVL' , 'CRMT' , 'NFGC' , 'SHTLF' , 'CSR' , 'TCBK' , 'WFCpD' , 'DCNNF' , 'RWLK' , 'CSTE' , 'ORN' , 'SOJD' , 'AVGR' , 'SWYDF' , 'BACpO' , 'DNAD' , 'DELCF' , 'LNN' , 'BACpQ' , 'HBT' , 'CNWGQ' , 'PMF' , 'BWV' , 'NHYDY' , 'AVO' , 'THCHW' , 'VULMF' , 'CHE' , 'EVAX' , 'SAFRY' , 'AMKBY' , 'JGGCW' , 'SMAGF' , 'PAX' , 'IRAAW' , 'DLTH' , 'WLMS' , 'SP' , 'CNICF' , 'ABST' , 'CCNE' , 'NHWK' , 'BONZ' , 'WTS' , 'LEN/B' , 'SREA' , 'ARC' , 'MF' , 'MITT' , 'OIL' , 'TCON' , 'NZTCF' , 'KREFpA' , 'FITBI' , 'BLIN' , 'GBHPF' , 'GMZP' , 'UFCS' , 'LVLU' , 'NSANY' , 'FOA' , 'ABOS' , 'TSYHF' , 'LZAGY' , 'BDTX' , 'TNC' , 'CNVVF' , 'FIXX' , 'RLYB' , 'APTPF' , 'FCNCA' , 'HCI' , 'MSBI' , 'MYRG' , 'TBIO' , 'HTD' , 'TBLD' , 'AMYZF' , 'ADDYY' , 'AEI' , 'RCFA' , 'JSD' , 'AVK' , 'AGFS' , 'RHCCF' , 'XPON' , 'CVLG' , 'WNDW' , 'IHD' , 'MOBQ' , 'EDI' , 'RVLGF' , 'CCD' , 'NA' , 'IKTO' , 'BLW' , 'APPF' , 'BHFAN' , 'EDSA' , 'MSpP' , 'CPSI' , 'KSPN' , 'ADUS' , 'BCUFF' , 'NXJ' , 'IPAX' , 'FEI' , 'FSXLF' , 'MGEE' , 'PHD' , 'USBpQ' , 'XBIO' , 'AXDDF' , 'MNGGF' , 'BLQC' , 'THQ' , 'LSRCY' , 'CTTAY' , 'GRSLF' , 'DBVT' , 'XCRT' , 'GHI' , 'PCB' , 'TA' , 'CMCXF' , 'ETB' , 'SCNA' , 'BRDCY' , 'CRESY' , 'XCUR' , 'TELHF' , 'BIOC' , 'REBN' , 'AZYO' , 'LMNL' , 'SAFT' , 'TPL' , 'CHCO' , 'ALLT' , 'EMOR' , 'VEEE' , 'TENKR' , 'KGFHY' , 'TRHC' , 'LIFW' , 'TKLF' , 'YRD' , 'CLRO' , 'PKE' , 'APOG' , 'MPAA' , 'OLMA' , 'MHI' , 'TCMD' , 'BKT' , 'AMSF' , 'BZTG' , 'NCA' , 'NKX' , 'CLMT' , 'PFBC' , 'AEHL' , 'FET' , 'NHS' , 'MSpE' , 'ARRNF' , 'NPPTF' , 'METpE' , 'JOUT' , 'DPUI' , 'OMMSF' , 'FNGR' , 'MPV' , 'KLTR' , 'ACGX' , 'EDXC' , 'HEINY' , 'HBANP' , 'ERIE' , 'PCQ' , 'NLYpI' , 'TFCpO' , 'FGB' , 'FOR' , 'MITEY' , 'HTBI' , 'NMTLF' , 'INOD' , 'MOBO' , 'TRYPF' , 'TGLDF' , 'GHAV' , 'CBNT' , 'HDGHF' , 'NTB' , 'PPBT' , 'SRGXF' , 'MMU' , 'TLPFY' , 'VRCFF' , 'EUSP' , 'OIA' , 'TBB' , 'OMZNF' , 'HAPBF' , 'DAO' , 'ODV' , 'JRS' , 'THM' , 'ICFI' , 'REPYY' , 'AFB' , 'PROK' , 'BIOX' , 'KMF' , 'ACHV' , 'VITFF' , 'BLFR' , 'ATHpE' , 'PDS' , 'MSB' , 'USBpP' , 'UHT' , 'NWPX' , 'ICLTF' , 'APCA/WS' , 'SIEB' , 'UNF' , 'VCISY' , 'APVO' , 'NGVC' , 'MOGO' , 'SNIPF' , 'CSPCY' , 'SPCB' , 'TGAN' , 'ROAD' , 'ETST' , 'ABVC' , 'NUWEW' , 'FTEK' , 'MKUL' , 'LMSQF' , 'CIA' , 'MLSS' , 'ARSMF' , 'MYSZ' , 'YTRA' , 'TCRX' , 'GSpD' , 'AADI' , 'CIHKY' , 'AGX' , 'GLXZ' , 'SGTX' , 'TY' , 'DALN' , 'FLNT' , 'RLBD' , 'USBpS' , 'ELVT' , 'MSN' , 'INVE' , 'LMAT' , 'RKLWQ' , 'RSVR' , 'MBRX' , 'SABRP' , 'FRLN' , 'DDNFF' , 'HOWL' , 'CNXN' , 'AEHA' , 'GPLL' , 'CWCO' , 'BGAVF' , 'AUNFF' , 'ANIP' , 'SSEZY' , 'HDELY' , 'PCF' , 'HLIO' , 'NIE' , 'SONX' , 'VCNX' , 'ORHB' , 'MVT' , 'GOGN/WS' , 'PXS' , 'OMQS' , 'TpA' , 'APETF' , 'ATHOF' , 'MOTS' , 'BLX' , 'GOTRF' , 'OCUP' , 'XOMA' , 'TCX' , 'REEMF' , 'EXPGY' , 'EM' , 'CRLFF' , 'GLV' , 'PINE' , 'PMCB' , 'LFVN' , 'ETpC' , 'PZG' , 'BPACW' , 'JILL' , 'EARN' , 'BFYW' , 'LUNMF' , 'DPSGY' , 'LGMH' , 'GTXAP' , 'HMMR' , 'LIXT' , 'ALTPF' , 'SKE' , 'SPAZF' , 'SCHYY' , 'RNLX' , 'MTEM' , 'BAESY' , 'ALPN' , 'REED' , 'EFXT' , 'CHAA' , 'ACGN' , 'TKAT' , 'MCR' , 'NMM' , 'DPG' , 'NCNA' , 'DMAC' , 'FRBA' , 'SGU' , 'ANAC' , 'FRA' , 'ELOX' , 'DZSI' , 'SRDX' , 'BWG' , 'TDF' , 'MGMNF' , 'HCCI' , 'CNTA' , 'NECB' , 'CREG' , 'TTNP' , 'CASS' , 'BFST' , 'HQGE' , 'BCBP' , 'IPXHY' , 'LTBR' , 'RMM' , 'VCV' , 'MLPMF' , 'GABC' , 'AMTB' , 'BURU/WS' , 'RENN' , 'GB' , 'ODDAF' , 'FSD' , 'THW' , 'AIMH' , 'RTSL' , 'EGPLF' , 'SMLR' , 'RGBPP' , 'UTL' , 'TLSA' , 'ADOC' , 'VPG' , 'LGIQ' , 'PUCK' , 'FpC' , 'STKXF' , 'RCG' , 'GFAIW' , 'ALG' , 'OTLC' , 'NSpB' , 'DSITF' , 'NLCP' , 'KUYAF' , 'BGR' , 'ZDGE' , 'LOBEF' , 'SHBI' , 'ATY' , 'PCK' , 'BFK' , 'SIREF' , 'JUBPF' , 'FLRE' , 'CYSNF' , 'OTSKY' , 'GBXI' , 'FATH' , 'HROWM' , 'MORN' , 'CDIO' , 'ARREF' , 'MFGCF' , 'BXC' , 'DBOEY' , 'IBDRY' , 'NEU' , 'SKYX' , 'JTKWY' , 'PRK' , 'CFGpE' , 'ISSC' , 'PEO' , 'BACpB' , 'MMRGF' , 'REYGF' , 'HHSE' , 'JPMpD' , 'GAIA' , 'ELRRF' , 'VSBGF' , 'TRNS' , 'WBRBY' , 'RSF' , 'ZEST' , 'NEXA' , 'JANX' , 'MOHOY' , 'DNBBY' , 'FCUV' , 'OMGA' , 'UBSFY' , 'IMPUY' , 'VMCS' , 'SRCO' , 'VHC' , 'ETCG' , 'WETH' , 'GPOX' , 'EDD' , 'SPMTF' , 'MTP' , 'TOLWF' , 'WPP' , 'CTAQ' , 'IGXT' , 'VPTDF' , 'EXNRF' , 'TLIF' , 'RCMT' , 'MEDAF' , 'OCFT' , 'PILBF' , 'JGH' , 'CCB' , 'FC' , 'DECA' , 'MIO' , 'VNTR' , 'KITT' , 'NGTF' , 'GSpK' , 'FRCpK' , 'BVAXF' , 'IMNM' , 'FSV' , 'NEOV' , 'IONI' , 'BEAT' , 'CKHUY' , 'CRARY' , 'JRI' , 'QVCD' , 'DFP' , 'YCBD' , 'GMTNF' , 'IMRX' , 'IRIX' , 'CPUH/WS' , 'CABO' , 'TSSI' , 'MIY' , 'OPRA' , 'NBMFF' , 'CCAI' , 'NVMI' , 'CBULF' , 'HUDAR' , 'GAM' , 'DOOO' , 'BSQR' , 'NBB' , 'CONXF' , 'BTMD' , 'NCLTY' , 'IMNN' , 'ILAL' , 'GRCAF' , 'ATLYF' , 'TRSSF' , 'OPAL' , 'SCYX' , 'ASMVY' , 'VOR' , 'ICD' , 'AIF' , 'CAC' , 'DIAX' , 'PFDR' , 'PRT' , 'TKOMF' , 'RGXTF' , 'BWB' , 'LBWR' , 'CAPR' , 'BREA' , 'PPRUY' , 'PTE' , 'ALIZY' , 'NKRSF' , 'TGNT' , 'KAIIW' , 'RVSDF' , 'GSCCF' , 'TDSpV' , 'CDRE' , 'MBIN' , 'YUEIY' , 'IMTE' , 'CICHY' , 'HOUR' , 'VRRCF' , 'GLASF' , 'RDRSF' , 'VBOC' , 'PRSTW' , 'HCDI' , 'BIMI' , 'NRDBY' , 'LGGNF' , 'NPSNY' , 'TCBIO' , 'PIK' , 'NXEN' , 'SLVO' , 'IBEX' , 'OST' , 'ACOGF' , 'ARBKF' , 'SWDBY' , 'CCLP' , 'ETON' , 'SOBKY' , 'RFI' , 'OGEN' , 'COPAF' , 'UZF' , 'YACAF' , 'SPQS' , 'IAE' , 'MRAM' , 'VNOpO' , 'QCRH' , 'PLAG' , 'ABCFF' , 'RIBT' , 'KAI' , 'ASYS' , 'ACFN' , 'KFS' , 'ALOR' , 'ANIK' , 'RANI' , 'MSACW' , 'BGX' , 'SHTDF' , 'BYTS' , 'CLPBY' , 'GHRS' , 'TNGL' , 'PRST' , 'PURE' , 'BNNLF' , 'BWLKF' , 'CEAD' , 'ATNI' , 'BURBY' , 'NGENF' , 'ICLK' , 'TPRFF' , 'GNT' , 'CAAP' , 'EBON' , 'NSpC' , 'RSNHF' , 'AFT' , 'ESAIY' , 'ARBGW' , 'HSTO' , 'STN' , 'SPRC' , 'IDT' , 'ABEPF' , 'ERC' , 'CBH' , 'HPI' , 'PCYG' , 'INXDF' , 'AKA' , 'SUP' , 'AMXEF' , 'KEYpK' , 'SYBT' , 'AEFC' , 'PSHG' , 'DMRC' , 'CINT' , 'SMURF' , 'MURMF' , 'CTBB' , 'CNVCF' , 'VMNT' , 'TELA' , 'GVP' , 'WSBF' , 'BVNNF' , 'ATVVF' , 'MBGAF' , 'PNI' , 'CLOQ' , 'ETpD' , 'GPAC' , 'PMOMF' , 'BMEA' , 'AYTU' , 'ELRFF' , 'GRPH' , 'VONOY' , 'CBDNF' , 'WMK' , 'PAC' , 'BLLYF' , 'DCO' , 'ASA' , 'ULTRF' , 'JCE' , 'APGN' , 'VEV' , 'IBCP' , 'NRGD' , 'QLGN' , 'BRN' , 'BCHG' , 'EFR' , 'WLKP' , 'DHCNL' , 'INVO' , 'CNNB' , 'WF' , 'GALKF' , 'BWAC' , 'VLVLY' , 'NBVAF' , 'UEIC' , 'FSUGY' , 'SNVpE' , 'NPFD' , 'ESGR' , 'INBK' , 'MMD' , 'VSEC' , 'GLRE' , 'FELTY' , 'NSRPF' , 'GBAB' , 'AGM' , 'SNRG' , 'NTWK' , 'UZD' , 'BYM' , 'OPFI' , 'TEAF' , 'APGB/U' , 'OCANF' , 'AAIC' , 'AVTE' , 'WEA' , 'DASTY' , 'MCB' , 'SBI' , 'MZDAY' , 'HSHCY' , 'PRED' , 'MSpI' , 'BITTF' , 'SLN' , 'PKLBF' , 'ONVO' , 'BORK' , 'APLIF' , 'MKL' , 'DTII' , 'RFMZ' , 'GENC' , 'CSRNF' , 'WNEB' , 'DHCNI' , 'CpJ' , 'ACRHF' , 'BATRA' , 'GSpA' , 'ULTXF' , 'PLOW' , 'JNSH' , 'BPYPM' , 'CXOXF' , 'BTMDW' , 'SMNNY' , 'FORA' , 'AMPE' , 'AIP' , 'ALLIF' , 'ATAKW' , 'CPWR' , 'SLVMF' , 'AEF' , 'SANW' , 'LAZY' , 'WGMCF' , 'UNICY' , 'KMTUY' , 'THFF' , 'DBKSF' , 'LMB' , 'RICK' , 'LMST' , 'PRDS' , 'MLNK' , 'IGA' , 'VIA' , 'PCCYF' , 'BBSI' , 'LSF' , 'CACO' , 'UAPC' , 'CENT' , 'AGFAF' , 'SINGF' , 'STEW' , 'TCCPY' , 'HFFG' , 'SAMG' , 'WGLIF' , 'RAYA' , 'CETUU' , 'SCLTF' , 'IRON' , 'CXAC/WS' , 'ISRLU' , 'DKL' , 'HY' , 'BVH' , 'LWAY' , 'HZN' , 'CLIR' , 'EESO' , 'FBRX' , 'MNTN' , 'OCCI' , 'VTVT' , 'BCDA' , 'RYCEF' , 'CATO' , 'RNGR' , 'FIF' , 'UNLRF' , 'TRC' , 'DMAN' , 'WFCpA' , 'TCHC' , 'TZPC' , 'ATHpC' , 'USCT' , 'MITGW' , 'CDTAF' , 'MXTRF' , 'GDCCW' , 'BRNGF' , 'ACMB' , 'FUTS' , 'SHIFF' , 'ZBNIF' , 'LEAS' , 'SMGBF' , 'PSHZF' , 'BHFAP' , 'FCO' , 'MSpK' , 'PBCRY' , 'ULH' , 'AE' , 'CMBM' , 'SII' , 'IHIT' , 'JAKK' , 'NVDSF' , 'VEDU' , 'JATT' , 'NLYpG' , 'RFpC' , 'FGLDF' , 'GBOOY' , 'SVNLF' , 'PHI' , 'ANTX' , 'EAR' , 'AKZOY' , 'TBC' , 'GLPEY' , 'IZOZF' , 'MG' , 'VOXX' , 'BTO' , 'EOD' , 'SGIOY' , 'KOSK' , 'HGLB' , 'UFPT' , 'ESLT' , 'CGLCF' , 'CLAZF' , 'ALCC' , 'TGL' , 'CAF' , 'FDEU' , 'USEG' , 'VXZ' , 'RXST' , 'TDCX' , 'AUMBF' , 'BVTEF' , 'EDBLW' , 'VCIF' , 'EZFL' , 'ROXIF' , 'CHRA' , 'PFH' , 'VBF' , 'BGT' , 'UGRO' , 'ETO' , 'MEGEF' , 'BACpK' , 'FDVXF' , 'GBTG' , 'NGGTF' , 'SGHT' , 'PMTpC' , 'JSHG' , 'MSD' , 'BEDU' , 'XPAX' , 'HOTH' , 'PSF' , 'BFS' , 'CRVS' , 'RIINF' , 'RHE' , 'SFpD' , 'LADX' , 'PHIO' , 'TMP' , 'SRHYY' , 'BUI' , 'MILC' , 'KERNW' , 'NFNT' , 'AMLM' , 'RFL' , 'VGI' , 'GRLRF' , 'TOELY' , 'PCM' , 'CMCL' , 'OLP' , 'FMIV' , 'STK' , 'QVCC' , 'PARAA' , 'ZPTAF' , 'HCMA' , 'LBCMF' , 'FHNpF' , 'PYR' , 'VVCVF' , 'REFG' , 'SIFY' , 'DYAI' , 'RVP' , 'PCGpA' , 'AVTX' , 'CANN' , 'CpN' , 'ABXXF' , 'LYSCF' , 'MEEC' , 'NRRSF' , 'COGNY' , 'LZRFY' , 'SRCE' , 'DEX' , 'NMG' , 'GDLNF' , 'SNSE' , 'NNI' , 'SEED' , 'NLLSF' , 'TRTNpE' , 'CNDGF' , 'DEWM' , 'RHCO' , 'ISUN' , 'HTY' , 'MSpL' , 'LTHHF' , 'GDNSF' , 'CLPT' , 'EQBK' , 'LGSTW' , 'VVOS' , 'ABIT' , 'EFSH' , 'INAB' , 'DLPN' , 'MAV' , 'SUHJY' , 'THRN' , 'MPX' , 'AKBTY' , 'SSY' , 'NXTP' , 'GHL' , 'CFMS' , 'TOBAF' , 'MKTW' , 'ARBKL' , 'IDE' , 'OVID' , 'COFpL' , 'FMN' , 'STCN' , 'DDI' , 'GDLC' , 'FARM' , 'SAUHY' , 'FWEDF' , 'GDO' , 'CRAI' , 'RITMpD' , 'PNXLF' , 'TELNY' , 'ENBA' , 'AMADY' , 'CCBG' , 'ECSL' , 'CPRRF' , 'DUKB' , 'MFH' , 'NOKPF' , 'LURAF' , 'LION' , 'CCAP' , 'CDBT' , 'RDGMF' , 'ASR' , 'TARS' , 'IFRX' , 'BMLpJ' , 'VIOT' , 'KRNLW' , 'MCBC' , 'MCIC' , 'ARGGY' , 'ENVB' , 'GHM' , 'LANV' , 'QTNTQ' , 'EMPYF' , 'TUWOY' , 'NLSP' , 'RNXT' , 'NOVRF' , 'DBL' , 'QRHC' , 'IEGCF' , 'SCHWpD' , 'GLBS' , 'MCFNF' , 'TGIFF' , 'GOCO' , 'MTR' , 'AFFCF' , 'AXAHY' , 'GTIM' , 'CBAN' , 'BYRN' , 'STTpD' , 'LGI' , 'COFpN' , 'HITC' , 'FCRD' , 'CAPL' , 'AOMR' , 'CMU' , 'SNES' , 'SCHWpJ' , 'BRGC' , 'VRSSF' , 'TCLRY' , 'CHVKF' , 'NXPL' , 'OLB' , 'HPF' , 'RIGMD' , 'GBR' , 'VMAR' , 'NVIV' , 'EDTK' , 'TAST' , 'EVEX' , 'HPQFF' , 'VIPRF' , 'CSTA/WS' , 'EGOC' , 'HKXCY' , 'LFT' , 'DNNGY' , 'PSGR' , 'CPSS' , 'EDN' , 'BTTX' , 'BMLpH' , 'KPRX' , 'HANNF' , 'MCBS' , 'SLNAW' , 'IMCC' , 'SCVFF' , 'IKNA' , 'WFCpR' , 'PTN' , 'LYSDY' , 'DLAKY' , 'CODYY' , 'CHSCM' , 'SECO' , 'JFIN' , 'DXYN' , 'PNCKF' , 'JPOTF' , 'FEN' , 'BWMN' , 'SYIEY' , 'AZ' , 'SCOBU' , 'QNCCF' , 'EXMGF' , 'EONGY' , 'OILSF' , 'SJ' , 'RVIV' , 'MXF' , 'ZKIN' , 'VELXF' , 'SQFT' , 'MYTE' , 'REPX' , 'SVLT' , 'SLDB' , 'SALM' , 'EVG' , 'SNNC' , 'MPRAU' , 'GPACU' , 'PRSO' , 'KNBWY' , 'ETFLF' , 'SRGA' , 'CKEFF' , 'EORBF' , 'CGUD' , 'SBLRF' , 'LFMD' , 'MYFW' , 'CVAT' , 'ERYP' , 'SDHY' , 'ROYTL' , 'OPSSF' , 'AIU' , 'HENKY' , 'ARTNA' , 'PROBF' , 'NEPH' , 'TCTZF' , 'CPZ' , 'LCUT' , 'CANSF' , 'YORW' , 'INIS' , 'GPLDF' , 'FPL' , 'MAIA' , 'NVR' , 'BLCM' , 'ADER' , 'BHFAM' , 'COKE' , 'NQP' , 'AHG' , 'MRCC' , 'RGF' , 'NIQ' , 'CTCGF' , 'WORX' , 'EEMMF' , 'CUBA' , 'DRRX' , 'NLVVF' , 'APGMF' , 'TZROP' , 'IMPNF' , 'AHNR' , 'LLLI' , 'EFLVF' , 'DELKY' , 'BMRC' , 'TNEYF' , 'RFpB' , 'FRST' , 'WCUFF' , 'ZTEK' , 'PRPH' , 'BBSEY' , 'SONM' , 'ETRGF' , 'PFD' , 'GRNAW' , 'AGLAF' , 'EMOTF' , 'NGS' , 'GAMB' , 'USBpR' , 'MTMT' , 'PRH' , 'DTOC' , 'RFpE' , 'VMSXF' , 'GIC' , 'NVNXF' , 'AEYE' , 'JVTSF' , 'BFZ' , 'BSL' , 'CAIXY' , 'TLRS' , 'SCD' , 'EWPMF' , 'CVM' , 'SCOBW' , 'RSMXF' , 'SABS' , 'CYAD' , 'TEZNY' , 'CABGY' , 'LKREF' , 'ATDRY' , 'PDOT' , 'ALCO' , 'COEPW' , 'BWVI' , 'HADV' , 'ANZUU' , 'IBATF' , 'MIND' , 'BYAGF' , 'OMAB' , 'VTRU' , 'BRT' , 'SWMAY' , 'TZOO' , 'RDDTF' , 'DGMLF' , 'LUVU' , 'SSTI' , 'STRT' , 'NEEpN' , 'EPOKY' , 'FOSYF' , 'CTDD' , 'ISENF' , 'LISMF' , 'TLSNY' , 'MQMNW' , 'CMMB' , 'FLOOF' , 'AJX' , 'PET' , 'SDPI' , 'AIBRF' , 'CMPOW' , 'MGF' , 'NCPL' , 'AQNU' , 'HESAY' , 'ZLNDY' , 'ALLG' , 'CEE' , 'VACC' , 'CXE' , 'TYRA' , 'FSNB' , 'PCGpE' , 'TKGBY' , 'SMBK' , 'BACpS' , 'DMS' , 'AETUF' , 'FINS' , 'BKRKY' , 'BSMX' , 'DSDVY' , 'LOV' , 'ARTL' , 'GCLT' , 'RTMVY' , 'SHZHY' , 'HBIO' , 'NVCN' , 'AGAE' , 'NKOSF' , 'ATHpA' , 'ATHpB' , 'TSRMF' , 'WRSLF' , 'BYNO' , 'IFS' , 'LGVN' , 'MNK' , 'GKIN' , 'NMS' , 'CTBI' , 'CHGCY' , 'CLLNY' , 'KOREF' , 'INMB' , 'ZIVO' , 'POTN' , 'RWEOY' , 'GGE' , 'AKTX' , 'CMND' , 'PLM' , 'MNSEF' , 'BOIVF' , 'BERI' , 'BRKCF' , 'NCPCF' , 'DCTH' , 'PSApL' , 'AWRE' , 'SBNYP' , 'MGU' , 'ARGYF' , 'DCFCW' , 'FpB' , 'CNF' , 'EIC' , 'KUBTY' , 'MPB' , 'THTX' , 'SCWX' , 'LSEA' , 'LKMNF' , 'VMCA' , 'KDKGF' , 'PGYWW' , 'WKSP' , 'IPDN' , 'WIA' , 'ALORW' , 'CLPHY' , 'IIF' , 'LYRA' , 'ROSS/WS' , 'LTMCF' , 'TTFNF' , 'TDW/WS/A' , 'INDT' , 'BYFC' , 'WEGZY' , 'PSApQ' , 'TXMD' , 'EOT' , 'ARCE' , 'OMEX' , 'NSS' , 'SLRX' , 'PRS' , 'ALBT' , 'IDLSF' , 'NSUPF' , 'DRTS' , 'SPXX' , 'CPFXF' , 'EOCW' , 'BSRR' , 'RLBY' , 'JT' , 'PRMNF' , 'NRSN' , 'SSU' , 'TCFC' , 'LNCpD' , 'MRGE' , 'RAIL' , 'ETpE' , 'TIPT' , 'PPSI' , 'FSRXU' , 'GSIT' , 'SILC' , 'AFRI' , 'RGLG' , 'NOGN' , 'MRAI' , 'DCAC' , 'XTPT' , 'AVVIY' , 'RMI' , 'APT' , 'GLIOF' , 'KGEIF' , 'LND' , 'WKEY' , 'EUDA' , 'GPTRF' , 'NHTC' , 'ESOA' , 'HCVI' , 'ALIM' , 'BPYPN' , 'MNXXF' , 'DHAC' , 'LVWR/WS' , 'KOMOD' , 'ADRNY' , 'HELFY' , 'ESKYF' , 'GLBXF' , 'KRKR' , 'FECCF' , 'ML/WS' , 'YGRAF' , 'HNHPF' , 'AZMCF' , 'FT' , 'CRT' , 'XSHLF' , 'ORZCF' , 'WFCpY' , 'SCTSF' , 'MACA' , 'PWRLF' , 'NBRV' , 'LVOX' , 'SHWZ' , 'KKRS' , 'UZE' , 'FFXDF' , 'ADD' , 'VINP' , 'CSCCF' , 'QUIK' , 'FFA' , 'NUVSF' , 'SOJC' , 'WWAC' , 'STTpG' , 'LRENY' , 'EVM' , 'LUXH' , 'PKKFF' , 'NMTC' , 'SOUHY' , 'JHX' , 'FSI' , 'AHI' , 'MITJF' , 'CARE' , 'ATLO' , 'NPK' , 'LEDS' , 'STOSF' , 'TRMLF' , 'SGAPY' , 'GB/WS' , 'WTKN' , 'FISI' , 'CPIX' , 'MCN' , 'BURU' , 'RVLWF' , 'TDPAY' , 'PEYUF' , 'IRMD' , 'CEN' , 'PIM' , 'GKPRF' , 'CNTB' , 'KCGI' , 'MVBF' , 'HYI' , 'MNNDF' , 'DMF' , 'EVLVW' , 'NCMGF' , 'MIMZF' , 'USAU' , 'RAVE' , 'BQ' , 'KEYpJ' , 'AUOTY' , 'FOF' , 'HCDIP' , 'DLHC' , 'NRC' , 'ZPHRF' , 'ACV' , 'KKPNF' , 'BTAEF' , 'SUUFF' , 'HERB' , 'RM' , 'NWCCF' , 'JG' , 'RNECY' , 'TOMZ' , 'SIVBP' , 'NVLPF' , 'OBTC' , 'SASI' , 'AMHG' , 'NEXNF' , 'AGIL' , 'DAVE' , 'BMLpL' , 'XLO' , 'SOHO' , 'LGRDY' , 'SISI' , 'SMMNY' , 'CSTR' , 'TUEM' , 'CSLLY' , 'FRHLF' , 'TYG' , 'WLDN' , 'POLA' , 'AAC/WS' , 'MPA' , 'NHC' , 'DFLI' , 'TRRE' , 'HUML' , 'MINE' , 'WMWWF' , 'CWLPF' , 'ZEPP' , 'MLR' , 'PSApK' , 'ITQRU' , 'GRNT' , 'SSUMY' , 'BBGI' , 'FTAA' , 'HLVX' , 'UNVGY' , 'STBFY' , 'FUSN' , 'XBIT' , 'PNRLF' , 'INCR' , 'ALRN' , 'CKISF' , 'DELHY' , 'EMMA' , 'APSI' , 'ECXWW' , 'GRRR' , 'SSBK' , 'CMCM' , 'BTA' , 'GDST' , 'IKT' , 'FBIOP' , 'YOSH' , 'CTM' , 'MNDO' , 'SGGEF' , 'JJC' , 'CMSD' , 'NSTB' , 'NOCRF' , 'FIORF' , 'AGD' , 'RRRLF' , 'RITMpC' , 'SFTBY' , 'MURGY' , 'RITMpA' , 'MXROF' , 'GSRM' , 'HPPpC' , 'CANF' , 'ZUKI' , 'EKSO' , 'MHN' , 'QYOUF' , 'UONEK' , 'FSNB/U' , 'PTPI' , 'EEX' , 'MNDP' , 'MPIR' , 'NAFS' , 'TARSF' , 'BSFFF' , 'BONXF' , 'TMEB' , 'RDBBY' , 'CDIX' , 'BURCF' , 'FTHWF' , 'FORD' , 'CBAOF' , 'SPVNF' , 'YARIY' , 'TPCS' , 'HMPT' , 'UMHpD' , 'MOFG' , 'PUBC' , 'EPOW' , 'IGI' , 'MPRAW' , 'OOMA' , 'ADRA/WS' , 'ONPH' , 'ESGRP' , 'CTIB' , 'COW' , 'LGO' , 'FLC' , 'TDSpU' , 'AMCI' , 'CMRA' , 'STTDF' , 'WEGYF' , 'NPRFF' , 'FCNCO' , 'OPFI/WS' , 'NURO' , 'AANNF' , 'NTCPF' , 'TAYD' , 'ACON' , 'RHHVF' , 'IESC' , 'MGR' , 'BFI' , 'ALVO' , 'BCLYF' , 'RETO' , 'ADVZF' , 'AGMpD' , 'TAIT' , 'JUN' , 'MSDAW' , 'PMTpB' , 'MWSNF' , 'ELBM' , 'FUND' , 'WAVD' , 'RKFL' , 'NVAAF' , 'MKKGY' , 'ACBA' , 'AGNCL' , 'CELC' , 'ZHSHF' , 'NUZE' , 'CCLDP' , 'MNOV' , 'IPW' , 'WDDD' , 'BACHY' , 'HERTF' , 'AOUT' , 'ATCOpI' , 'TORXF' , 'IICN' , 'ETX' , 'ILHMF' , 'IINN' , 'EBCOY' , 'FDEI' , 'GMGMF' , 'FRONW' , 'IMMP' , 'RONI' , 'GF' , 'PCTI' , 'ORGS' , 'RINO' , 'CLGN' , 'CLTS' , 'STTK' , 'FANH' , 'KEN' , 'ODII' , 'TIIAY' , 'OBIO' , 'CGABL' , 'NRVTF' , 'NTPIF' , 'EVGDF' , 'INTT' , 'SCAQ' , 'SOR' , 'CIMpC' , 'EDAP' , 'CVCY' , 'ZING' , 'PWCDF' , 'DBSDY' , 'JCSE' , 'PCRAF' , 'JETMF' , 'PBIO' , 'MBWM' , 'PSYCF' , 'SMBMF' , 'PMTS' , 'CIF' , 'MLCT' , 'NRP' , 'WRDLY' , 'CLRB' , 'INRD' , 'GRVY' , 'UONE' , 'OVTZ' , 'TPBAW' , 'RCA' , 'SRNW' , 'ATHC' , 'GWAV' , 'FRD' , 'MSSAW' , 'SEKZF' , 'GHVNF' , 'ACCYY' , 'NTRB' , 'RWTpA' , 'POSAF' , 'SNBH' , 'ATMCW' , 'IOBT' , 'FTHM' , 'NAZ' , 'SMMF' , 'KCCFF' , 'LITB' , 'ID' , 'KPELF' , 'VFL' , 'SAR' , 'PPERY' , 'ESQ' , 'BNCHF' , 'KSM' , 'ELA' , 'CPAQW' , 'PEMIF' , 'GTLSpB' , 'PMTpA' , 'HOFT' , 'BCSA' , 'PCCT' , 'VOYApB' , 'AKU' , 'JFU' , 'EPRpC' , 'AHLpE' , 'CDAQ' , 'NUW' , 'LNVGY' , 'JJA' , 'KIQ' , 'ENOB' , 'USDR' , 'MNRLF' , 'BCML' , 'SLVDF' , 'SVBL' , 'OILFF' , 'TGODF' , 'LAKE' , 'OZKAP' , 'CLRMF' , 'INNV' , 'SEGXF' , 'AACTF' , 'EVGR' , 'SNYNF' , 'ALPMY' , 'FRCpN' , 'DTRUY' , 'CPPKF' , 'DQJCY' , 'NRAC' , 'JOF' , 'ISTR' , 'LGACW' , 'FQVLF' , 'BITE/WS' , 'NWPG' , 'NMLSF' , 'OESX' , 'WXXWY' , 'MCURF' , 'GIFI' , 'NIpB' , 'VVX' , 'ASCB' , 'SOHU' , 'MQT' , 'MGPHF' , 'AHKSY' , 'COSG' , 'RDCM' , 'MGWFF' , 'OSIIF' , 'XSNX' , 'LMRMF' , 'NFTFF' , 'RNMBY' , 'HSQVY' , 'ECRAF' , 'LEAI' , 'CSSE' , 'KOSS' , 'FRCpM' , 'CHEKZ' , 'LOKM/WS' , 'CCF' , 'AAWH' , 'NAMS' , 'RMHB' , 'NUO' , 'DTW' , 'CLPR' , 'DPMLF' , 'SNPMF' , 'RNRpF' , 'EBZT' , 'DERM' , 'DLAKF' , 'MDEX' , 'PSApP' , 'AFLYY' , 'PGPEF' , 'PEPG' , 'SCFR' , 'WHGLY' , 'FRBN' , 'ECRTF' , 'TRRXF' , 'EDTXF' , 'ADMQ' , 'GEEXW' , 'BGTK' , 'SLAMW' , 'LVRLF' , 'VYYRF' , 'RIOFF' , 'ESAC' , 'BHFAO' , 'FCBC' , 'TMVWY' , 'NYCBpA' , 'SSYRF' , 'ANIX' , 'ELNSF' , 'GANX' , 'DYLLF' , 'WTT' , 'LGSXY' , 'NSPR' , 'DTEGF' , 'FJTSY' , 'MIMO' , 'ATLC' , 'ABRpF' , 'WHLR' , 'KEYpI' , 'FFOXF' , 'WHG' , 'ARBEW' , 'GYST' , 'DGICA' , 'PROF' , 'PFO' , 'MBOT' , 'AUGG' , 'CLSH' , 'ASDZF' , 'BDRFY' , 'VJET' , 'ELDN' , 'RZC' , 'EVI' , 'EQHpA' , 'CGEMY' , 'GMGSF' , 'WBEVQ' , 'SGMA' , 'SCEpJ' , 'PRETN' , 'FRTN' , 'OCG' , 'NNY' , 'GSpC' , 'HTHIY' , 'NIHK' , 'DLNG' , 'UKOMW' , 'OPTHF' , 'BEPH' , 'AXSpE' , 'CETYD' , 'EBR/B' , 'VKIN' , 'UPH' , 'RFHRF' , 'WRRZF' , 'TMCGF' , 'ACXP' , 'NROM' , 'TAKOF' , 'ASGI' , 'TCVA' , 'GCV' , 'AYASF' , 'BBLN' , 'CJPRY' , 'MXE' , 'MONOY' , 'ARQQW' , 'HXGBF' , 'HOFV' , 'NATR' , 'BWAY' , 'FLME/WS' , 'APAAF' , 'JPI' , 'VNOpM' , 'RAYT' , 'BNJ' , 'MTHRY' , 'GTEC' , 'DOMH' , 'VWEWW' , 'JAN' , 'AEPPZ' , 'PLRTF' , 'IMPL' , 'CZNC' , 'NBNKF' , 'ATHpD' , 'JAGGF' , 'SXOOF' , 'WWACU' , 'WMC' , 'LBC' , 'NPNYY' , 'HBB' , 'IDCBY' , 'TGHpB' , 'GOFPY' , 'ROIVW' , 'CLGUF' , 'RZB' , 'RWBYF' , 'FETM' , 'CNTMF' , 'ADMLF' , 'ALRS' , 'AGMpE' , 'XXMMF' , 'OVLY' , 'GSD' , 'SNPHY' , 'ARAAF' , 'KCDMY' , 'VGANF' , 'INFU' , 'HDST' , 'MDIT' , 'ACTHF' , 'SOMLY' , 'MTNOY' , 'IRVRF' , 'IDN' , 'DTLAp' , 'OPNT' , 'NDVLY' , 'ASNS' , 'CXDO' , 'ATLCP' , 'CHCI' , 'FENG' , 'GRNBF' , 'ANPC' , 'DSNKY' , 'HUNGF' , 'GMVHY' , 'FMANF' , 'BLUA' , 'SMSEY' , 'CMT' , 'SLAC' , 'APGOF' , 'PENMF' , 'DSGR' , 'PAASF' , 'NLBS' , 'ECIFY' , 'BTTC' , 'EZGO' , 'SHGDF' , 'RLTR' , 'SCYYF' , 'SVNDY' , 'WPCA' , 'TANH' , 'ECF' , 'GFGDW' , 'CYTO' , 'ATCOpH' , 'ADAG' , 'UPXI' , 'CRSXF' , 'KEYpL' , 'SQL' , 'LANDO' , 'SNMRY' , 'MNPR' , 'HNNMY' , 'PLSE' , 'KACLR' , 'FNGO' , 'MFIN' , 'SFST' , 'QUAN' , 'CPOP' , 'BXBLY' , 'IPDQF' , 'MSMGF' , 'SNVpD' , 'UNTC' , 'NFLDF' , 'WALpA' , 'SBSAA' , 'GHG' , 'EVVTY' , 'REMRF' , 'WVMDF' , 'BWTX' , 'LIQQF' , 'FRCpJ' , 'AIH' , 'GTVI' , 'CASI' , 'ALTIW' , 'PSApF' , 'WSHE' , 'SRV' , 'AZASF' , 'PMCOF' , 'LBSR' , 'ARBE' , 'ERH' , 'TMOAY' , 'STEV' , 'VPV' , 'KPEA' , 'SATL' , 'AHCHY' , 'CETXP' , 'LUMO' , 'ACGLN' , 'AGE' , 'QSEP' , 'GNAL' , 'PACWP' , 'SITS' , 'BME' , 'PRLD' , 'CRZBY' , 'BBUC' , 'FRCpL' , 'LCCTF' , 'NHLG' , 'BFIN' , 'FBRTpE' , 'IPA' , 'NIC' , 'SMBC' , 'BKYI' , 'WSTRF' , 'MCI' , 'ENLV' , 'BRFH' , 'WESMF' , 'FCNCP' , 'BGRYW' , 'NBW' , 'ACGLO' , 'ESOCF' , 'VYST' , 'KPIFF' , 'CHN' , 'KDKCF' , 'CIMpD' , 'PTSI' , 'CGO' , 'SHASF' , 'JMSB' , 'AKO/B' , 'DENKF' , 'SUTNY' , 'OLVRF' , 'CXCQ' , 'VTN' , 'CPSH' , 'ANPMF' , 'IWAL' , 'WECMF' , 'VHAQ' , 'RNRpG' , 'AROW' , 'HYW' , 'QSG' , 'AMFL' , 'ENTX' , 'ACRV' , 'LITT' , 'SANG' , 'REUN' , 'CORR' , 'KNYJY' , 'XELAP' , 'AMNF' , 'LNKB' , 'SFBQF' , 'NRILY' , 'FNCTF' , 'BOUYY' , 'IQMD' , 'WTBA' , 'SSREY' , 'PSApR' , 'LHC' , 'CYLC' , 'TGLO' , 'INTZ' , 'LVWR' , 'SVLKF' , 'AWSL' , 'GENQ' , 'ICUCW' , 'IMOS' , 'MHUA' , 'AAIGF' , 'NVEC' , 'AFHIF' , 'AUXXF' , 'HIGpG' , 'SPFI' , 'CLPS' , 'ENCPW' , 'EGAN' , 'EBKDY' , 'MCHX' , 'MUE' , 'MLECW' , 'RMMZ' , 'HLDCY' , 'PYNKF' , 'CVU' , 'GHC' , 'SPOFF' , 'ACAHU' , 'PRKA' , 'MWRK' , 'BBDO' , 'MLLOF' , 'WYNMY' , 'EVE/WS' , 'FMBH' , 'TCBX' , 'CORG' , 'CHOOF' , 'ZNNC' , 'QTXB' , 'VVIVF' , 'EUMNF' , 'BMKDF' , 'DUUO' , 'MTNOF' , 'SAVNF' , 'AAIRF' , 'RBMNF' , 'SPRN' , 'ATAKR' , 'ESIFF' , 'AKMYF' , 'BBRRF' , 'GETH' , 'GLRI' , 'LNDZF' , 'DGDCF' , 'CGNMF' , 'AUCUF' , 'CRGP' , 'BHLIF' , 'HRAL' , 'EIPAF' , 'GWRS' , 'POET' , 'SWAG' , 'BF/A' , 'TREIF' , 'QABSY' , 'MOVE' , 'ALLpB' , 'TNYYF' , 'HEQ' , 'IFPJF' , 'IVFH' , 'JAPAY' , 'JBAXY' , 'NNOMF' , 'MEDH' , 'KZIA' , 'OILCF' , 'MIRO' , 'EVO' , 'STAF' , 'FNWB' , 'FHTX' , 'NXGL' , 'BOMXF' , 'MOXC' , 'FBIZ' , 'CEM' , 'BRTX' , 'DDF' , 'RCKY' , 'SEKEY' , 'VEL' , 'BYTSW' , 'BPTH' , 'HCMLF' , 'ISDR' , 'LTRN' , 'ABVG' , 'KALY' , 'OPBK' , 'THNPY' , 'ABIO' , 'BPYPP' , 'GSBC' , 'SNAX' , 'TKOI' , 'BAESF' , 'ANZGY' , 'NOA' , 'RGLSF' , 'IXHL' , 'PNF' , 'NEXOY' , 'FITBP' , 'MNTX' , 'BMTX' , 'COVTY' , 'AGNCO' , 'IVRpB' , 'KIGRY' , 'VNOpL' , 'CIMpB' , 'PKBK' , 'CIVB' , 'BDRBF' , 'CMSpC' , 'NESRF' , 'SCEpH' , 'TLGRF' , 'CPCAY' , 'KHOLY' , 'ALSAW' , 'MCHOY' , 'GFCOF' , 'FISB' , 'CIMpA' , 'SMHI' , 'NBY' , 'MOND' , 'GPMTpA' , 'CDRpC' , 'TRTXpC' , 'TWOpA' , 'MFGI' , 'MIDLF' , 'RWCRF' , 'MBINO' , 'GAYGF' , 'IHSZF' , 'PRMRF' , 'GECC' , 'BHB' , 'PARG' , 'POFCY' , 'GDC' , 'AIRG' , 'TWOpC' , 'HIE' , 'ELMGF' , 'NKG' , 'XAUMF' , 'PETRY' , 'CET' , 'GEF/B' , 'RDUFF' , 'WRBpF' , 'REFI' , 'MOR' , 'SWGAY' , 'KMDA' , 'DLNGpA' , 'BLPH' , 'PW' , 'JEQ' , 'CHSCL' , 'CCOOF' , 'GRYCF' , 'LEGH' , 'DNIF' , 'ACNT' , 'APELY' , 'HALL' , 'ISUZY' , 'MFApB' , 'MYN' , 'BIPpB' , 'MLGF' , 'CLDTpA' , 'KNRRY' , 'HSPOR' , 'WWACW' , 'APGNW' , 'NSTC' , 'SBT' , 'ESLOY' , 'SNAL' , 'GAYMD' , 'VIVK' , 'MFV' , 'FSBW' , 'MIELY' , 'BYNOU' , 'ENDV' , 'TFCpI' , 'VIAO' , 'FRTX' , 'FOXO/WS' , 'TRUMY' , 'JHS' , 'BFC' , 'DLTNF' , 'STHZF' , 'BNTGY' , 'OAKpB' , 'SFR' , 'NVX' , 'UNTY' , 'SEOVF' , 'AHLpD' , 'DCF' , 'NREF' , 'SLLDY' , 'WRBpH' , 'SCCE' , 'LGGNY' , 'DYNT' , 'SRT' , 'MVNT' , 'LTGHY' , 'PYCMF' , 'RTMNF' , 'LBYE' , 'PULM' , 'RVLP' , 'ATAQ' , 'CRWS' , 'GROW' , 'OFS' , 'HBANM' , 'GBMIF' , 'NVZMY' , 'DTST' , 'PSApI' , 'ENX' , 'TRRGF' , 'NIMC' , 'FSBC' , 'FRGI' , 'CLLXF' , 'SHCAY' , 'ACAX' , 'EQTRF' , 'ALKFF' , 'PLSH' , 'DBRGpH' , 'BHM' , 'FGOVF' , 'SGNLF' , 'ADRA' , 'JJN' , 'JVA' , 'BNRE' , 'MEAUF' , 'KVLQF' , 'CMRZF' , 'SSRSF' , 'USHAF' , 'OLNCF' , 'GSPE' , 'CING' , 'QUEXF' , 'MGRB' , 'BPAC' , 'DHCC' , 'FGBI' , 'TRTL/WS' , 'AEY' , 'APEOF' , 'HLLPF' , 'MDJH' , 'PDYPY' , 'ERNA' , 'WLDPF' , 'SGG' , 'NXOPF' , 'DNZOY' , 'NWITY' , 'VIRC' , 'GLSI' , 'STRR' , 'RGDFF' , 'ACKRF' , 'ALTAF' , 'AGNCP' , 'RYSKF' , 'FMCXF' , 'BUKS' , 'BUDZ' , 'IRS/WS' , 'VNOpN' , 'CFGpD' , 'BON' , 'FULTP' , 'NXG' , 'VDMCY' , 'KREVF' , 'TYIDY' , 'OSAAW' , 'TSQ' , 'GRNL' , 'FEMY' , 'TWRFF' , 'MTBpH' , 'SMMYY' , 'DOMWF' , 'GGLDF' , 'ECTM' , 'IVCPW' , 'GLpD' , 'FPRGF' , 'PGP' , 'PTNR' , 'ELTP' , 'BLPG' , 'ACR' , 'OIIIF' , 'NTRSO' , 'SAXPY' , 'NDBKY' , 'CMSQY' , 'KRMD' , 'NRIM' , 'FNMAT' , 'UPC' , 'DFKCY' , 'HBEID' , 'MAKSY' , 'IBDSF' , 'CWBC' , 'ALLpI' , 'BKTI' , 'PIFR' , 'VEOEY' , 'TTP' , 'OAKpA' , 'TSKFF' , 'MIXT' , 'ESSA' , 'AELpA' , 'NWVCF' , 'MBINN' , 'XELB' , 'IPRC' , 'VLEEY' , 'AHLpC' , 'NAMSW' , 'EVOK' , 'TOYOF' , 'TSAT' , 'RFMCF' , 'ATCOpD' , 'FOBIF' , 'GARWF' , 'MFD' , 'DDDX' , 'HROWL' , 'LRGR' , 'VLKPF' , 'SCKT' , 'QTCI' , 'THLLY' , 'CHYHY' , 'BNEFF' , 'ESCA' , 'NPV' , 'PBIpB' , 'OWRDF' , 'TWOpB' , 'FPAY' , 'ARRpC' , 'NXDTpA' , 'QCCUF' , 'SMTK' , 'WNNR/WS' , 'CWSFF' , 'AFBI' , 'REVRQ' , 'NBO' , 'SAGGF' , 'MMMW' , 'INSO' , 'PRTH' , 'GEG' , 'EGFEY' , 'NYMTZ' , 'FUAPF' , 'PARAP' , 'KBCSY' , 'AGMpF' , 'CRD/A' , 'SGC' , 'LFAC' , 'DHIL' , 'ABCP' , 'XGN' , 'CORRpA' , 'IHTA' , 'AGBA' , 'CMREpE' , 'CLBEY' , 'GNCAQ' , 'GBNH' , 'SLGpI' , 'FLYNF' , 'HOCPY' , 'ABRpD' , 'BTTR' , 'PGLDF' , 'TBCP' , 'RNECF' , 'AGNCM' , 'UURAF' , 'BZLFY' , 'GSQD/U' , 'CPNFF' , 'TVCCF']

# %%
if Update_or_Delete == 'Update':
    Master_List = Companies_that_need_updating()
    print(len(Master_List))
# Out:
# 292

# %% [markdown]
# # Getting into the Main Code File

# %%
today = datetime.today()
Current_Year = int(today.year)

# NYSE
# Master_List = ['TSLA' , 'AMZN' , 'INTC' , 'AAPL' , 'NVDA' , 'MSFT' , 'RIVN' , 'MARA' , 'SOFI' , 'SNAP' , 'SHOP' , 'PLUG' , 'PLTR' , 'LCID' , 'META' , 'UBER' , 'GOOG' , 'GOLD' , 'LUMN' , 'ITUB' , 'VALE' , 'CVNA' , 'PARA' , 'XPEV' , 'AFRM' , 'SIRI' , 'LYFT' , 'JBLU' , 'CFLT' , 'FTCH' , 'CSCO' , 'COIN' , 'DKNG' , 'HZNP' , 'SCHW' , 'HBAN' , 'RIOT' , 'BABA' , 'AGNC' , 'ERIC' , 'PYPL' , 'MRVL' , 'COSM' , 'NCLH' , 'RBLX' , 'ELAN' , 'BILI' , 'PINS' , 'CHPT' , 'PTON' , 'ROKU' , 'NFLX' , 'CTRA' , 'FLEX' , 'TEVA' , 'QCOM' , 'ORCL' , 'AVTR' , 'LBRT' , 'DDOG' , 'PANW' , 'MBLY' , 'SPCE' , 'LAZR' , 'FTNT' , 'SBUX' , 'MUFG' , 'INFY' , 'ALLY' , 'STNE' , 'CRWD' , 'MLCO' , 'RDFN' , 'NYCB' , 'AMAT' , 'HOOD' , 'FITB' , 'WOLF' , 'LEVI' , 'CLVT' , 'IOVA' , 'TOST' , 'ARRY' , 'VTRS' , 'PACB' , 'COTY' , 'FSTX' , 'DISH' , 'AXTA' , 'ABNB' , 'NVAX' , 'WYNN' , 'MDLZ' , 'BEKE' , 'MCHP' , 'VIRT' , 'SABR' , 'NDAQ' , 'DASH' , 'EQNR' , 'PATH' , 'ABBV' , 'BORR' , 'PSTG' , 'AMCR' , 'CPNG' , 'UPST' , 'SNOW' , 'AQUA' , 'TCOM' , 'STLA' , 'EBAY' , 'SMFG' , 'ATVI' , 'NOVA' , 'TWLO' , 'PAGS' , 'TGTX' , 'SHEL' , 'VIPS' , 'TMUS' , 'ARMK' , 'ATCO' , 'SPWR' , 'STLD' , 'CTVA' , 'GILD' , 'PTEN' , 'ENPH' , 'STEM' , 'PAAS' , 'EXTR' , 'ENVX' , 'BLUE' , 'EVGO' , 'CHWY' , 'CTSH' , 'FREY' , 'BLDP' , 'PEAK' , 'AUPH' , 'VICI' , 'CTIC' , 'NWSA' , 'RITM' , 'KALA' , 'SUMO' , 'CPRX' , 'NXPI' , 'NVST' , 'GOOS' , 'CHGG' , 'MTCH' , 'TECK' , 'DOCU' , 'CTLT' , 'PAGP' , 'CNHI' , 'TDOC' , 'VNET' , 'FAST' , 'CUBI' , 'MOMO' , 'PCAR' , 'MGNI' , 'FSLY' , 'INVH' , 'BOOT' , 'SHLS' , 'MNKD' , 'IRWD' , 'HUYA' , 'TROW' , 'COMM' , 'ALIT' , 'GBTC' , 'AMGN' , 'FNGU' , 'UNIT' , 'LRCX' , 'CARR' , 'UMPQ' , 'SAND' , 'AVGO' , 'ARCC' , 'ETRN' , 'NINE' , 'SBSW' , 'FANG' , 'ALGM' , 'ETSY' , 'MRNA' , 'CBAY' , 'AZUL' , 'ADBE' , 'NTAP' , 'ONON' , 'TSCO' , 'FUTU' , 'PAYO' , 'DXCM' , 'EHTH' , 'NAVI' , 'LTHM' , 'SGFY' , 'PLRX' , 'FOXA' , 'EWBC' , 'VTNR' , 'SKIN' , 'ASAN' , 'ETHE' , 'STOR' , 'CADE' , 'FSLR' , 'EXEL' , 'FIGS' , 'GEHC' , 'GNTX' , 'HOLX' , 'VIVO' , 'FISV' , 'GLOP' , 'VLAT' , 'STWD' , 'OKTA' , 'AZEK' , 'FATE' , 'BBWI' , 'BLDR' , 'DOCS' , 'TEAM' , 'JNPR' , 'VOYA' , 'FOLD' , 'CENX' , 'MNST' , 'CSGP' , 'ROST' , 'DVAX' , 'DINO' , 'ALLO' , 'CHTR' , 'NEOG' , 'RADI' , 'CFFN' , 'VERU' , 'EXPE' , 'ISEE' , 'BILL' , 'EXAS' , 'AVDX' , 'ISRG' , 'CLNE' , 'CALX' , 'GENI' , 'EURN' , 'EDIT' , 'LESL' , 'SYNH' , 'LULU' , 'COUP' , 'HIMX' , 'FNGD' , 'WDAY' , 'UUUU' , 'HOUS' , 'GTLB' , 'PAYX' , 'BIDU' , 'SWKS' , 'KLAC' , 'PAYA' , 'CRDO' , 'DELL' , 'PSNY' , 'HTHT' , 'ANET' , 'ONEM' , 'CPRT' , 'DLTR' , 'RVNC' , 'LHCG' , 'STNG' , 'PACW' , 'ASML' , 'COST' , 'LICY' , 'BXMT' , 'INCY' , 'HSBC' , 'BSAC' , 'SPGI' , 'SAVA' , 'SITC' , 'SPOT' , 'ORCC' , 'SPLK' , 'NATI' , 'XRAY' , 'APPS' , 'YUMC' , 'LSPD' , 'MTDR' , 'MTAL' , 'AJRD' , 'RPRX' , 'SMAR' , 'DADA' , 'HAYW' , 'BMBL' , 'BCRX' , 'BF/B' , 'ESTC' , 'YEXT' , 'BYND' , 'MRTX' , 'GPRO' , 'NTRS' , 'ASTL' , 'GOGL' , 'ACAD' , 'FRSH' , 'SCLX' , 'EMBC' , 'DOMO' , 'ZION' , 'EXPI' , 'OTIS' , 'NARI' , 'BMRN' , 'ACVA' , 'SILV' , 'CBRE' , 'TRIP' , 'AAWW' , 'VRTX' , 'AMYT' , 'PLXS' , 'INFN' , 'ALCC' , 'ROIV' , 'HIMS' , 'INTU' , 'BOWL' , 'ARHS' , 'BRKL' , 'TREX' , 'QRVO' , 'WELL' , 'TGNA' , 'QFIN' , 'PENN' , 'JBGS' , 'PTRA' , 'CPRI' , 'VRRM' , 'TTWO' , 'DCGO' , 'COLB' , 'YETI' , 'CUBE' , 'FIVN' , 'APLS' , 'ASPS' , 'HLMN' , 'ACGL' , 'URBN' , 'DBRG' , 'TRGP' , 'ENTG' , 'CHRW' , 'VIAV' , 'CIEN' , 'ALGN' , 'FGEN' , 'HSIC' , 'STKL' , 'MPLX' , 'BHLB' , 'BLMN' , 'VKTX' , 'RVLV' , 'VTYX' , 'PSEC' , 'BBVA' , 'BBIO' , 'CMCA' , 'GBDC' , 'COLD' , 'CROX' , 'NTNX' , 'ESTE' , 'RLAY' , 'INVZ' , 'BIGC' , 'NTES' , 'MNTV' , 'ABCL' , 'ENLC' , 'CNCE' , 'KEYS' , 'CSIQ' , 'VRNS' , 'ALKS' , 'HOPE' , 'FLNC' , 'RETA' , 'USFD' , 'LMND' , 'AEHR' , 'ANAB' , 'NTLA' , 'VSCO' , 'EXPD' , 'ACMR' , 'TALO' , 'GNRC' , 'FOUR' , 'CEIX' , 'ESPR' , 'SCCO' , 'GLBE' , 'BIGZ' , 'PUMP' , 'DNUT' , 'FORG' , 'SCRM' , 'BALL' , 'MCRB' , 'LYTS' , 'WOOF' , 'SBLK' , 'BSBR' , 'LOGI' , 'PRVB' , 'SBNY' , 'APTV' , 'SRPT' , 'HCAT' , 'NTCT' , 'RPAY' , 'CVBF' , 'HLIT' , 'ETWO' , 'CRBG' , 'SNDX' , 'GLNG' , 'TWST' , 'APLE' , 'SGEN' , 'UNVR' , 'ABCB' , 'BPOP' , 'CRSP' , 'CVLG' , 'EVRG' , 'CDLX' , 'LSCC' , 'APEN' , 'TNDM' , 'MDRX' , 'CLFD' , 'ACDI' , 'ADSK' , 'BERY' , 'ALSN' , 'FYBR' , 'PRGO' , 'NVRO' , 'VHNA' , 'INVA' , 'NCNO' , 'CDNS' , 'CCTS' , 'STAG' , 'GWRE' , 'AMKR' , 'ADPT' , 'BROS' , 'OCSL' , 'SSRM' , 'OXLC' , 'OSTK' , 'HUBS' , 'MELI' , 'HALO' , 'DMTK' , 'REXR' , 'FINV' , 'NTRA' , 'AXAC' , 'SSNC' , 'FBIN' , 'VNOM' , 'SBRA' , 'RELY' , 'OLPX' , 'GTES' , 'VRSK' , 'BXSL' , 'ARES' , 'TECH' , 'RMBS' , 'CHKP' , 'AKAM' , 'MSDA' , 'TSVT' , 'BLNK' , 'PDCE' , 'GBCI' , 'MANU' , 'CCEP' , 'FROG' , 'PGRE' , 'INDI' , 'AMPS' , 'PLAY' , 'RELX' , 'NOMD' , 'ABCM' , 'ATAT' , 'FULT' , 'CVAC' , 'GLPI' , 'ACCD' , 'TIGO' , 'TGAA' , 'ASPN' , 'LAUR' , 'CHRS' , 'AMBP' , 'DCPH' , 'DOCN' , 'MAXR' , 'FWBI' , 'KNBE' , 'ORGN' , 'TTMI' , 'ADEA' , 'KALV' , 'IONS' , 'ODFL' , 'XPRO' , 'SONO' , 'FLYW' , 'IMVT' , 'SMCI' , 'VIST' , 'AXON' , 'PRTS' , 'OLLI' , 'SEIC' , 'IDXX' , 'ICPT' , 'SAVE' , 'EPRT' , 'PTGX' , 'PPBI' , 'COOP' , 'IBKR' , 'INMD' , 'SBCF' , 'UPWK' , 'GTHX' , 'RAPT' , 'PLNT' , 'ARNC' , 'TMHC' , 'CALM' , 'NBIX' , 'FERG' , 'BWEN' , 'NVCR' , 'NXGN' , 'BRBR' , 'CDAY' , 'DWAC' , 'COHR' , 'CARG' , 'PARR' , 'ASTS' , 'FFWM' , 'TVTX' , 'CMRE' , 'CDXS' , 'LITE' , 'GTAC' , 'ILMN' , 'INSM' , 'ZLAB' , 'GDDY' , 'CDNA' , 'PLYA' , 'PRMW' , 'SWTX' , 'SIVB' , 'LPSN' , 'CCCS' , 'YELP' , 'SEMR' , 'BLEU' , 'PLTK' , 'BURL' , 'SEDG' , 'GRFS' , 'WRBY' , 'RYAM' , 'CAKE' , 'MNSO' , 'APGB' , 'DSEY' , 'MODG' , 'CERT' , 'SNDR' , 'TENB' , 'MERC' , 'MRVI' , 'PFGC' , 'VUZI' , 'RARE' , 'MSCI' , 'MKSI' , 'RVMD' , 'TROX' , 'REPL' , 'VEEV' , 'BZUN' , 'WTTR' , 'ARCO' , 'BAND' , 'SONY' , 'ECVT' , 'GMAB' , 'ARWR' , 'RCUS' , 'AVXL' , 'KTOS' , 'HAIN' , 'TRMB' , 'AMLX' , 'RXRX' , 'PGNY' , 'TSLX' , 'LDOS' , 'SASR' , 'HTGC' , 'COUR' , 'VVNT' , 'ADNT' , 'THRX' , 'SWBI' , 'BRZE' , 'NVCT' , 'ACIW' , 'VAQC' , 'GGAL' , 'KMPR' , 'KRNY' , 'FVRR' , 'XMTR' , 'HOMB' , 'LUNG' , 'RCKT' , 'AXSM' , 'IMAX' , 'WTRG' , 'EOLS' , 'MEKA' , 'CBOE' , 'BIIB' , 'SGRY' , 'OPCH' , 'ANSS' , 'SLGN' , 'EVRI' , 'ALNY' , 'ESNT' , 'CMPR' , 'TRMK' , 'SHAK' , 'GRMN' , 'NMRK' , 'OTEX' , 'SNPS' , 'FIBK' , 'AMBC' , 'FFIV' , 'LNTH' , 'GPRE' , 'PNFP' , 'QGEN' , 'TIMB' , 'PERI' , 'PRVA' , 'BNTX' , 'ZYME' , 'CTKB' , 'BRKR' , 'PFLT' , 'ROIC' , 'GRPN' , 'TWNK' , 'JBHT' , 'VERA' , 'AIRC' , 'VCYT' , 'PTCT' , 'CUTR' , 'SMPL' , 'CSTM' , 'MYGN' , 'GTLS' , 'MRSN' , 'GCMG' , 'POST' , 'ETNB' , 'DENN' , 'AGCO' , 'CIVI' , 'VMGA' , 'SANM' , 'FRXB' , 'APMI' , 'NWBI' , 'SMTC' , 'AACI' , 'KURA' , 'MRTN' , 'CYTK' , 'IDCC' , 'MKTX' , 'ALLK' , 'ZETA' , 'BHVN' , 'AMCX' , 'KYMR' , 'PDCO' , 'VTLE' , 'ECAT' , 'UCBI' , 'ADTN' , 'GOGO' , 'HCSG' , 'WFRD' , 'TRMD' , 'NEXT' , 'HUBB' , 'COGT' , 'RGEN' , 'SQSP' , 'UBSI' , 'ACLS' , 'AROC' , 'ARQT' , 'BWXT' , 'CNOB' , 'GMRE' , 'FLWS' , 'VERI' , 'IFIN' , 'JAZZ' , 'LPRO' , 'PHAT' , 'GHIX' , 'AGTI' , 'TASK' , 'WERN' , 'BMEZ' , 'DXLG' , 'TPIC' , 'MITA' , 'REZI' , 'IART' , 'PCOR' , 'ARCH' , 'PCTY' , 'VSAT' , 'AZTA' , 'SHOO' , 'HOLO' , 'TREE' , 'AXNX' , 'AMPY' , 'MODN' , 'AGRO' , 'SIGA' , 'HAIA' , 'CELH' , 'RYTM' , 'DALS' , 'BBDC' , 'SDRL' , 'RAMP' , 'GMFI' , 'FLNG' , 'METC' , 'BEAM' , 'PCVX' , 'BEPC' , 'DSGN' , 'ULCC' , 'TWOU' , 'DICE' , 'CGNX' , 'SFNC' , 'FULC' , 'ORAN' , 'TMST' , 'CASH' , 'CRNC' , 'THRY' , 'EZPW' , 'SAIA' , 'EVBG' , 'EWCZ' , 'SBAC' , 'FIVE' , 'STAR' , 'CSLM' , 'MXCT' , 'LGST' , 'BLUA' , 'MMYT' , 'WING' , 'NTST' , 'LFAC' , 'LPLA' , 'NVSA' , 'SEAS' , 'LQDA' , 'ARLP' , 'COWN' , 'MAXN' , 'KROS' , 'MSTR' , 'IRBT' , 'FORM' , 'KDNY' , 'XNCR' , 'CORT' , 'TXRH' , 'JUGG' , 'GSBD' , 'ROCL' , 'DESP' , 'ATKR' , 'VRNT' , 'IHRT' , 'ACRE' , 'CYRX' , 'ALLE' , 'VERV' , 'BCAT' , 'RGLD' , 'CINF' , 'ULTA' , 'EVER' , 'GLOB' , 'PZZA' , 'AMBA' , 'SLCA' , 'SAGE' , 'CHEF' , 'TCBI' , 'SCAQ' , 'MIRM' , 'JWSM' , 'NMIH' , 'KRNT' , 'CRBU' , 'AZPN' , 'MMSI' , 'NKTX' , 'KLIC' , 'JKHY' , 'CRNX' , 'CRSR' , 'NTCO' , 'CABA' , 'BSTZ' , 'MNDY' , 'AMPL' , 'MNRO' , 'DECK' , 'WRLD' , 'SCVL' , 'MIDD' , 'PLAB' , 'JACK' , 'BPMC' , 'NMFC' , 'CTRE' , 'CXAC' , 'NEON' , 'SWAV' , 'LADR' , 'HESM' , 'BFAM' , 'AHCO' , 'BANC' , 'WASH' , 'SGML' , 'BTAI' , 'RACE' , 'CLAR' , 'VBTX' , 'ALEC' , 'ANGO' , 'CATY' , 'EQIX' , 'MASS' , 'IMAB' , 'ATEN' , 'HASI' , 'CEQP' , 'ATEC' , 'PECO' , 'RXDX' , 'ORLY' , 'CRUS' , 'GOLF' , 'DAWN' , 'CACI' , 'LSTR' , 'ICLR' , 'FRPT' , 'VRSN' , 'MSEX' , 'SBGI' , 'ALHC' , 'MGNX' , 'WAFD' , 'SKYT' , 'APPN' , 'JELD' , 'PYCR' , 'REGN' , 'LWLG' , 'PTLO' , 'VRNA' , 'FTDR' , 'ATHM' , 'ALBO' , 'CDMO' , 'OSUR' , 'ESRT' , 'UDMY' , 'NUVA' , 'CMPS' , 'ARVN' , 'MYOV' , 'HDSN' , 'IBER' , 'DOLE' , 'AMAL' , 'TRNO' , 'HEES' , 'LECO' , 'GLDD' , 'VNDA' , 'STGW' , 'GDOT' , 'ELME' , 'FOSL' , 'LILA' , 'OSBC' , 'IRDM' , 'DRVN' , 'TMDX' , 'PODD' , 'MSpE' , 'MCFT' , 'PETS' , 'FRBA' , 'BRSP' , 'PDSB' , 'RUTH' , 'SSYS' , 'PCRX' , 'INDB' , 'VREX' , 'ALVR' , 'STAA' , 'BGNE' , 'ATAK' , 'CARA' , 'NOTV' , 'PINC' , 'GATO' , 'DNOW' , 'TBPH' , 'PMVP' , 'PRPL' , 'GIII' , 'LAMR' , 'CCRN' , 'PRTA' , 'HBNC' , 'SBOW' , 'MTSI' , 'OMCL' , 'LIVN' , 'VSTO' , 'OFIX' , 'NNOX' , 'ITCI' , 'SGII' , 'INSW' , 'EVCM' , 'MLVF' , 'PWSC' , 'ZUMZ' , 'RMBL' , 'INGR' , 'STEP' , 'WTFC' , 'NSTG' , 'LEGN' , 'AKRO' , 'COHU' , 'BAER' , 'ENOV' , 'DUOL' , 'AIMC' , 'QURE' , 'MNTK' , 'NRDS' , 'GPMT' , 'MLKN' , 'NEWR' , 'SAIC' , 'ICHR' , 'CYBR' , 'TRTN' , 'MPWR' , 'FTEV' , 'ENVA' , 'BGFV' , 'GBIO' , 'PUBM' , 'SITE' , 'FFIN' , 'HIBB' , 'CBSH' , 'CSAN' , 'UCTT' , 'ACRS' , 'CONN' , 'CVLT' , 'QNST' , 'GMED' , 'CWEN' , 'MFGP' , 'BOKF' , 'FTAI' , 'GSQB' , 'COLL' , 'TSEM' , 'ZIMV' , 'ANNX' , 'SLVM' , 'BECN' , 'DNLI' , 'PRDO' , 'PETQ' , 'GSQD' , 'GOOD' , 'TNET' , 'CLBK' , 'CINC' , 'ACET' , 'NBTB' , 'RYAN' , 'STET' , 'FNKO' , 'ACAH' , 'PRPC' , 'ATRO' , 'AVNT' , 'PACK' , 'CRGY' , 'PEGA' , 'EPAM' , 'CHRD' , 'MATX' , 'CECO' , 'HELE' , 'BXMX' , 'RAIN' , 'FCPT' , 'SYNA' , 'APAM' , 'NXST' , 'EHAB' , 'HRMY' , 'CPTK' , 'MLTX' , 'ALDX' , 'SDGR' , 'TRUP' , 'PLTN' , 'PRIM' , 'LFST' , 'CTAS' , 'REYN' , 'PFSI' , 'RMNI' , 'NBXG' , 'GDYN' , 'AMRC' , 'TWOA' , 'POWI' , 'ACDC' , 'ONTF' , 'STRL' , 'OCFC' , 'VLRS' , 'UHAL' , 'STRO' , 'KNOP' , 'RNST' , 'SPNT' , 'INBX' , 'ESMT' , 'CEPU' , 'HAYN' , 'INSP' , 'PAYC' , 'UTHR' , 'MTVC' , 'VERX' , 'IIPR' , 'LOVE' , 'CNNE' , 'NDSN' , 'THMO' , 'SCHN' , 'INSE' , 'TFSL' , 'BRCC' , 'ROCC' , 'CHMI' , 'CERE' , 'TWKS' , 'SFBS' , 'ALTI' , 'QLYS' , 'BUSE' , 'EEFT' , 'UNFI' , 'BJRI' , 'CLDX' , 'ZNTL' , 'CNXC' , 'BKNG' , 'SSTK' , 'NTGR' , 'CETX' , 'CBRL' , 'MEOH' , 'ITOS' , 'NBHC' , 'CREC' , 'MRNS' , 'ACLX' , 'CODI' , 'MLNK' , 'XENE' , 'AGIO' , 'TBBK' , 'EXFY' , 'PANL' , 'RCII' , 'ASUR' , 'RSKD' , 'INFA' , 'ACHC' , 'WEBR' , 'AVDL' , 'VCEL' , 'QTWO' , 'FICO' , 'QDEL' , 'LANV' , 'MASI' , 'TFIN' , 'DMLP' , 'MGPI' , 'UMBF' , 'VZIO' , 'FSNB' , 'SIBN' , 'NFBK' , 'ZBRA' , 'KNSA' , 'HLNE' , 'JANX' , 'VECO' , 'DAVA' , 'PRGS' , 'RGNX' , 'EGRX' , 'SEAT' , 'ACCO' , 'GRBK' , 'AURA' , 'BLFS' , 'PSFE' , 'NAAS' , 'PLCE' , 'HUDI' , 'CNMD' , 'NOAH' , 'LIND' , 'AMED' , 'OPNT' , 'BIPC' , 'SNCY' , 'EFXT' , 'TFPM' , 'SCPH' , 'CLBT' , 'IMTX' , 'OLED' , 'JAMF' , 'ERII' , 'VPCB' , 'GKOS' , 'BCSF' , 'CCOI' , 'POOL' , 'DMYS' , 'TITN' , 'BALY' , 'HROW' , 'TUSK' , 'HONE' , 'ATSG' , 'SNBR' , 'CSWC' , 'FFBC' , 'VICR' , 'SLAB' , 'CCCC' , 'REVE' , 'AXGN' , 'ITRI' , 'HTLD' , 'SPWH' , 'MATV' , 'PRCT' , 'VRDN' , 'IDYA' , 'MAIN' , 'VCTR' , 'LASR' , 'MOBV' , 'ARIS' , 'UTAA' , 'BNIX' , 'FARO' , 'HCKT' , 'NHIC' , 'FCFS' , 'ATCX' , 'TRIN' , 'SKYW' , 'SUPN' , 'FRHC' , 'NAPA' , 'NETI' , 'HNRG' , 'TNGX' , 'SRCL' , 'LKFN' , 'ATRC' , 'FBRT' , 'SITM' , 'DGNU' , 'CAMT' , 'MDGL' , 'BANR' , 'WSFS' , 'FBNC' , 'AFYA' , 'KREF' , 'LFUS' , 'MSpF' , 'RCFA' , 'PATK' , 'BCTX' , 'AVNS' , 'CKPT' , 'ARCT' , 'LGND' , 'EPAC' , 'BIVI' , 'CTLP' , 'NGMS' , 'PSTX' , 'ASLE' , 'COCO' , 'SIMO' , 'OTTR' , 'CGBD' , 'PGTI' , 'TIXT' , 'FDMT' , 'AMRK' , 'BBCP' , 'KRTX' , 'EVTC' , 'FMNB' , 'RJAC' , 'MANH' , 'SJIJ' , 'SHYF' , 'RELL' , 'RILY' , 'UFPI' , 'CSII' , 'TTEK' , 'NRIX' , 'ATNM' , 'MRCY' , 'OPRT' , 'KMPH' , 'AGYS' , 'PNNT' , 'HCCI' , 'GLAD' , 'IBOC' , 'TOWN' , 'ONTO' , 'TILE' , 'XPAX' , 'EGBN' , 'CWAN' , 'TRCA' , 'ASGN' , 'MTLS' , 'ALRS' , 'FOCS' , 'STER' , 'ENSG' , 'NMCO' , 'SRAD' , 'CRTO' , 'LCII' , 'MITK' , 'FWRG' , 'TMCI' , 'MORF' , 'OPRA' , 'STBA' , 'MLEC' , 'TRTX' , 'PAXS' , 'GDEN' , 'MEDP' , 'IMXI' , 'EBIX' , 'ZYXI' , 'FRME' , 'CWST' , 'FFIC' , 'XFLT' , 'ESAB' , 'KLXE' , 'VITL' , 'MEGI' , 'HUBG' , 'SATS' , 'SRRK' , 'FOXF' , 'ETpC' , 'HAFC' , 'AEIS' , 'NVEI' , 'TGLS' , 'ATMC' , 'DGII' , 'TFII' , 'CGAU' , 'NSSC' , 'SILK' , 'UPLD' , 'IBCP' , 'GSHD' , 'DZSI' , 'CLDT' , 'PRFT' , 'DSKE' , 'ASAI' , 'ARGX' , 'KRYS' , 'DIOD' , 'EGLE' , 'NICE' , 'CHAA' , 'TRAQ' , 'GPRK' , 'KVSA' , 'SCPL' , 'PLYM' , 'STIM' , 'BLKB' , 'EGAN' , 'BCYC' , 'BLFY' , 'OSPN' , 'OBNK' , 'SPRY' , 'ALEX' , 'IBTX' , 'SLRC' , 'XPER' , 'HTBK' , 'NABL' , 'MSGE' , 'LGIH' , 'CTOS' , 'HFRO' , 'RPTX' , 'CARS' , 'ALTR' , 'COLM' , 'ALRM' , 'ALGT' , 'NRGD' , 'WSBC' , 'NPCT' , 'MGTX' , 'NUVL' , 'RONI' , 'URGN' , 'MUSA' , 'IMCR' , 'BLCO' , 'IRTC' , 'HERA' , 'CASY' , 'CION' , 'XPOF' , 'IMMR' , 'GATX' , 'FTHY' , 'KNTK' , 'ARKO' , 'EVOP' , 'VYGR' , 'HFWA' , 'NUWE' , 'PNTG' , 'AFCG' , 'LOCO' , 'PVBC' , 'CHDN' , 'CAAS' , 'CMTG' , 'FRBN' , 'TACT' , 'LAND' , 'MFIC' , 'LOPE' , 'QQQX' , 'TCMD' , 'LBAI' , 'ICVX' , 'ICUI' , 'HZON' , 'ARCB' , 'ACEL' , 'PRTG' , 'AMPH' , 'INDO' , 'NDMO' , 'FLME' , 'HRZN' , 'AOSL' , 'TTGT' , 'NVGS' , 'ROAD' , 'IIIV' , 'ALXO' , 'AIRS' , 'DFIN' , 'PLMR' , 'ENFN' , 'NSIT' , 'AVID' , 'ASND' , 'HSAQ' , 'LGTO' , 'FLGT' , 'MBUU' , 'GRND' , 'TPVG' , 'CHRA' , 'HTLF' , 'KVSC' , 'EXLS' , 'BFAC' , 'ALKT' , 'IVCP' , 'FSRX' , 'SPNS' , 'EFSC' , 'MTRN' , 'STVN' , 'SPTN' , 'SNEX' , 'VRTV' , 'QTRX' , 'NETC' , 'BIOT' , 'CTAQ' , 'AXTI' , 'PRAA' , 'JRVR' , 'AAON' , 'XAIR' , 'NOVT' , 'RXST' , 'IIIN' , 'ANDE' , 'AMCI' , 'IPGP' , 'ATGE' , 'NESR' , 'SIGI' , 'ALTG' , 'MATW' , 'TRST' , 'SOVO' , 'NXRT' , 'NGVT' , 'ONEW' , 'PRLB' , 'HOLI' , 'SLAM' , 'WIRE' , 'CCNE' , 'ORIC' , 'WABC' , 'USAC' , 'ECPG' , 'ELAT' , 'EPSN' , 'KCGI' , 'DOOR' , 'ENGH' , 'PINE' , 'GRIN' , 'MHUA' , 'DECA' , 'CELC' , 'TLYS' , 'AVAV' , 'CACC' , 'OSIS' , 'ADRA' , 'CSSE' , 'MRUS' , 'KFRC' , 'EQBK' , 'WEST' , 'MLAB' , 'HMST' , 'PIPR' , 'BSIG' , 'AMWD' , 'LOMA' , 'BFST' , 'PEBO' , 'STRA' , 'RRGB' , 'PTVE' , 'ASYS' , 'WLDN' , 'MIXT' , 'IGMS' , 'FBMS' , 'JYNT' , 'SCHL' , 'GILT' , 'GAMB' , 'REVG' , 'RLTY' , 'TCPC' , 'EXAI' , 'SYBT' , 'MSGS' , 'KRUS' , 'CNTY' , 'KAMN' , 'FELE' , 'XPEL' , 'AMPX' , 'GSpK' , 'EARN' , 'PBPB' , 'CCAP' , 'IPAR' , 'PDFS' , 'PRLD' , 'CCSI' , 'GETY' , 'UVSP' , 'PROK' , 'SPSC' , 'SKWD' , 'CLMT' , 'ITGR' , 'CVII' , 'DLTH' , 'PRPH' , 'RLYB' , 'CCAI' , 'NFNT' , 'THRM' , 'MSpO' , 'MODV' , 'BASE' , 'ARDC' , 'HTBI' , 'FEAM' , 'NEWT' , 'QRHC' , 'STEL' , 'IVAC' , 'SDHY' , 'RFMZ' , 'CMTL' , 'CSGS' , 'INTA' , 'MGRC' , 'ERIE' , 'DORM' , 'APPF' , 'HURN' , 'RMAX' , 'OCFT' , 'NOTE' , 'SBSI' , 'HSKA' , 'AMSC' , 'SPXX' , 'TTEC' , 'ENTA' , 'PWUP' , 'GSpJ' , 'SPXC' , 'HOTH' , 'GLpD' , 'DSGX' , 'VOXX' , 'DIAX' , 'AMEH' , 'GDST' , 'GPOR' , 'BWMN' , 'TRMR' , 'NRAC' , 'ALPN' , 'HEAR' , 'OCAX' , 'POWL' , 'ROCK' , 'SRTS' , 'SMWB' , 'THCP' , 'ABST' , 'APEI' , 'EBON' , 'LANC' , 'DCOM' , 'DIBS' , 'RWOD' , 'AVTE' , 'ATLX' , 'MSpA' , 'ACAX' , 'CGEM' , 'PFBC' , 'IBEX' , 'CMPO' , 'NRGU' , 'LUNA' , 'LQDT' , 'MTRX' , 'RLGT' , 'RDWR' , 'HLIO' , 'KNSL' , 'CVGI' , 'FENC' , 'STOK' , 'BMTX' , 'PACI' , 'CTRN' , 'ASIX' , 'TBLD' , 'DCRD' , 'MSpP' , 'CSTL' , 'WKME' , 'CPLP' , 'KIDS' , 'SMHI' , 'MCRI' , 'BMRC' , 'CATC' , 'NAMS' , 'TPBA' , 'INST' , 'BCPC' , 'ABOS' , 'CMLS' , 'PSPC' , 'RCEL' , 'RWAY' , 'SLDB' , 'MACK' , 'TERN' , 'CHUY' , 'FLIC' , 'HSTM' , 'BCBP' , 'GLPG' , 'SAGA' , 'STEW' , 'SPOK' , 'LXFR' , 'FWRD' , 'ICFI' , 'NEXA' , 'ESTA' , 'JJSF' , 'ATOM' , 'RDNT' , 'NDLS' , 'BCOV' , 'BANF' , 'UFPT' , 'CSWI' , 'MITT' , 'CVCO' , 'CTDD' , 'DOOO' , 'NVMI' , 'FIZZ' , 'EVEX' , 'MCBC' , 'AORT' , 'ROOT' , 'FPAC' , 'SIpA' , 'LBPH' , 'QCRH' , 'NVCN' , 'USPH' , 'USAP' , 'SHEN' , 'PSMT' , 'FUND' , 'FDUS' , 'ARGO' , 'RFpB' , 'JAKK' , 'ARYD' , 'TCBK' , 'OPRX' , 'DFLI' , 'ATXS' , 'TXMD' , 'CMCO' , 'AIRG' , 'JILL' , 'KTRA' , 'VRTS' , 'PEPG' , 'LIVB' , 'SMMF' , 'SAFE' , 'NVEC' , 'FRFR' , 'GSpD' , 'KRNL' , 'CRAI' , 'SZZL' , 'DMRC' , 'GAIN' , 'KBAL' , 'CFCX' , 'COHN' , 'CEVA' , 'SDAC' , 'LCUT' , 'TRDA' , 'CHCT' , 'NXDT' , 'CSTE' , 'SURG' , 'NVEE' , 'MSpI' , 'PLUS' , 'BEEM' , 'RFpC' , 'EXPO' , 'APOG' , 'MORN' , 'MSpK' , 'CVRX' , 'HIPO' , 'LMAT' , 'BRDG' , 'CRCT' , 'NMAI' , 'BOOM' , 'ASTE' , 'OMAB' , 'SREA' , 'THFF' , 'INMB' , 'INGN' , 'CSTR' , 'DRIO' , 'MYRG' , 'HGLB' , 'AEFC' , 'NIMC' , 'ENBA' , 'KNTE' , 'DCBO' , 'ADUS' , 'INVE' , 'MPRA' , 'AADI' , 'RCpE' , 'ATEX' , 'TRNS' , 'MACA' , 'ZEUS' , 'USOI' , 'PRME' , 'WDFC' , 'PSTL' , 'SRpA' , 'CMBM' , 'CINT' , 'STRE' , 'CMSD' , 'CHCO' , 'AUDC' , 'ESLT' , 'RICK' , 'AMSF' , 'BNKD' , 'PCYO' , 'WEAV' , 'MFIN' , 'CMCL' , 'TAYD' , 'PTOC' , 'SOHU' , 'IPVI' , 'CAPL' , 'LITT' , 'CTBB' , 'ESGR' , 'IMNM' , 'NECB' , 'RNER' , 'EWTX' , 'ANVS' , 'SRDX' , 'GLRE' , 'BWFG' , 'NPFD' , 'TARS' , 'INBK' , 'KALU' , 'BLBD' , 'TOAC' , 'CABO' , 'SOJD' , 'ETpD' , 'NGVC' , 'RSLS' , 'ANIK' , 'SOJC' , 'DAVE' , 'SEVN' , 'AOMR' , 'DNIF' , 'AVNW' , 'AMTB' , 'PROF' , 'AQNU' , 'VTOL' , 'SOJE' , 'JBSS' , 'LMNR' , 'JOUT' , 'BBLN' , 'HWKN' , 'MSBI' , 'CVGW' , 'GBAB' , 'ACAC' , 'SCUA' , 'EFHT' , 'NRGX' , 'RNGR' , 'HSII' , 'FIAC' , 'BMEA' , 'STKS' , 'PEBK' , 'GSpA' , 'INSI' , 'CLPT' , 'INTT' , 'CATO' , 'BF/A' , 'GBTG' , 'DUET' , 'MGEE' , 'PFSW' , 'QVCD' , 'CDRE' , 'ANIP' , 'SCSC' , 'CNXN' , 'MPAA' , 'PLOW' , 'CPSI' , 'OCCI' , 'UEIC' , 'HOFT' , 'BLZE' , 'PAHC' , 'QVCC' , 'AKYA' , 'SAFT' , 'REFI' , 'CPSS' , 'VSEC' , 'CARE' , 'HALL' , 'CASS' , 'FORR' , 'FLUX' , 'TIPT' , 'CBNK' , 'BBSI' , 'SMHB' , 'BYRN' , 'CWCO' , 'WNEB' , 'PIXY' , 'LAZY' , 'BIPI' , 'NUZE' , 'LSEA' , 'BIOX' , 'BEPH' , 'IOSP' , 'FEIM' , 'HGTY' , 'CRMT' , 'AESC' , 'MYTE' , 'SMLR' , 'SELF' , 'AGAC' , 'TDCX' , 'CTBI' , 'MSpL' , 'CAAP' , 'JGGC' , 'INFU' , 'CRWS' , 'LFCR' , 'BITW' , 'DPSI' , 'GLUE' , 'NRUC' , 'CIGI' , 'BWpA' , 'SGHT' , 'ARCE' , 'INDT' , 'EOCW' , 'ANPC' , 'IQMD' , 'NLCP' , 'OOMA']
# Dividend 
# Master_List = Master_List[:25]
# Master_List = ['MSFT']

start = timer()
Tick_Count =0
error_grouping = {}

x =1
for Ticker in Master_List:
    # Deleting the Ticker if requested to update
    if Update_or_Delete == 'Update':
        Deleting_Company(Ticker)
        
    Tick_Count = Tick_Count + 1
    Remaining_Count = round(len(Master_List)-Tick_Count,0)
    try:
        # Connecting to SEC
        Ticker = Ticker.replace('/','-')
        try:
            CIK = CIK_Finder(Ticker)
        except:
            continue

        ## Basic Company Information 
        url = 'https://data.sec.gov/submissions/CIK'+ CIK +'.json'
        try:
            soup = SEC_link(url)
        except:
            continue
        sic = soup['sic']
        if sic == '':
            continue   
        sic_Description = soup['sicDescription']
        ein = soup['ein']

        #Importing Data into Company Info
        importing_Company_data('company_info')

        ## Fundamental Data 
        url = 'https://data.sec.gov/api/xbrl/companyfacts/CIK'+ CIK + '.json'
        try:
            soup = SEC_link(url)
        except:
            continue

        # Collecting Data
        ## Data Directly From the SEC  
        ### Equity Info
        Split_Hist = Split(1)
        Share_Count = Shares(['WeightedAverageNumberOfDilutedSharesOutstanding'])
        Shares_Outstanding = Shares(['CommonStockSharesOutstanding', 'SharesOutstanding', 'WeightedAverageNumberOfSharesOutstandingBasic'])

        ### Storing Data from Yahoo's Data Analytics  
        Yahoo_data = YAHOO(Ticker)
        nextYR_growth = Yahoo_data[0]
        fiveYR_growth = Yahoo_data[1]
        Ticker = Ticker.replace('-','.')
        price = ThinkORSwim(Ticker)
        Current_Earnings = Yahoo_data[3]
        Future_Earnings = Yahoo_data[4]
        Rev_gr = Yahoo_data[5]
        try :
            Current_PE = round(price/Current_Earnings,2)
        except: 
            Current_PE = None
        Market_Cap = MC_fucntion(Shares_Outstanding, price)

        ### Importing 
        importing_Yahoo_Forecast(nextYR_growth, fiveYR_growth, price , Current_Earnings, Future_Earnings, Rev_gr, Current_PE)
        Original_importing_data('Market_Cap', Market_Cap)

        ### Clearing data, this is so values dont overlap in Yahoo's table
        YahooMySQL = [nextYR_growth, fiveYR_growth, price , Current_Earnings, Future_Earnings, Rev_gr, Current_PE]
        for items in YahooMySQL:
            items = None

        ### Income Statement        
        Revenue = USD_gaap(['Revenues', 'SalesRevenueNet', 'RevenueFromContractWithCustomerExcludingAssessedTax', 'RevenuesNetOfInterestExpense', 'RevenueFromContractWithCustomerIncludingAssessedTax', 'SalesRevenueGoodsNet', 'RevenueFromContractWithCustomerIncludingAssessedTax'])
        RevenueTTM = TTM(Revenue[1])

        Earnings = USD_gaap(['NetIncomeLossAvailableToCommonStockholdersBasic','NetIncomeLoss', 'ProfitLoss', 'NetIncomeLossAvailableToCommonStockholdersBasic'])
        EarningsTTM = TTM(Earnings[1])
        
        ### Balance Sheet
        Cash = USD_gaap(['CashAndCashEquivalentsAtCarryingValue', 'CashCashEquivalentsAndShortTermInvestments', 'CashAndDueFromBanks'])[1]        
        Property_Equipment = USD_gaap(['PropertyPlantAndEquipmentNet', 'PaymentsToAcquirePropertyPlantAndEquipment', 'RealEstateInvestmentPropertyAtCost', 'RealEstateInvestmentPropertyNet', 'PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetAfterAccumulatedDepreciationAndAmortization'])[1]
        Current_Debt = USD_gaap(['LongTermDebtCurrent', 'DebtCurrent', 'NotesPayableCurrent','UnsecuredDebtCurrent', 'LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths', 'LongTermDebtAndCapitalLeaseObligationsCurrent', 'OperatingLeaseLiabilityCurrent','AccruedLiabilitiesCurrent', 'LongTermDebtAndFinanceLeasesCurrent', 'ShortTermBorrowings', 'RepaymentsOfLinesOfCredit'])[1]
        Long_Term_Debt = USD_gaap(['LongTermDebtNoncurrent', 'LongTermDebt', 'LongTermNotesAndLoans', 'LongTermDebtAndFinanceLeasesNoncurrent', 'OperatingLeaseLiabilityNoncurrent', 'LongTermDebtAndCapitalLeaseObligations', 'LongTermDebtAndCapitalLeaseObligations'])[1]
        Total_Debt =USD_gaap(['DebtAndCapitalLeaseObligations', 'DebtandFinanceLeaseLiabilities', 'NotesPayable', 'LoansPayable'])[1]
        Total_current_Liabilites = USD_gaap(['LiabilitiesCurrent'])[1]
        Total_Long_Term_Liabilities = USD_gaap(['LiabilitiesNoncurrent'])[1] 
        Total_Liabilities = USD_gaap(['Liabilities'])[1]
        Equity = USD_gaap(['StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest', 'StockholdersEquity'])[1]
        Liabilities_And_StockholdersEquity = USD_gaap(['LiabilitiesAndStockholdersEquity', 'Assets'])[1]

        ### Cashflow Statement
        Operating_Cash_Flow = USD_gaap(['NetCashProvidedByUsedInOperatingActivities', 'NetCashProvidedByUsedInOperatingActivitiesContinuingOperations'])
        Div_Cash = USD_gaap(['Dividends', 'PaymentsOfDividendsCommonStock', 'DividendsCommonStockCash', 'PaymentsOfDividends', 'PaymentsOfOrdinaryDividends', 'PaymentsOfDividendsCommonStock'])[0]
        Div_per_Share = USD_gaap_per_shares(['CommonStockDividendsPerShareDeclared', 'CommonStockDividendsPerShareCashPaid', 'CommonStockDividendsAndDividendEquivalentsPerShareDeclared'])[0]

        ## Auto Fill Missing Numbers with Calculations
        for num in range(3):
            ### Balance Sheet
            Calc1_Current_Debt = Subtraction(Total_Debt, Long_Term_Debt)
            Current_Debt = Append(Current_Debt, Calc1_Current_Debt)

            Calc1_Long_Term_Debt = Subtraction(Total_Debt, Current_Debt)
            Long_Term_Debt = Append(Long_Term_Debt, Calc1_Long_Term_Debt)

            Calc1_Total_Debt = Addition(Current_Debt, Long_Term_Debt)
            Total_Debt = Append(Total_Debt, Calc1_Total_Debt)

            Calc1_Total_current_Liabilites = Subtraction(Total_Liabilities, Total_Long_Term_Liabilities)
            Total_current_Liabilites = Append(Total_current_Liabilites, Calc1_Total_current_Liabilites)

            Calc1_Total_Long_Term_Liabilities = Subtraction(Total_Liabilities, Total_current_Liabilites)
            Calc2_Total_Long_Term_Liabilities = Addition(Equity, Total_current_Liabilites)
            Calc2_Total_Long_Term_Liabilities = Subtraction(Liabilities_And_StockholdersEquity, Calc2_Total_Long_Term_Liabilities)
            Appended1 = Append(Calc1_Total_Long_Term_Liabilities,Calc2_Total_Long_Term_Liabilities)
            Total_Long_Term_Liabilities = Append(Total_Long_Term_Liabilities,Appended1)

            Calc1_Total_Liabilities = Subtraction(Liabilities_And_StockholdersEquity, Equity)
            Total_Liabilities = Append(Total_Liabilities, Calc1_Total_Liabilities)
            
            Calc1_Equity = Subtraction(Liabilities_And_StockholdersEquity, Total_Liabilities)
            Equity = Append(Equity, Calc1_Equity)
            
        ### Cash Flow Statement
        Calc1Div_per_Share = Division(Div_Cash,Shares_Outstanding)
        Div_per_Share = Append(Div_per_Share,Calc1Div_per_Share)


        ## Calculated Values numbers the SEC does not Offer 
        ### Gaap
        Earnings_per_share = Division(Earnings[0],Share_Count)

        ### Non-gaap
        Free_Cash_Flow = Subtraction(Operating_Cash_Flow[0],Property_Equipment)
        Levered_Free_Cash_Flow = Subtraction(Free_Cash_Flow,Current_Debt)
        Total_LTL_per_LFCF = Division_Flipped(Total_Long_Term_Liabilities, Levered_Free_Cash_Flow)
        
        CashperTotalDebt = Division(Cash,Total_Debt)
        Total_Debt_to_Equity = Division(Total_Debt, Equity)
        
        
        #Storing Data to from SEC
        ## Income Statement  
        importing_data('Revenue', Revenue[0])
        importing_data('Revenue', RevenueTTM)
        Combination_of_Calc_Func('Revenue', Revenue[0], ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        Combination_of_Calc_Func('Revenue', RevenueTTM, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        
        importing_data('Earnings', Earnings[0])
        importing_data('Earnings', EarningsTTM)
        Combination_of_Calc_Func('Earnings', Earnings[0], ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        Combination_of_Calc_Func('Earnings', EarningsTTM, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        
        ## Balance Sheet 
        importing_data('Cash', Cash)
        Combination_of_Calc_Func('Cash', Cash, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        
        importing_data('Total_Debt', Total_Debt)
        Combination_of_Calc_Func('Total_Debt', Total_Debt, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        
        importing_data('Long_term_Liabilites', Total_Long_Term_Liabilities)
        Combination_of_Calc_Func('Long_term_Liabilites', Total_Long_Term_Liabilities, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        
        ## Calculated Functions  
        importing_data('Earnings_Per_Share', Earnings_per_share)
        Combination_of_Calc_Func('Earnings_Per_Share', Earnings_per_share, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])

        importing_data('Div_per_Share', Div_per_Share)
        Combination_of_Calc_Func('Div_per_Share', Div_per_Share, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        
        importing_data('Levered_Free_Cash_Flow', Levered_Free_Cash_Flow)
        Combination_of_Calc_Func('Levered_Free_Cash_Flow', Levered_Free_Cash_Flow, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        
        importing_data('Total_LTL_per_LFCF', Total_LTL_per_LFCF)
        Combination_of_Calc_Func('Total_LTL_per_LFCF', Total_LTL_per_LFCF, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        
        importing_data('CashperTotalDebt', CashperTotalDebt)
        Combination_of_Calc_Func('CashperTotalDebt', CashperTotalDebt, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])
        
        importing_data('Total_Debt_to_Equity', Total_Debt_to_Equity)
        Combination_of_Calc_Func('Total_Debt_to_Equity', Total_Debt_to_Equity, ['YoY', 'CAGR', 'YoYAvg', 'Avg'])

        end = timer()
        Time_remaining = round(((end-start)/Tick_Count)*Remaining_Count,0)
        Time_remaining_str = '{} seconds'.format(Time_remaining)
        if Time_remaining>60:
            Time_remaining = round(Time_remaining/60,1)
            Time_remaining_str = '{} minutes'.format(Time_remaining)
            if Time_remaining>60:
                Time_remaining = round(Time_remaining/60,1)
                Time_remaining_str = '{} hours'.format(Time_remaining)

        #Error Code String
        count = 0 
        List_str = ['Revenue[0]', 'Revenue[1]', 'Earnings[0]', 'Earnings[1]', 'Operating_Cash_Flow[0]', 
                    'Operating_Cash_Flow[1]', 'Property_Equipment', 'Current_Debt', 'Long_Term_Debt', 'Total_Debt', 
                    'Total_current_Liabilites', 'Total_Long_Term_Liabilities', 'Total_Liabilities', 'Equity', 
                    'Liabilities_And_StockholdersEquity', 'Cash', 'Shares_Outstanding', 'Market_Cap']      
        List = [Revenue[0], Revenue[1], Earnings[0], Earnings[1], Operating_Cash_Flow[0], 
                Operating_Cash_Flow[1], Property_Equipment, Current_Debt, Long_Term_Debt, Total_Debt, 
                Total_current_Liabilites, Total_Long_Term_Liabilities, Total_Liabilities, Equity, 
                Liabilities_And_StockholdersEquity, Cash, Shares_Outstanding, Market_Cap]
        
        # Code for calculating the future date for earnings 
        Calander_Data = dataForFurtureEarnings(List)
        importing_data_futureEarningsDate(Calander_Data)
        
        string = 'We have collected {} companies, with {} remaining. Estimated remaining time {} {}                            '.format(Tick_Count, Remaining_Count, Time_remaining_str, Ticker)
        print(string, end='\r')
        
        for table in List:
            count= count +1
            x = 1
            for items in table:
                if table[items] != {}:
                    x = 2
            if x == 1: 
                x=1/0

    except ZeroDivisionError:
        try:
            error_grouping[List_str[count-1]][sic_Description].append(Ticker)
        except: 
            try:
                error_grouping[List_str[count-1]][sic_Description] = []
                error_grouping[List_str[count-1]][sic_Description].append(Ticker)
            except:
                error_grouping[List_str[count-1]] = {}
                error_grouping[List_str[count-1]][sic_Description] = []
                error_grouping[List_str[count-1]][sic_Description].append(Ticker)
    except mysql.connector.Error:
        # Filters out duplicate errors 
        x=1
    except Exception as err:
        print("An error of {} has occured in the company {}                                                                        ".format(err, Ticker))
# error_grouping
# Out:
# We have collected 285 companies, with 7 remaining. Estimated remaining time 26.0 seconds TCRR

# %%
for labels in error_grouping:
    print(labels)
    for sic_group in error_grouping[labels]:
        print(sic_group)
        print(error_grouping[labels][sic_group])
    print('')

# %% [markdown]
# # This will shut down your computer

# %%
if Computer_Shutdown == 'Yes':
    import os
    def shutdown():
        return os.system("shutdown /s /t 1")
    shutdown()

# %%
cursor.close()
cnx.close()

# %%
# Label = 'CommonStockDividendsPerShareDeclared'
# for items in soup['facts']['us-gaap'][Label]['units']['USD/shares']:
# for items in soup['facts']['us-gaap']:
    
#     print(items)
